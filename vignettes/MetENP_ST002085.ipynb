# %% [markdown]
# ## MetENP

# %% [markdown]
# MetENP is a R package that enables detection of significant metabolites from metabolite information
# (names or names and concentration along with metadata information) and provides
#
# 1. Enrichment score of metabolite class,
# 2. Maps to pathway of the species of choice,
# 3. Calculate enrichment score of pathways,
# 4. Plots the pathways and shows the metabolite increase or decrease
# 5. Gets gene info, reaction info, enzyme info
#
# For more info, check out the vignette.

# %%
if (!requireNamespace("KEGGREST", quietly = TRUE))
    BiocManager::install("KEGGREST", update = TRUE, ask = FALSE)

if (!requireNamespace("KEGGgraph", quietly = TRUE))
    BiocManager::install("KEGGgraph", update = TRUE, ask = FALSE)

if (!requireNamespace("pathview", quietly = TRUE))
    BiocManager::install("pathview", update = TRUE, ask = FALSE)

#if (!requireNamespace("KEGG.db", quietly = TRUE))
#    BiocManager::install("KEGG.db", update = TRUE, ask = FALSE)

#if (!requireNamespace("MetENP", quietly = TRUE))
#    devtools::install("..", upgrade = "never")
# Out:
# ##############################################################################
# Pathview is an open source software package distributed under GNU General
# Public License version 3 (GPLv3). Details of GPLv3 is available at
# http://www.gnu.org/licenses/gpl-3.0.html. Particullary, users are required to
# formally cite the original Pathview paper (not just mention it) in publications
# or products. For details, do citation("pathview") within R.
#
# The pathview downloads and uses KEGG data. Non-academic uses may require a KEGG
# license agreement (details at http://www.kegg.jp/kegg/legal.html).
# ##############################################################################

# %%
USER_HOME=Sys.getenv("HOME");
USER_PWD=Sys.getenv("PWD");
#.libPaths( c( .libPaths(), paste0(USER_HOME, "/.local/R") ))
.libPaths( c( .libPaths(), paste0(USER_PWD, "/../../R") )); # suitable path to where MetENP R package is installed
#.libPaths( c( .libPaths(), paste0("../../R") )); # suitable path to where MetENP R package is installed

library(MetENP)

# %% [markdown]
# #### If you do not wish to install, alternatively, download from github(https://github.com/metabolomicsworkbench/MetENP) and load libraries and functions
# #### Complete information for this study is at Metabolomics Workbench: https://www.metabolomicsworkbench.org/data/DRCCMetadata.php?Mode=Study&StudyID=ST002085&StudyType=MS&ResultType=1

# %%
data = getmwstudies('ST002085', 'data')
head(data)
# Out:
#   analysis_id <NA>     <NA>     <NA>     <NA>     <NA>
# 1 AN003402    AN003402 AN003402 AN003402 AN003402 AN003402
# 2 AN003402    AN003402 AN003402 AN003402 AN003402 AN003402
# 3 AN003402    AN003402 AN003402 AN003402 AN003402 AN003402
# 4 AN003402    AN003402 AN003402 AN003402 AN003402 AN003402
# 5 AN003402    AN003402 AN003402 AN003402 AN003402 AN003402
# 6 AN003402    AN003402 AN003402 AN003402 AN003402 AN003402
#   analysis_summary        <NA>                    <NA>
# 1 HILIC POSITIVE ION MODE HILIC POSITIVE ION MODE HILIC POSITIVE ION MODE
# 2 HILIC POSITIVE ION MODE HILIC POSITIVE ION MODE HILIC POSITIVE ION MODE
# 3 HILIC POSITIVE ION MODE HILIC POSITIVE ION MODE HILIC POSITIVE ION MODE
# 4 HILIC POSITIVE ION MODE HILIC POSITIVE ION MODE HILIC POSITIVE ION MODE
# 5 HILIC POSITIVE ION MODE HILIC POSITIVE ION MODE HILIC POSITIVE ION MODE
# 6 HILIC POSITIVE ION MODE HILIC POSITIVE ION MODE HILIC POSITIVE ION MODE
#   <NA>                    <NA>                    <NA>
# 1 HILIC POSITIVE ION MODE HILIC POSITIVE ION MODE HILIC POSITIVE ION MODE
# 2 HILIC POSITIVE ION MODE HILIC POSITIVE ION MODE HILIC POSITIVE ION MODE
# 3 HILIC POSITIVE ION MODE HILIC POSITIVE ION MODE HILIC POSITIVE ION MODE
# 4 HILIC POSITIVE ION MODE HILIC POSITIVE ION MODE HILIC POSITIVE ION MODE
# 5 HILIC POSITIVE ION MODE HILIC POSITIVE ION MODE HILIC POSITIVE ION MODE
# 6 HILIC POSITIVE ION MODE HILIC POSITIVE ION MOD
# 5 3031                            1164
# 6 1210823                         756655

# %%
metadata = getmwstudies('ST002085', 'factors')
head(metadata)
# Out:
#   study_id local_sample_id sample_source factors      mb_sample_id raw_data
# 1 ST002085 20181221....    T-cells       Genotype.... SA198310     20181221....
# 2 ST002085 20181221....    T-cells       Genotype.... SA198313     20181221....
# 3 ST002085 20181221....    T-cells       Genotype.... SA198314     20181221....
# 4 ST002085 20181221....    T-cells       Genotype.... SA198312     20181221....
# 5 ST002085 20181221....    T-cells       Genotype.... SA198311     20181221....
# 6 ST002085 20181221....    T-cells       Genotype.... SA198317     20181221....
#   Genotype  Treatment
# 1 PRODH2_OE PRODH2
# 2 PRODH2_OE PRODH2
# 3 PRODH2_OE PRODH2
# 4 PRODH2_OE PRODH2
# 5 PRODH2_OE PRODH2
# 6 Vector_OE Control

# %% [markdown]
# Find the factors you would want to compare
# Multiple factors (independent variables) are formatted in multiple columns but you can get information on all the factors by "factors" column, such as 'TreatmentGroup:Prednisolone', this indicates column name 'TreatmentGroup' with factor Prednisolone. For t-test use the factors in the same column. For comparing multipe independent variables use anova by anova_ana function.

# %% [markdown]
# ### Associate metabolomics data to the refmet class

# %%
refmet_class= convert_refmet(data)
head(refmet_class)
# Out:
#   metabolite_name     analysis_id analysis_summary metabolite_id refmet_name
# 1 2-Hydroxy-Glutarate AN003402    HILIC PO....     ME483792      2-Hydrox....
# 2 2-Hydroxy-Glutarate AN003403    HILIC PO....     ME483836      2-Hydrox....
# 3 3-Phosphoserine     AN003402    HILIC PO....     ME483783      Phosphos....
# 4 3-Phosphoserine     AN003403    HILIC PO....     ME483827      Phosphos....
# 5 4-Hydroxy-Glutamate AN003402    HILIC PO....     ME483788      Erythro-....
# 6 4-Hydroxy-Glutamate AN003403    HILIC PO....     ME483832      Erythro-....
#   20181221_hProdh2_OE_1_M62 20181221_hProdh2_OE_2_M62 20181221_hProdh2_OE_3_M62
# 1 19140                     20065                     17383
# 2 19140                     20065                     17383
# 3 1968                      3001                      878
# 4 1968                      3001                      878
# 5 951                       1208                      3492
# 6 951                       1208                      3492
#   20181221_hProdh2_OE_4_M62 20181221_hProdh2_OE_5_M62
# 1 27650                     5763
# 2 27650                     5763
# 3 6420                      2976
# 4 6420                      2976
# 5 4155                      3755
# 6 4155                      3755
#   20181221_hProdh2_OE_Vector1_M62 20181221_hProdh2_OE_Vector2_M62
# 1 43202                           3879
# 2 43202                           3879
# 3 2051                            722
# 4 2051                            722
# 5 6300                            3382
# 6 6300                            3382
#   20181221_hProdh2_OE_Vector3_M62 20181221_hProdh2_OE_Vector4_M62
# 1 25582                           43366
# 2 25582                           43366
# 3 2442                            2808
# 4 2442                            2808
# 5 2946                            6041
# 6 2946                            6041
#   20181221_hProdh2_OE_Vector5_M62 formula  super_class
# 1 6616                            C5H8O5   Fatty Acyls
# 2 6616                            C5H8O5   Fatty Acyls
# 3 646                             C3H8NO6P Organic acids
# 4 646                             C3H8NO6P Organic acids
# 5 2656                            C5H9NO5  Organic acids
# 6 2656                            C5H9NO5  Organic acids
#   main_class               sub_class          refmet_id
# 1 Fatty acids              Dicarboxylic acids RM0153554
# 2 Fatty acids              Dicarboxylic acids RM0153554
# 3 Amino acids and peptides Amino acids        RM0135926
# 4 Amino acids and peptides Amino acids        RM0135926
# 5 Amino acids and peptides Amino acids        RM0056414
# 6 Amino acids and peptides Amino acids        RM0056414

# %%
unique(metadata$factors)
# Out:
# [[1]]
# [1] "Genotype:PRODH2_OE | Treatment:PRODH2"
#
# [[2]]
# [1] "Genotype:Vector_OE | Treatment:Control"

# %%
### Find the analysis mode
unique(data$analysis_summary)
# Out:
# [[1]]
# [1] "HILIC POSITIVE ION MODE"

# %% [markdown]
# ### Find significant metabolites, run significance of all the analysis summary together. The analysis summary/modes you got in the previous section
# There is a normalization step which takes into account missing values, and this can be achieved via three methods:
#
# 1) half_of_min: where the NAs are replaced by half of min values in the data
#
# 2) remove_NAs: where Cols with NAs values are removed
#
# 3) 50percent: where cols with more than 50% NAs values are removed, and then the remaining NA values are replaced with half_of_min
#
# half_of_min is ideal when you wish to see which metabolites were present in either group. Very high fold change would mean it was present in either group.

# %%
stats_metabolites = significant_met(metabolomics_data=refmet_class, met_col="metabolite_name",analysis_type=c("HILIC POSITIVE ION MODE"), metadata=metadata, factor1='Control', factor2=c('PRODH2'), factor_col='Treatment',sample_col='local_sample_id', p_adjust='fdr',normalization="50percent")

sig_metabolites = stats_metabolites[which(stats_metabolites[,"pval"] <= 0.05&abs(stats_metabolites[,"log2Fold_change"])>0.5),]

# %%
plot_volcano(stats_metabolites, thres_pval= 0.05,thres_log2foldchange = 0.5, TRUE)
# Out:
# plot without title

# %% [markdown]
# ### Map metabolite class of the significant metabolites utilzing refmet classification in Metabolomics Workbench
# This function not only maps metabolite to metabolite class but also to external databases such as pubchem, inchi key, smiles and kegg
#
# In this example, we will go forward with significant metabolite obtained by t-test/

# %%
sig_metabolites_kegg_id= map_keggid(sig_metabolites)

# %% [markdown]
# #### Check all your significant metabolites have not been assigned metabolite class

# %%
setdiff(sig_metabolites$refmet_name, sig_metabolites_kegg_id$refmet_name)
# Out:
# [1] "Oxoproline"

# %% [markdown]
# ### Count metabolites in each of the metabolite class and plotting
# You may choose from sub_class, main_class and super_class

# %%
count_changes = metcountplot(df_metclass=sig_metabolites_kegg_id, metclass='sub_class', plotting=TRUE, thres_logfC = 0.0, updown_fillcolor=c("red", "green"))
print(count_changes$sig_met_count)
# Out:
#           sub_class No.of_metabolites                 color
# 1                 -                 1 increased metabolites
# 2       Amino acids                 2 increased metabolites
# 3          Cholines                 1 increased metabolites
# 4     Hypoxanthines                 1 increased metabolites
# 5 Short-chain acids                 1 increased metabolites
# 6       Amino acids                -4 decreased metabolites
# 7 Short-chain acids                -1 decreased metabolites
# 8         TCA acids                -2 decreased metabolites

# %%
count_changes$plotimg
# Out:
# Warning message:
# “Use of `count_changes[[metclass]]` is discouraged.
# ℹ Use `.data[[metclass]]` instead.”
# plot without title

# %% [markdown]
# ### Enrichment class score
#
# Calculate the enrichment score of each metabolite class. Enrichment score is calculated through hypergeometric method. One can specify the no. of significant metabolites in a class while calculating the enrichment score. We advice to use the number of mtabolites in each class as 3 or more. But if someone just wants to know the enrichment score and rest of the information of all the metabolites, then they can choose the number as 1.

# %%
# pass debug = 0 below or comment some lines to suppress some print output
metenrichment = metclassenrichment(df_metclass=sig_metabolites_kegg_id,refmet_class, metclass="sub_class",enrich_stats="HG",no=1, debug = 1)
print(head(metenrichment))
#knitr::kable(head(metenrichment))
metenrichment[metenrichment$main_class %in% c("Ceramides", "Sphingomyelins"), c("Metabolite", "pval", "super_class", "main_class", "sub_class", "HG p-value")]
colnames(metenrichment)
metenrichment$super_class
metenrichment$main_class
metenrichment$sub_class
# Out:
# [1] "Name = Aspartic acid"
# [1] "M = 6"                  "L = 13"                 "N = 88"
# [4] "k = 48"                 "pp = 0.831390157184161"
# [1] "Name = Choline"
# [1] "M = 1"                  "L = 13"                 "N = 88"
# [4] "k = 2"                  "pp = 0.275078369905956"
# [1] "Name = cis-4-Hydroxyproline"
# [1] "M = 6"                  "L = 13"                 "N = 88"
# [4] "k = 48"                 "pp = 0.831390157184161"
# [1] "Name = Cystine"
# [1] "M = 6"                  "L = 13"                 "N = 88"
# [4] "k = 48"                 "pp = 0.831390157184161"
# [1] "Name = Glutamic acid"
# [1] "M = 6"                  "L = 13"                 "N = 88"
# [4] "k = 48"                 "pp = 0.831390157184161"
# [1] "Name = Guanine"
# [1] "M = 1"                  "L = 13"                 "N = 88"
# [4] "k = 2"                  "pp = 0.275078369905956"
# [1] "Name = Histidine"
# [1] "M = 6"                  "L = 13"                 "N = 88"
# [4] "k = 48"                 "pp = 0.831390157184161"
# [1] "Name = Lactic acid"
# [1] "M = 2"                  "L = 13"                 "N = 88"
# [4] "k = 4"                  "pp = 0.102326867905433"
# [1] "Name = Malic acid"
# [1] "M = 2"                  "L = 13"                 "N = 88"
# [4] "k = 10"                 "pp = 0.454617779004663"
# [1] "Name = Ornithine"
# [1] "M = 6"                  "L = 13"                 "N = 88"
# [4] "k = 48"                 "pp = 0.831390157184161"
# [1] "Name = Oxaloacetic acid"
# [1] "M = 2"                  "L = 13"                 "N = 88"
# [4] "k = 10"                 "pp = 0.454617779004663"
# [1] "Name = Pro-His-Cys"
# [1] "M = 1"                  "L = 13"                 "N = 88"
# [4] "k = 6"                  "pp = 0.628440775094942"
# [1] "Name = Pyruvic acid"
# [1] "M = 2"                  "L = 13"                 "N = 88"
# [4] "k = 4"                  "pp = 0.102326867905433"
#            refmet_name Exact mass KEGG ID       Metabolite Control_mean
# 1        Aspartic acid   133.0375  C00049    Aspartic acid     558528.2
# 2              Choline   104.1075  C00114          Choline      24981.6
# 3 cis-4-Hydroxyproline   131.0582  C01015 4-Hydroxyproline     139802.4
# 4              Cystine   240.0239  C00491          Cystine       3514.0
# 5        Glutamic acid   147.0532  C00025        Glutamate       341291
# 6              Guanine   151.0494  C00242          Guanine      16660.8
#   PRODH2_mean Fold_change log2Fold_change   t_value         pval       padj
# 1    242610.4   0.4343745      -1.2029887  5.440578 0.0025676570 0.02259538
# 2     64179.0   2.5690508       1.3612354 -3.699725 0.0137936775 0.06743576
# 3     58407.6   0.4177868      -1.2591611  6.367282 0.0015610538 0.02048054
# 4      8317.6   2.3669892       1.2430531 -2.691686 0.0317524001 0.10746966
# 5     1407425   4.1238269       2.0439838 -6.667387 0.0007422693 0.01925911
# 6     26459.6   1.5881350       0.6673336 -2.376347 0.0465670856 0.14635370
#   metabolite_id                super_class               main_class
# 1      ME483799              Organic acids Amino acids and peptides
# 2      ME483813 Organic nitrogen compounds                 Cholines
# 3      ME483803              Organic acids Amino acids and peptides
# 4      ME483778              Organic acids Amino acids and peptides
# 5      ME483793              Organic acids Amino acids and peptides
# 6      ME483790              Nucleic acids                  Purines
#       sub_class     formula HG p-value
# 1   Amino acids     C4H7NO4  0.8313902
# 2      Cholines     C5H14NO  0.2750784
# 3   Amino acids     C5H9NO3  0.8313902
# 4   Amino acids C6H12N2O4S2  0.8313902
# 5   Amino acids     C5H9NO4  0.8313902
# 6 Hypoxanthines     C5H5N5O  0.2750784
#      Metabolite pval super_class main_class sub_class HG p-value
#  [1] "refmet_name"     "Exact mass"      "KEGG ID"         "Metabolite"
#  [5] "Control_mean"    "PRODH2_mean"     "Fold_change"     "log2Fold_change"
#  [9] "t_value"         "pval"            "padj"            "metabolite_id"
# [13] "super_class"     "main_class"      "sub_class"       "formula"
# [17] "HG p-value"
#  [1] "Organic acids"              "Organic nitrogen compounds"
#  [3] "Organic acids"              "Organic acids"
#  [5] "Organic acids"              "Nucleic acids"
#  [7] "Organic acids"              "Organic acids"
#  [9] "Organic acids"              "Organic acids"
# [11] "Organic acids"              "-"
# [13] "Organic acids"
#  [1] "Amino acids and peptides" "Cholines"
#  [3] "Amino acids and peptides" "Amino acids and peptides"
#  [5] "Amino acids and peptides" "Purines"
#  [7] "Amino acids and peptides" "Short-chain acids"
#  [9] "TCA acids"                "Amino acids and peptides"
# [11] "TCA acids"                "-"
# [13] "Short-chain acids"
#  [1] "Amino acids"       "Cholines"          "Amino acids"
#  [4] "Amino acids"       "Amino acids"       "Hypoxanthines"
#  [7] "Amino acids"       "Short-chain acids" "TCA acids"
# [10] "Amino acids"       "TCA acids"         "-"
# [13] "Short-chain acids"

# %% [markdown]
# #### Plot the enrichment score via function plot_met_enrichment

# %%
plot_met_enrichment(metenrichment, "sub_class","HG", no=1)
# Out:
# Warning message:
# “Use of `metclass_stats[[metclass]]` is discouraged.
# ℹ Use `.data[[metclass]]` instead.”
# Warning message:
# “Use of `metclass_stats[[enrich_stats]]` is discouraged.
# ℹ Use `.data[[enrich_stats]]` instead.”
# Warning message:
# “Use of `metclass_stats[[enrich_stats]]` is discouraged.
# ℹ Use `.data[[enrich_stats]]` instead.”
# plot without title

# %% [markdown]
# ### Check the pathways with reactions of all the significant metabolites

# %%
met_path = met_pathways(df_metenrichment = metenrichment, 'hsa')
head(met_path)
# Out:
#   rxn    refmet_name   Exact mass KEGG ID Metabolite Control_mean PRODH2_mean
# 1 R00008 Pyruvic acid  88.0160    C00022  Pyruvate   2282.4        963.0
# 2 R00014 Pyruvic acid  88.0160    C00022  Pyruvate   2282.4        963.0
# 3 R00014 Pyruvic acid  88.0160    C00022  Pyruvate   2282.4        963.0
# 4 R00014 Pyruvic acid  88.0160    C00022  Pyruvate   2282.4        963.0
# 5 R00014 Pyruvic acid  88.0160    C00022  Pyruvate   2282.4        963.0
# 6 R00021 Glutamic acid 147.0532   C00025  Glutamate   341291      1407425
#   Fold_change log2Fold_change t_value   ⋯ metabolite_id super_class
# 1 0.4219243   -1.244944        4.457655 ⋯ ME483815      Organic acids
# 2 0.4219243   -1.244944        4.457655 ⋯ ME483815      Organic acids
# 3 0.4219243   -1.244944        4.457655 ⋯ ME483815      Organic acids
# 4 0.4219243   -1.244944        4.457655 ⋯ ME483815      Organic acids
# 5 0.4219243   -1.244944        4.457655 ⋯ ME483815      Organic acids
# 6 4.1238269    2.043984       -6.667387 ⋯ ME483793      Organic acids
#   main_class               sub_class         formula HG p-value Rxn_name
# 1 Short-chain acids        Short-chain acids C3H4O3  0.1023269  4-hydrox....
# 2 Short-chain acids        Short-chain acids C3H4O3  0.1023269  pyruvate....
# 3 Short-chain acids        Short-chain acids C3H4O3  0.1023269  pyruvate....
# 4 Short-chain acids        Short-chain acids C3H4O3  0.1023269  pyruvate....
# 5 Short-chain acids        Short-chain acids C3H4O3  0.1023269  pyruvate....
# 6 Amino acids and peptides Amino acids       C5H9NO4 0.8313902  L-glutam....
#   PATHWAY                                 pathway_id sps_path_id
# 1 Metabolic pathways                      rn01100    hsa01100
# 2 Glycolysis / Gluconeogenesis            rn00010    hsa00010
# 3 Citrate cycle (TCA cycle)               rn00020    hsa00020
# 4 Pyruvate metabolism                     rn00620    hsa00620
# 5 Lipoic acid metabolism                  rn00785    hsa00785
# 6 Glyoxylate and dicarboxylate metabolism rn00630    hsa00630

# %% [markdown]
# Find metabolites for which no pathways were registered in Kegg and/or no kegg id was found

# %%
setdiff(metenrichment$Metabolite,unique(met_path$Metabolite))
# Out:
# [1] "4-Hydroxyproline" "PHC"

# %% [markdown]
# ### Get pathway enrichment sore.
#
# Once we have the pathway information, we can calculate enrichment score of pathways. Again, here I have used hypergeometric (HG) score. For hypergeometric score, we need to know the total number of kegg compounds that are linked to kegg pathways.
#
# N = total no. of compounds/metabolites linked to all kegg pathways (kegg_comp_path = TRUE) or the total number of metabolites detected in a study (kegg_comp_path = FALSE).
#
# In the former case, this step might take long time, so I advice to run the script comp_linkedto_pathways() just the first time or after 6 months or so if desired to run the pipeline again. Save the result from comp_linkedto_pathways() and load it. Loading from saved file would save time for another analysis with another study. However the package takes care of loading. Save the data in the data folder.
#
# L = No. of significant metabolites detected in a study
#
# M = No. of significant metabolites detected in a metabolite class or pathway
#
# k = Total no. of metabolites detected in a metabolite class/pathway
#
# p-value = phyper(M-1, L, N-L, k, lower.tail=FALSE) # as in the actual R code # originally, it was wriiten as: phyper(M, L, N-L, K)
#
# This function also utilizes korg dataset from pathview package.

# %%
load('../data/ls_path.RData')
load('../data/korg.RData')
kegg_es = path_enrichmentscore(met_path,sig_metabolites_kegg_id=sig_metabolites_kegg_id,ls_path=ls_path,refmet_class=refmet_class,sps='hsa',padj='BH', kegg_comp_path=TRUE, debug = 1)
# Out:
#    M  L    N   k           pp
# 1  4 13 6148  28 2.393293e-07
# 2  1 13 6148  73 1.439577e-01
# 3  3 13 6148  52 1.537805e-04
# 4  2 13 6148  79 1.160218e-02
# 5  5 13 6148  71 2.133886e-07
# 6  5 13 6148  24 7.332604e-10
# 7  1 13 6148  57 1.141504e-01
# 8  4 13 6148  32 4.183600e-07
# 9  2 13 6148 122 2.640809e-02
# 10 2 13 6148  47 4.228976e-03
# 11 3 13 6148  20 8.249213e-06
# 12 4 13 6148  68 9.081455e-06
# 13 6 13 6148  69 2.584648e-09
# 14 1 13 6148  25 5.164120e-02
# 15 2 13 6148  58 6.382448e-03
# 16 2 13 6148  55 5.754319e-03
# 17 1 13 6148  46 9.310526e-02
# 18 2 13 6148  38 2.779880e-03
# 19 1 13 6148  38 7.751088e-02
# 20 1 13 6148  56 1.122560e-01
# 21 5 13 6148  50 3.553099e-08
# 22 3 13 6148  31 3.209201e-05
# 23 5 13 6148  67 1.589769e-07
# 24 4 13 6148  47 2.038818e-06
# 25 1 13 6148  44 8.922964e-02
# 26 2 13 6148  56 5.960333e-03
# 27 1 13 6148  81 1.585117e-01
# 28 3 13 6148  55 1.818842e-04
# 29 1 13 6148  20 4.151424e-02
# 30 2 13 6148  26 1.303679e-03
# 31 3 13 6148  30 2.902180e-05
# 32 1 13 6148  61 1.216907e-01
# 33 1 13 6148  37 7.554427e-02
# 34 2 13 6148  51 4.964192e-03
# 35 4 13 6148  35 6.070137e-07
# 36 2 13 6148  57 6.169714e-03
# 37 2 13 6148 148 3.773547e-02
# 38 4 13 6148  42 1.286975e-06
# 39 3 13 6148 101 1.092034e-03
# 40 2 13 6148  66 8.203537e-03
# 41 4 13 6148  32 4.183600e-07
# 42 1 13 6148  27 5.566425e-02
# 43 1 13 6148  36 7.357380e-02
# 44 6 13 6148  24 3.033126e-12
# 45 1 13 6148  47 9.503735e-02
# 46 2 13 6148  31 1.854171e-03
# 47 2 13 6148  84 1.304935e-02
# 48 2 13 6148  79 1.160218e-02
# 49 2 13 6148  74 1.023196e-02
# 50 2 13 6148  23 1.018503e-03
# 51 2 13 6148  42 3.388457e-03
# 52 4 13 6148  29 2.772959e-07
# [1] "freqtable = "
#                                           Pathway name
# 1          Alanine, aspartate and glutamate metabolism
# 2          Amino sugar and nucleotide sugar metabolism
# 3                          Aminoacyl-tRNA biosynthesis
# 4                          Arachidonic acid metabolism
# 5                      Arginine and proline metabolism
# 6                                Arginine biosynthesis
# 7                    Ascorbate and aldarate metabolism
# 8                              beta-Alanine metabolism
# 9            Biosynthesis of various nucleotide sugars
# 10                                Butanoate metabolism
# 11                           Citrate cycle (TCA cycle)
# 12                  Cysteine and methionine metabolism
# 13                             D-Amino acid metabolism
# 15                              Ether lipid metabolism
# 16                                 Folate biosynthesis
# 17                     Fructose and mannose metabolism
# 18                                Galactose metabolism
# 19                              Glutathione metabolism
# 20                             Glycerolipid metabolism
# 21                      Glycerophospholipid metabolism
# 22            Glycine, serine and threonine metabolism
# 23                        Glycolysis / Gluconeogenesis
# 24             Glyoxylate and dicarboxylate metabolism
# 25                                Histidine metabolism
# 26                              Lipoic acid metabolism
# 27                                  Lysine degradation
# 28     Neomycin, kanamycin and gentamicin biosynthesis
# 29              Nicotinate and nicotinamide metabolism
# 30                                 Nitrogen metabolism
# 31                           One carbon pool by folate
# 32                   Pantothenate and CoA biosynthesis
# 33            Pentose and glucuronate interconversions
# 34                           Pentose phosphate pathway
# 35                            Phenylalanine metabolism
# 36 Phenylalanine, tyrosine and tryptophan biosynthesis
# 37              Phosphonate and phosphinate metabolism
# 38                                Porphyrin metabolism
# 39                               Propanoate metabolism
# 40                                   Purine metabolism
# 41                               Pyrimidine metabolism
# 42                                 Pyruvate metabolism
# 43                           Selenocompound metabolism
# 44                             Sphingolipid metabolism
# 45                  Taurine and hypotaurine metabolism
# 46                     Terpenoid backbone biosynthesis
# 47                                 Thiamine metabolism
# 48                               Tryptophan metabolism
# 49                                 Tyrosine metabolism
# 50 Ubiquinone and other terpenoid-quinone biosynthesis
# 51         Valine, leucine and isoleucine biosynthesis
# 52          Valine, leucine and isoleucine degradation
# 53                               Vitamin B6 metabolism
#    No. of sig mets in pathway Total_no._of_comps_in_pathway
# 1                           4                            28
# 2                           1                            73
# 3                           3                            52
# 4                           2                            79
# 5                           5                            71
# 6                           5                            24
# 7                           1                            57
# 8                           4                            32
# 9                           2                           122
# 10                          2                            47
# 11                          3                            20
# 12                          4                            68
# 13                          6                            69
# 15                          1                            25
# 16                          2                            58
# 17                          2                            55
# 18                          1                            46
# 19                          2                            38
# 20                          1                            38
# 21                          1                            56
# 22                          5                            50
# 23                          3                            31
# 24                          5                            67
# 25                          4                            47
# 26                          1                            44
# 27                          2                            56
# 28                          1                            81
# 29                          3                            55
# 30                          1                            20
# 31                          2                            26
# 32                          3                            30
# 33                          1                            61
# 34                          1                            37
# 35                          2                            51
# 36                          4                            35
# 37                          2                            57
# 38                          2                           148
# 39                          4                            42
# 40                          3                           101
# 41                          2                            66
# 42                          4                            32
# 43                          1                            27
# 44                          1                            36
# 45                          6                            24
# 46                          1                            47
# 47                          2                            31
# 48                          2                            84
# 49                          2                            79
# 50                          2                            74
# 51                          2                            23
# 52                          2                            42
# 53                          4                            29
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             id
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          
# 3 C00025;C00037;C00041;C00047;C00049;C00062;C00064;C00065;C00073;C00078;C00079;C00082;C00097;C00101;C00123;C00135;C00148;C00152;C00183;C00188;C00234;C00407;C00886;C01005;C01931;C02047;C02163;C02282;C02412;C02430;C02553;C02554;C02702;C02839;C02984;C02987;C02988;C02992;C03125;C03127;C03294;C03402;C03511;C03512;C06112;C06113;C06481;C06482;C16138;C16638;C17022;C17027
# 4 C00157;C00219;C00427;C00584;C00639;C00696;C00909;C01312;C02165;C02166;C02198;C03577;C04577;C04671;C04707;C04742;C04758;C04805;C04822;C04835;C04853;C05356;C05949;C05950;C05951;C05952;C05953;C05954;C05955;C05956;C05957;C05958;C05959;C05960;C05961;C05962;C05963;C05964;C05965;C05966;C06314;C06315;C06462;C13809;C14717;C14732;C14748;C14749;C14768;C14769;C14770;C14771;C14772;C14773;C14774;C14775;C14776;C14777;C14778;C14779;C14780;C14781;C14782;C14794;C14795;C14807;C14808;C14809;C14810;C14811;C14812;C14813;C14814;C14815;C14820;C14821;C14822;C14823;C14824
# 5 C00012;C00019;C00022;C00025;C00048;C00062;C00077;C00086;C00134;C00148;C00179;C00213;C00223;C00300;C00315;C00334;C00406;C00431;C00436;C00441;C00533;C00555;C00581;C00750;C00763;C00791;C00884;C00986;C01035;C01043;C01110;C01137;C01157;C01165;C01250;C01682;C02305;C02565;C02647;C02714;C02946;C03078;C03166;C03287;C03296;C03375;C03415;C03564;C03771;C03912;C04137;C04281;C05147;C05931;C05932;C05933;C05936;C05938;C05945;C05946;C05947;C10497;C15699;C15700;C15767;C18172;C18174;C18326;C19706;C20560;C22886
# 6 C00011;C00014;C00025;C00026;C00049;C00062;C00064;C00077;C00086;C00122;C00169;C00288;C00327;C00437;C00624;C01010;C01250;C03406;C04133;C15532;C20948;C20949;C20950;C20951
#   pathway_HG_p_value Padjust
# 1 2.393293e-07       1.777874e-06
# 2 1.439577e-01       1.467804e-01
# 3 1.537805e-04       4.442547e-04
# 4 1.160218e-02       1.723752e-02
# 5 2.133886e-07       1.777874e-06
# 6 7.332604e-10       1.906477e-08

# %% [markdown]
# ### Plot pathway network
# Only plotting significant pathways (pathway with p-value significance).
#
# The pathway network is such that it shows metabolites that are connected to different pathways and same metabolite in different pathway. Color of nodes of metabolites are according to the fold change of metabolites (low expression in green and high in red) and size of pathway nodes (square nodes) are according to the number of branches (meaning no of metabolites). All metabolite are written in blue

# %%
plot_pathway_networks (met_path,kegg_es, TRUE)
# Out:
# Warning message:
# “ggrepel: 9 unlabeled data points (too many overlaps). Consider increasing max.overlaps”
# plot without title

# %% [markdown]
# ### Heatmap

# %%
plot_heatmap(met_path, shorten_name=TRUE,refmet_name=FALSE, xaxis=8, yaxis=6)
# Out:
# plot without title

# %% [markdown]
# ### Dotplot

# %%
dotplot_met_class_path (met_path, kegg_es,"sub_class",xaxis=8,yaxis=6)
# Out:
# Warning message:
# “Use of `significant_pathways[["pathway_HG_p_value"]]` is discouraged.
# ℹ Use `.data[["pathway_HG_p_value"]]` instead.”
# plot without title

# %% [markdown]
# ### Get the gene and enzyme info
#
# Here we get the information of genes involved in enriched pathways for specified organism

# %%
met_gene_info = enzyme_gene_info (metenrichment, "hsa","sub_class")
head(met_gene_info)
# Out:
#   orthology_id ORTHOLOGY                             gene_id gene_name
# 1 K00016       L-lactate dehydrogenase [EC:1.1.1.27] 160287  (RefSeq)....
# 2 K00016       L-lactate dehydrogenase [EC:1.1.1.27] 160287  (RefSeq)....
# 3 K00016       L-lactate dehydrogenase [EC:1.1.1.27]   3939  (RefSeq)....
# 4 K00016       L-lactate dehydrogenase [EC:1.1.1.27]   3939  (RefSeq)....
# 5 K00016       L-lactate dehydrogenase [EC:1.1.1.27]   3945  (RefSeq)....
# 6 K00016       L-lactate dehydrogenase [EC:1.1.1.27]   3945  (RefSeq)....
#   ORGANISM     PATHWAY      DBLINKS      MOTIF        rxn    Metabolite KEGG ID
# 1 Homo sap.... Glycolys.... NCBI-Gen.... Pfam: Ld.... R00703 Lactate    C00186
# 2 Homo sap.... Glycolys.... NCBI-Gen.... Pfam: Ld.... R00703 Pyruvate   C00022
# 3 Homo sap.... Glycolys.... NCBI-Gen.... Pfam: Ld.... R00703 Lactate    C00186
# 4 Homo sap.... Glycolys.... NCBI-Gen.... Pfam: Ld.... R00703 Pyruvate   C00022
# 5 Homo sap.... Glycolys.... NCBI-Gen.... Pfam: Ld.... R00703 Lactate    C00186
# 6 Homo sap.... Glycolys.... NCBI-Gen.... Pfam: Ld.... R00703 Pyruvate   C00022
#   sub_class         Rxn_name     RCLASS       EQUATION     EQUATION_more
# 1 Short-chain acids (S)-lact.... RC00001 .... C00186 +.... (S)-Lact....
# 2 Short-chain acids (S)-lact.... RC00001 .... C00186 +.... (S)-Lact....
# 3 Short-chain acids (S)-lact.... RC00001 .... C00186 +.... (S)-Lact....
# 4 Short-chain acids (S)-lact.... RC00001 .... C00186 +.... (S)-Lact....
# 5 Short-chain acids (S)-lact.... RC00001 .... C00186 +.... (S)-Lact....
# 6 Short-chain acids (S)-lact.... RC00001 .... C00186 +.... (S)-Lact....
#   ENZYME
# 1 1.1.1.27
# 2 1.1.1.27
# 3 1.1.1.27
# 4 1.1.1.27
# 5 1.1.1.27
# 6 1.1.1.27

# %% [markdown]
# #### Get the information if metabolite is a reactant or substrate

# %%
rclass_info = react_substrate(met_gene_info)
head(rclass_info)
# Out:
#   orthology_id ORTHOLOGY                             gene_id gene_name
# 1 K00016       L-lactate dehydrogenase [EC:1.1.1.27] 160287  (RefSeq)....
# 2 K00016       L-lactate dehydrogenase [EC:1.1.1.27] 160287  (RefSeq)....
# 3 K00016       L-lactate dehydrogenase [EC:1.1.1.27]   3939  (RefSeq)....
# 4 K00016       L-lactate dehydrogenase [EC:1.1.1.27]   3939  (RefSeq)....
# 5 K00016       L-lactate dehydrogenase [EC:1.1.1.27]   3945  (RefSeq)....
# 6 K00016       L-lactate dehydrogenase [EC:1.1.1.27]   3945  (RefSeq)....
#   ORGANISM     PATHWAY      DBLINKS      MOTIF        rxn    Metabolite KEGG ID
# 1 Homo sap.... Glycolys.... NCBI-Gen.... Pfam: Ld.... R00703 Lactate    C00186
# 2 Homo sap.... Glycolys.... NCBI-Gen.... Pfam: Ld.... R00703 Pyruvate   C00022
# 3 Homo sap.... Glycolys.... NCBI-Gen.... Pfam: Ld.... R00703 Lactate    C00186
# 4 Homo sap.... Glycolys.... NCBI-Gen.... Pfam: Ld.... R00703 Pyruvate   C00022
# 5 Homo sap.... Glycolys.... NCBI-Gen.... Pfam: Ld.... R00703 Lactate    C00186
# 6 Homo sap.... Glycolys.... NCBI-Gen.... Pfam: Ld.... R00703 Pyruvate   C00022
#   sub_class         Rxn_name     RCLASS       EQUATION     EQUATION_more
# 1 Short-chain acids (S)-lact.... RC00001 .... C00186 +.... (S)-Lact....
# 2 Short-chain acids (S)-lact.... RC00001 .... C00186 +.... (S)-Lact....
# 3 Short-chain acids (S)-lact.... RC00001 .... C00186 +.... (S)-Lact....
# 4 Short-chain acids (S)-lact.... RC00001 .... C00186 +.... (S)-Lact....
# 5 Short-chain acids (S)-lact.... RC00001 .... C00186 +.... (S)-Lact....
# 6 Short-chain acids (S)-lact.... RC00001 .... C00186 +.... (S)-Lact....
#   ENZYME   reactant_product
# 1 1.1.1.27 Substrate
# 2 1.1.1.27 Product
# 3 1.1.1.27 Substrate
# 4 1.1.1.27 Product
# 5 1.1.1.27 Substrate
# 6 1.1.1.27 Product

# %% [markdown]
# #### Get gene info in short form

# %%
met_gene_info2=data.table::data.table(rclass_info)[,lapply(.SD, function(x) toString(unique(x))), by = 'Metabolite']
