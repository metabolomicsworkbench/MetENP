# %% [markdown]
# ## MetENP

# %% [markdown]
# MetENP is a R package that enables detection of significant metabolites from metabolite information
# (names or names and concentration along with metadata information) and provides
#
# 1. Enrichment score of metabolite class,
# 2. Maps to pathway of the species of choice,
# 3. Calculate enrichment score of pathways,
# 4. Plots the pathways and shows the metabolite increase or decrease
# 5. Gets gene info, reaction info, enzyme info
#
# For more info, check out the vignette.

# %%
if (!requireNamespace("KEGGREST", quietly = TRUE))
    BiocManager::install("KEGGREST", update = TRUE, ask = FALSE)

if (!requireNamespace("KEGGgraph", quietly = TRUE))
    BiocManager::install("KEGGgraph", update = TRUE, ask = FALSE)

if (!requireNamespace("pathview", quietly = TRUE))
    BiocManager::install("pathview", update = TRUE, ask = FALSE)

#if (!requireNamespace("KEGG.db", quietly = TRUE))
#    BiocManager::install("KEGG.db", update = TRUE, ask = FALSE)

#if (!requireNamespace("MetENP", quietly = TRUE))
#    devtools::install("..", upgrade = "never")
# Out:
# ##############################################################################
# Pathview is an open source software package distributed under GNU General
# Public License version 3 (GPLv3). Details of GPLv3 is available at
# http://www.gnu.org/licenses/gpl-3.0.html. Particullary, users are required to
# formally cite the original Pathview paper (not just mention it) in publications
# or products. For details, do citation("pathview") within R.
#
# The pathview downloads and uses KEGG data. Non-academic uses may require a KEGG
# license agreement (details at http://www.kegg.jp/kegg/legal.html).
# ##############################################################################

# %%
USER_HOME=Sys.getenv("HOME");
USER_PWD=Sys.getenv("PWD");
#.libPaths( c( .libPaths(), paste0(USER_HOME, "/.local/R") ))
.libPaths( c( .libPaths(), paste0(USER_PWD, "/../../R") )); # suitable path to where MetENP R package is installed
#.libPaths( c( .libPaths(), paste0("../../R") )); # suitable path to where MetENP R package is installed

library(MetENP)

# %% [markdown]
# #### If you do not wish to install, alternatively, download from github(https://github.com/metabolomicsworkbench/MetENP) and load libraries and functions

# %%
data = getmwstudies('ST000915', 'data')
head(data)
# Out:
#   analysis_id <NA>     <NA>     <NA>     <NA>     <NA>
# 1 AN001485    AN001485 AN001485 AN001485 AN001485 AN001485
# 2 AN001485    AN001485 AN001485 AN001485 AN001485 AN001485
# 3 AN001485    AN001485 AN001485 AN001485 AN001485 AN001485
# 4 AN001485    AN001485 AN001485 AN001485 AN001485 AN001485
# 5 AN001485    AN001485 AN001485 AN001485 AN001485 AN001485
# 6 AN001485    AN001485 AN001485 AN001485 AN001485 AN001485
#   analysis_summary               <NA>
# 1 Core G Fatty acids/Eicosanoids Core G Fatty acids/Eicosanoids
# 2 Core G Fatty acids/Eicosanoids Core G Fatty acids/Eicosanoids
# 3 Core G Fatty acids/Eicosanoids Core G Fatty acids/Eicosanoids
# 4 Core G Fatty acids/Eicosanoids Core G Fatty acids/Eicosanoids
# 5 Core G Fatty acids/Eicosanoids Core G Fatty acids/Eicosanoids
# 6 Core G Fatty acids/Eicosanoids Core G Fatty acids/Eicosanoids
#   <NA>                           <NA>
# 1 Core G Fatty acids/Eicosanoids Core G Fatty acids/Eicosanoids
# 2 Core G Fatty acids/Eicosanoids Core G Fatty acids/Eicosanoids
# 3 Core G Fatty acids/Eicosanoids Core G Fatty acids/Eicosanoids
# 4 Core G Fatty acids/Eicosanoids Core G Fatty acids/Eicosanoids
# 5 Core G Fatty acids/Eicosanoids Core G Fatty acids/Eicosanoids
# 6 Core G Fatty acids/Eicosanoids Core G Fatty acids/Eicosanoids
#   <NA>                           <NA>                           metabolite_name
# 1 Core G Fatty acids/Eicosanoids Core G Fatty acids/Eicosanoids 10 HDoHE
# 2 Core G Fatty acids/Eicosanoids Core G Fatty acids/Eicosanoids 10 HDoHE
# 3 Core G Fatty acids/Eicosanoids Core G Fatty acids/Eicosanoids 10 HDoHE
# 4 Core G Fatty acids/Eicosanoids Core G Fatty acids/Eicosanoids 10 HDoHE
# 5 Core G Fatty acids/Eicosanoids Core G Fatty acids/Eicosanoids 10 HDoHE
# 6 Core G Fatty acids/Eicosanoids Core G Fatty acids/Eicosanoids 10 HDoHE
#   <NA>          <NA>      <NA>     <NA>     <NA>    metabolite_id <NA>
# 1 11,12-diHETrE 11,12-EET 11b PGE2 11 HDoHE 11-HEPE ME230937      ME230961
# 2 11,12-diHETrE 11,12-EET 11b PGE2 11 HDoHE 11-HEPE ME230937      ME230961
# 3 11,12-diHETrE 11,12-EET 11b PGE2 11 HDoHE 11-HEPE ME230937      ME230961
# 4 11,12-diHETrE 11,12-EET 11b PGE2 11 HDoHE 11-HEPE ME230937      ME230961
# 5 11,12-diHETrE 11,12-EET 11b PGE2 11 HDoHE 11-HEPE ME230937      ME230961
# 6 11,12-diHETrE 11,12-EET 11b PGE2 11 HDoHE 11-HEPE ME230937      ME230961
#   <NA>     <NA>     <NA>     <NA>     refmet_name <NA>          <NA>
# 1 ME230954 ME230914 ME230941 ME230917 10-HDoHE    11,12-DiHETrE 11,12-EpETrE
# 2 ME230954 ME230914 ME230941 ME230917 10-HDoHE    11,12-DiHETrE 11,12-EpETrE
# 3 ME230954 ME230914 ME230941 ME230917 10-HDoHE    11,12-DiHETrE 11,12-EpETrE
# 4 ME230954 ME230914 ME230941 ME230917 10-HDoHE    11,12-DiHETrE 11,12-EpETrE
# 5 ME230954 ME230914 ME230941 ME230917 10-HDoHE    11,12-DiHETrE 11,12-EpETrE
# 6 ME230954 ME230914 ME230941 ME230917 10-HDoHE    11,12-DiHETrE 11,12-EpETrE
#   <NA>        <NA>     <NA>    NASH001 NASH002 NASH003 NASH004 NASH005 ⋯
# 1 11beta-PGE2 11-HDoHE 11-HEPE 0.00419 0.01396 0.00285 0.00705 0.00020 ⋯
# 2 11beta-PGE2 11-HDoHE 11-HEPE 0.01346 1.84739 0.63897 1.87466 0.21119 ⋯
# 3 11beta-PGE2 11-HDoHE 11-HEPE 0.20666 0.12915 0.18170 0.11368 0.06081 ⋯
# 4 11beta-PGE2 11-HDoHE 11-HEPE 0.00048 0.00128 NA      NA      NA      ⋯
# 5 11beta-PGE2 11-HDoHE 11-HEPE 0.00617 0.03174 0.00958 0.00593 0.00271 ⋯
# 6 11beta-PGE2 11-HDoHE 11-HEPE 0.00642 NA      0.01625 0.02049 0.00115 ⋯
#   NASH082 NASH083 NASH084 NASH085 NASH086 NASH087 NASH088 NASH089 NASH090
# 1 0.00073 0.00641 0.00667 0.00143 0.02844 0.02243 0.00915 0.00366 0.00208
# 2 0.06045 0.03386 0.01953 0.02720 0.02104 0.06057 0.03444 0.01259 0.02891
# 3 0.97974 0.66245 0.19845 0.30318 0.37735 0.67719 0.64060 0.39347 0.22317
# 4 0.00098 0.00206 0.00076 0.00213 0.00093 0.02040 0.02086 0.00070 0.00136
# 5 0.01842 0.01902 0.01049 0.00151 0.02371 0.03326 0.00267 0.00232 NA
# 6 0.02481 0.00969 0.00109 NA      0.02083 0.00539 0.00666 0.00745 0.01074
#   NASH091
# 1 0.00144
# 2 0.05983
# 3 0.38579
# 4 0.00969
# 5 0.00584
# 6 0.00425

# %%
metadata = getmwstudies('ST000915', 'factors')
head(metadata)
# Out:
#   study_id local_sample_id sample_source factors      mb_sample_id raw_data
# 1 ST000915 NASH005         Liver         Diagnosi.... SA053807
# 2 ST000915 NASH007         Liver         Diagnosi.... SA053815
# 3 ST000915 NASH009         Liver         Diagnosi.... SA053817
# 4 ST000915 NASH013         Liver         Diagnosi.... SA053813
# 5 ST000915 NASH016         Liver         Diagnosi.... SA053812
# 6 ST000915 NASH022         Liver         Diagnosi.... SA053816
#   Diagnosis
# 1 Cirrhosis
# 2 Cirrhosis
# 3 Cirrhosis
# 4 Cirrhosis
# 5 Cirrhosis
# 6 Cirrhosis

# %% [markdown]
# Find the factors you would want to compare
# Multiple factors (independent variables) are formatted in multiple columns but you can get information on all the factors by "factors" column, such as 'TreatmentGroup:Prednisolone', this indicates column name 'TreatmentGroup' with factor Prednisolone. For t-test use the factors in the same column. For comparing multipe independent variables use anova by anova_ana function.

# %% [markdown]
# ### Associate metabolomics data to the refmet class

# %%
refmet_class= convert_refmet(data)
head(refmet_class)
# Out:
#   metabolite_name analysis_id analysis_summary metabolite_id refmet_name
# 1 1,2-DG(30:0)    AN001488    Core E N....     ME231190      1,2-DG 30:0
# 2 1,2-DG(30:1)    AN001488    Core E N....     ME231189      1,2-DG 30:1
# 3 1,2-DG(32:0)    AN001488    Core E N....     ME231196      1,2-DG 32:0
# 4 1,2-DG(32:1)    AN001488    Core E N....     ME231195      1,2-DG 32:1
# 5 1,2-DG(32:2)    AN001488    Core E N....     ME231194      1,2-DG 32:2
# 6 1,2-DG(32:3)    AN001488    Core E N....     ME231193      1,2-DG 32:3
#   NASH001 NASH002 NASH003 NASH004 NASH005 ⋯ NASH087 NASH088 NASH089 NASH090
# 1 2.7     NA      NA      NA      NA      ⋯ 68.2    87.9    33.1    45.7
# 2 1.8     NA      NA      NA      NA      ⋯ 24.2    34.9    15.2    26.0
# 3 12.2    7.1     2.2     2.0     1.4     ⋯ 221.6   300.8   115.0   200.2
# 4 7.6     5.7     2.1     1.4     1.1     ⋯ 134.5   217.6   88.8    151.2
# 5 2.0     1.9     NA      NA      NA      ⋯ 77.9    125.3   63.7    92.7
# 6 NA      NA      NA      NA      NA      ⋯ 7.8     16.1    8.5     11.4
#   NASH091 formula  super_class   main_class       sub_class refmet_id
# 1 9.2     C33H64O5 Glycerolipids Diradylglycerols DAG       RM0035472
# 2 5.5     C33H62O5 Glycerolipids Diradylglycerols DAG       RM0030559
# 3 29.4    C35H68O5 Glycerolipids Diradylglycerols DAG       RM0033817
# 4 26.5    C35H66O5 Glycerolipids Diradylglycerols DAG       RM0033888
# 5 18.6    C35H64O5 Glycerolipids Diradylglycerols DAG       RM0033590
# 6 3.8     C35H62O5 Glycerolipids Diradylglycerols DAG       RM0030553

# %%
unique(metadata$factors)
# Out:
# [[1]]
# [1] "Diagnosis:Cirrhosis"
#
# [[2]]
# [1] "Diagnosis:NASH"
#
# [[3]]
# [1] "Diagnosis:Normal"
#
# [[4]]
# [1] "Diagnosis:Steatosis"

# %%
### Find the analysis mode
unique(data$analysis_summary)
# Out:
# [[1]]
# [1] "Core G Fatty acids/Eicosanoids"
#
# [[2]]
# [1] "Core J Sterols"
#
# [[3]]
# [1] "Core K Prenols/Cardiolipins"
#
# [[4]]
# [1] "Core E Neutral Lipids"
#
# [[5]]
# [1] "Core I Sphingolipids"
#
# [[6]]
# [1] "Core H Phospholipids"

# %% [markdown]
# ### Find significant metabolites, run significance of all the analysis summary together. The analysis summary/modes you got in the previous section
# There is a normalization step which takes into account missing values, and this can be achieved via three methods:
#
# 1) half_of_min: where the NAs are replaced by half of min values in the data
#
# 2) remove_NAs: where Cols with NAs values are removed
#
# 3) 50percent: where cols with more than 50% NAs values are removed, and then the remaining NA values are replaced with half_of_min
#
# half_of_min is ideal when you wish to see which metabolites were present in either group. Very high fold change would mean it was present in either group.

# %%
stats_metabolites = significant_met(metabolomics_data=refmet_class, met_col="metabolite_name",analysis_type=c("Core G Fatty acids/Eicosanoids","Core J Sterols","Core K Prenols/Cardiolipins","Core E Neutral Lipids","Core I Sphingolipids","Core H Phospholipids"), metadata=metadata, factor1='Cirrhosis', factor2=c('Normal'), factor_col='Diagnosis',sample_col='local_sample_id', p_adjust='fdr',normalization="50percent")

sig_metabolites = stats_metabolites[which(stats_metabolites[,"pval"] <= 0.05&abs(stats_metabolites[,"log2Fold_change"])>0.5),]

# %%
plot_volcano(stats_metabolites, thres_pval= 0.05,thres_log2foldchange = 0.5, TRUE)
# Out:
# Warning message:
# “ggrepel: 48 unlabeled data points (too many overlaps). Consider increasing max.overlaps”
# plot without title

# %% [markdown]
# ### Map metabolite class of the significant metabolites utilzing refmet classification in Metabolomics Workbench
# This function not only maps metabolite to metabolite class but also to external databases such as pubchem, inchi key, smiles and kegg
#
# In this example, we will go forward with significant metabolite obtained by t-test/

# %%
sig_metabolites_kegg_id= map_keggid(sig_metabolites)

# %% [markdown]
# #### Check all your significant metabolites have not been assigned metabolite class

# %%
setdiff(sig_metabolites$refmet_name, sig_metabolites_kegg_id$refmet_name)
# Out:
# [1] "11,12-EpETrE" "14,15-EpETrE" "5,6-EpETrE"   ""             "PE P-36:4"

# %% [markdown]
# ### Count metabolites in each of the metabolite class and plotting
# You may choose from sub_class, main_class and super_class

# %%
count_changes = metcountplot(df_metclass=sig_metabolites_kegg_id, metclass='sub_class', plotting=TRUE, thres_logfC = 0.0, updown_fillcolor=c("red", "green"))
print(count_changes$sig_met_count)
# Out:
#             sub_class No.of_metabolites                 color
# 1                   -                 5 increased metabolites
# 2          1-deoxyCer                 5 increased metabolites
# 3                 BMP                 2 increased metabolites
# 4                 Cer                 1 increased metabolites
# 5        Chol. esters                 5 increased metabolites
# 6        Cholesterols                 1 increased metabolites
# 7                  CL                 3 increased metabolites
# 8                 DAG                 9 increased metabolites
# 9         Docosanoids                 3 increased metabolites
# 10          Dolichols                 4 increased metabolites
# 11             EpETrE                 1 increased metabolites
# 12               HEPE                 1 increased metabolites
# 13               HETE                 1 increased metabolites
# 14             HexCer                 5 increased metabolites
# 15                LPC                 1 increased metabolites
# 16                LPG                 2 increased metabolites
# 17         Oxysterols                 1 increased metabolites
# 18                 PA                 2 increased metabolites
# 19                 PC                 1 increased metabolites
# 20                 PE                 2 increased metabolites
# 21     Prostaglandins                 1 increased metabolites
# 22                 PS                 1 increased metabolites
# 23       Saturated FA                 1 increased metabolites
# 24                 SM                 3 increased metabolites
# 25 Sphingoid base 1-P                 1 increased metabolites
# 26       Sphingosines                 1 increased metabolites
# 27                TAG                 3 increased metabolites
# 28       Cholesterols                -2 decreased metabolites
# 29              DHCer                -1 decreased metabolites
# 30              HETrE                -1 decreased metabolites
# 31         Oxysterols                -1 decreased metabolites
# 32                 PE                -2 decreased metabolites
# 33                 PI                -2 decreased metabolites
# 34     Prostaglandins                -1 decreased metabolites
# 35                 PS                -3 decreased metabolites
# 36                 SM                -1 decreased metabolites

# %%
count_changes$plotimg
# Out:
# Warning message:
# “Use of `count_changes[[metclass]]` is discouraged.
# ℹ Use `.data[[metclass]]` instead.”
# plot without title

# %% [markdown]
# ### Enrichment class score
#
# Calculate the enrichment score of each metabolite class. Enrichment score is calculated through hypergeometric method. One can specify the no. of significant metabolites in a class while calculating the enrichment score. We advice to use the number of mtabolites in each class as 3 or more. But if someone just wants to know the enrichment score and rest of the information of all the metabolites, then they can choose the number as 1.

# %%
# pass debug = 0 below or comment some lines to suppress some print output
metenrichment = metclassenrichment(df_metclass=sig_metabolites_kegg_id,refmet_class, metclass="sub_class",enrich_stats="HG",no=1, debug = 1)
print(head(metenrichment))
#knitr::kable(head(metenrichment))
metenrichment[metenrichment$main_class %in% c("Ceramides", "Sphingomyelins"), c("Metabolite", "pval", "super_class", "main_class", "sub_class", "HG p-value")]
colnames(metenrichment)
metenrichment$super_class
metenrichment$main_class
metenrichment$sub_class
# Out:
# [1] "Name = 1-DeoxyCer 18:0;O/16:0"
# [1] "M = 5"                   "L = 80"
# [3] "N = 542"                 "k = 16"
# [5] "pp = 0.0716951736164676"
# [1] "Name = 1-DeoxyCer 18:0;O/18:0"
# [1] "M = 5"                   "L = 80"
# [3] "N = 542"                 "k = 16"
# [5] "pp = 0.0716951736164676"
# [1] "Name = 1-DeoxyCer 18:0;O/20:0"
# [1] "M = 5"                   "L = 80"
# [3] "N = 542"                 "k = 16"
# [5] "pp = 0.0716951736164676"
# [1] "Name = 1-DeoxyCer 18:0;O/22:0"
# [1] "M = 5"                   "L = 80"
# [3] "N = 542"                 "k = 16"
# [5] "pp = 0.0716951736164676"
# [1] "Name = 1-DeoxyCer 18:0;O/24:0"
# [1] "M = 5"                   "L = 80"
# [3] "N = 542"                 "k = 16"
# [5] "pp = 0.0716951736164676"
# [1] "Name = 1,2-DG 32:0"
# [1] "M = 9"                 "L = 80"                "N = 542"
# [4] "k = 47"                "pp = 0.24341920174985"
# [1] "Name = 1,2-DG 32:1"
# [1] "M = 9"                 "L = 80"                "N = 542"
# [4] "k = 47"                "pp = 0.24341920174985"
# [1] "Name = 1,2-DG 34:0"
# [1] "M = 9"                 "L = 80"                "N = 542"
# [4] "k = 47"                "pp = 0.24341920174985"
# [1] "Name = 1,2-DG 34:1"
# [1] "M = 9"                 "L = 80"                "N = 542"
# [4] "k = 47"                "pp = 0.24341920174985"
# [1] "Name = 1,2-DG 34:2"
# [1] "M = 9"                 "L = 80"                "N = 542"
# [4] "k = 47"                "pp = 0.24341920174985"
# [1] "Name = 1,2-DG 36:1"
# [1] "M = 9"                 "L = 80"                "N = 542"
# [4] "k = 47"                "pp = 0.24341920174985"
# [1] "Name = 1,2-DG 36:2"
# [1] "M = 9"                 "L = 80"                "N = 542"
# [4] "k = 47"                "pp = 0.24341920174985"
# [1] "Name = 1,2-DG 36:3"
# [1] "M = 9"                 "L = 80"                "N = 542"
# [4] "k = 47"                "pp = 0.24341920174985"
# [1] "Name = 1,2-DG 36:4"
# [1] "M = 9"                 "L = 80"                "N = 542"
# [4] "k = 47"                "pp = 0.24341920174985"
# [1] "Name = 12-HEPE"
# [1] "M = 1"                  "L = 80"                 "N = 542"
# [4] "k = 4"                  "pp = 0.473092547138833"
# [1] "Name = 12-HETE"
# [1] "M = 1"                  "L = 80"                 "N = 542"
# [4] "k = 14"                 "pp = 0.896213981623375"
# [1] "Name = 14-HDoHE"
# [1] "M = 3"                   "L = 80"
# [3] "N = 542"                 "k = 8"
# [5] "pp = 0.0997410855510741"
# [1] "Name = 15-HETrE"
# [1] "M = 1"                  "L = 80"                 "N = 542"
# [4] "k = 8"                  "pp = 0.723804164591792"
# [1] "Name = 16-HDoHE"
# [1] "M = 3"                   "L = 80"
# [3] "N = 542"                 "k = 8"
# [5] "pp = 0.0997410855510741"
# [1] "Name = 22R-Hydroxycholesterol"
# [1] "M = 2"                 "L = 80"                "N = 542"
# [4] "k = 11"                "pp = 0.50031615679179"
# [1] "Name = 25-Hydroxycholesterol"
# [1] "M = 2"                 "L = 80"                "N = 542"
# [4] "k = 11"                "pp = 0.50031615679179"
# [1] "Name = 4-HDoHE"
# [1] "M = 3"                   "L = 80"
# [3] "N = 542"                 "k = 8"
# [5] "pp = 0.0997410855510741"
# [1] "Name = 6-Keto-PGF1alpha"
# [1] "M = 2"                  "L = 80"                 "N = 542"
# [4] "k = 14"                 "pp = 0.637326808835359"
# [1] "Name = 8,9-EpETrE"
# [1] "M = 1"                  "L = 80"                 "N = 542"
# [4] "k = 4"                  "pp = 0.473092547138833"
# [1] "Name = BMP 40:7"
# [1] "M = 2"                  "L = 80"                 "N = 542"
# [4] "k = 6"                  "pp = 0.217322500171134"
# [1] "Name = BMP 40:8"
# [1] "M = 2"                  "L = 80"                 "N = 542"
# [4] "k = 6"                  "pp = 0.217322500171134"
# [1] "Name = CE 18:2"
# [1] "M = 5"                 "L = 80"                "N = 542"
# [4] "k = 22"                "pp = 0.21258925419864"
# [1] "Name = CE 18:3"
# [1] "M = 5"                 "L = 80"                "N = 542"
# [4] "k = 22"                "pp = 0.21258925419864"
# [1] "Name = CE 20:3"
# [1] "M = 5"                 "L = 80"                "N = 542"
# [4] "k = 22"                "pp = 0.21258925419864"
# [1] "Name = CE 20:4"
# [1] "M = 5"                 "L = 80"                "N = 542"
# [4] "k = 22"                "pp = 0.21258925419864"
# [1] "Name = CE 22:6"
# [1] "M = 5"                 "L = 80"                "N = 542"
# [4] "k = 22"                "pp = 0.21258925419864"
# [1] "Name = Cer 18:0;O2/24:1"
# [1] "M = 1"                  "L = 80"                 "N = 542"
# [4] "k = 10"                 "pp = 0.800426573133057"
# [1] "Name = Cer 18:1;O2/18:0"
# [1] "M = 5"                  "L = 80"                 "N = 542"
# [4] "k = 13"                 "pp = 0.030322979264103"
# [1] "Name = Cer 18:1;O2/18:1"
# [1] "M = 1"                  "L = 80"                 "N = 542"
# [4] "k = 3"                  "pp = 0.381256825507257"
# [1] "Name = Cer 18:1;O2/20:0"
# [1] "M = 5"                  "L = 80"                 "N = 542"
# [4] "k = 13"                 "pp = 0.030322979264103"
# [1] "Name = Cer 18:1;O2/22:0"
# [1] "M = 5"                  "L = 80"                 "N = 542"
# [4] "k = 13"                 "pp = 0.030322979264103"
# [1] "Name = Cer 18:1;O2/24:0"
# [1] "M = 5"                  "L = 80"                 "N = 542"
# [4] "k = 13"                 "pp = 0.030322979264103"
# [1] "Name = Cer 18:1;O2/26:0"
# [1] "M = 5"                  "L = 80"                 "N = 542"
# [4] "k = 13"                 "pp = 0.030322979264103"
# [1] "Name = CL 72:8"
# [1] "M = 3"                   "L = 80"
# [3] "N = 542"                 "k = 4"
# [5] "pp = 0.0111189387573834"
# [1] "Name = CL 74:7"
# [1] "M = 3"                   "L = 80"
# [3] "N = 542"                 "k = 4"
# [5] "pp = 0.0111189387573834"
# [1] "Name = CL 74:8"
# [1] "M = 3"                   "L = 80"
# [3] "N = 542"                 "k = 4"
# [5] "pp = 0.0111189387573834"
# [1] "Name = Desmosterol"
# [1] "M = 3"                 "L = 80"                "N = 542"
# [4] "k = 15"                "pp = 0.38554922696671"
# [1] "Name = Dihydrocholesterol"
# [1] "M = 3"                 "L = 80"                "N = 542"
# [4] "k = 15"                "pp = 0.38554922696671"
# [1] "Name = Dolichol-17"
# [1] "M = 4"                     "L = 80"
# [3] "N = 542"                   "k = 4"
# [5] "pp = 0.000444757550295334"
# [1] "Name = Dolichol-18"
# [1] "M = 4"                     "L = 80"
# [3] "N = 542"                   "k = 4"
# [5] "pp = 0.000444757550295334"
# [1] "Name = Dolichol-19"
# [1] "M = 4"                     "L = 80"
# [3] "N = 542"                   "k = 4"
# [5] "pp = 0.000444757550295334"
# [1] "Name = Dolichol-20"
# [1] "M = 4"                     "L = 80"
# [3] "N = 542"                   "k = 4"
# [5] "pp = 0.000444757550295334"
# [1] "Name = GalCer 18:1;O2/24:0"
# [1] "M = 5"                  "L = 80"                 "N = 542"
# [4] "k = 40"                 "pp = 0.732755384315239"
# [1] "Name = GlcCer 18:1;O2/22:0"
# [1] "M = 5"                  "L = 80"                 "N = 542"
# [4] "k = 40"                 "pp = 0.732755384315239"
# [1] "Name = GlcCer 18:1;O2/24:0"
# [1] "M = 5"                  "L = 80"                 "N = 542"
# [4] "k = 40"                 "pp = 0.732755384315239"
# [1] "Name = HexCer 18:1;O2/22:0"
# [1] "M = 5"                  "L = 80"                 "N = 542"
# [4] "k = 40"                 "pp = 0.732755384315239"
# [1] "Name = HexCer 18:1;O2/24:0"
# [1] "M = 5"                  "L = 80"                 "N = 542"
# [4] "k = 40"                 "pp = 0.732755384315239"
# [1] "Name = Lanosterol"
# [1] "M = 3"                 "L = 80"                "N = 542"
# [4] "k = 15"                "pp = 0.38554922696671"
# [1] "Name = Lignoceric acid"
# [1] "M = 1"                  "L = 80"                 "N = 542"
# [4] "k = 10"                 "pp = 0.800426573133057"
# [1] "Name = LPC 18:0"
# [1] "M = 1"                  "L = 80"                 "N = 542"
# [4] "k = 5"                  "pp = 0.551443097750159"
# [1] "Name = LPG 18:1"
# [1] "M = 2"                  "L = 80"                 "N = 542"
# [4] "k = 2"                  "pp = 0.021553635129697"
# [1] "Name = LPG 18:2"
# [1] "M = 2"                  "L = 80"                 "N = 542"
# [4] "k = 2"                  "pp = 0.021553635129697"
# [1] "Name = PA 40:5"
# [1] "M = 2"                  "L = 80"                 "N = 542"
# [4] "k = 15"                 "pp = 0.676061821430535"
# [1] "Name = PA 40:6"
# [1] "M = 2"                  "L = 80"                 "N = 542"
# [4] "k = 15"                 "pp = 0.676061821430535"
# [1] "Name = PC 36:4"
# [1] "M = 1"                  "L = 80"                 "N = 542"
# [4] "k = 21"                 "pp = 0.967376153918654"
# [1] "Name = PE 32:1"
# [1] "M = 4"                  "L = 80"                 "N = 542"
# [4] "k = 16"                 "pp = 0.199224261257463"
# [1] "Name = PE 36:3"
# [1] "M = 4"                  "L = 80"                 "N = 542"
# [4] "k = 16"                 "pp = 0.199224261257463"
# [1] "Name = PE 38:6"
# [1] "M = 4"                  "L = 80"                 "N = 542"
# [4] "k = 16"                 "pp = 0.199224261257463"
# [1] "Name = PE 40:6"
# [1] "M = 4"                  "L = 80"                 "N = 542"
# [4] "k = 16"                 "pp = 0.199224261257463"
# [1] "Name = PGE2"
# [1] "M = 2"                  "L = 80"                 "N = 542"
# [4] "k = 14"                 "pp = 0.637326808835359"
# [1] "Name = PI 36:3"
# [1] "M = 2"                  "L = 80"                 "N = 542"
# [4] "k = 14"                 "pp = 0.637326808835359"
# [1] "Name = PI 38:5"
# [1] "M = 2"                  "L = 80"                 "N = 542"
# [4] "k = 14"                 "pp = 0.637326808835359"
# [1] "Name = PS 34:1"
# [1] "M = 4"                  "L = 80"                 "N = 542"
# [4] "k = 13"                 "pp = 0.110183279315913"
# [1] "Name = PS 36:2"
# [1] "M = 4"                  "L = 80"                 "N = 542"
# [4] "k = 13"                 "pp = 0.110183279315913"
# [1] "Name = PS 36:3"
# [1] "M = 4"                  "L = 80"                 "N = 542"
# [4] "k = 13"                 "pp = 0.110183279315913"
# [1] "Name = PS 40:6"
# [1] "M = 4"                  "L = 80"                 "N = 542"
# [4] "k = 13"                 "pp = 0.110183279315913"
# [1] "Name = SM 18:0;O2/16:0"
# [1] "M = 4"                  "L = 80"                 "N = 542"
# [4] "k = 17"                 "pp = 0.232794363298088"
# [1] "Name = SM 18:1;O2/18:1"
# [1] "M = 4"                  "L = 80"                 "N = 542"
# [4] "k = 17"                 "pp = 0.232794363298088"
# [1] "Name = SM 18:1;O2/20:0"
# [1] "M = 4"                  "L = 80"                 "N = 542"
# [4] "k = 17"                 "pp = 0.232794363298088"
# [1] "Name = SM 18:1;O2/22:0"
# [1] "M = 4"                  "L = 80"                 "N = 542"
# [4] "k = 17"                 "pp = 0.232794363298088"
# [1] "Name = Sphingosine"
# [1] "M = 1"                 "L = 80"                "N = 542"
# [4] "k = 1"                 "pp = 0.14760147601476"
# [1] "Name = Sphingosine 1-phosphate"
# [1] "M = 1"                  "L = 80"                 "N = 542"
# [4] "k = 2"                  "pp = 0.273649316899823"
# [1] "Name = TG 51:1"
# [1] "M = 3"                  "L = 80"                 "N = 542"
# [4] "k = 120"                "pp = 0.999999872016166"
# [1] "Name = TG 52:1"
# [1] "M = 3"                  "L = 80"                 "N = 542"
# [4] "k = 120"                "pp = 0.999999872016166"
# [1] "Name = TG 52:3"
# [1] "M = 3"                  "L = 80"                 "N = 542"
# [4] "k = 120"                "pp = 0.999999872016166"
#              refmet_name Exact mass KEGG ID       Metabolite Cirrhosis_mean
# 1 1-DeoxyCer 18:0;O/16:0   523.5328         C16DH 1-deoxyCer     0.05623685
# 2 1-DeoxyCer 18:0;O/18:0   551.5641         C18DH 1-deoxyCer      0.0906803
# 3 1-DeoxyCer 18:0;O/20:0   579.5954         C20DH 1-deoxyCer      0.0723488
# 4 1-DeoxyCer 18:0;O/22:0   607.6267         C22DH 1-deoxyCer      0.1513816
# 5 1-DeoxyCer 18:0;O/24:0   635.6580         C24DH 1-deoxyCer      0.1177141
# 6            1,2-DG 32:0   568.5067  C00641     1,2-DG(32:0)       210.0625
#   Normal_mean Fold_change log2Fold_change   t_value         pval        padj
# 1  0.12178748    2.165617        1.114778 -3.028001 0.0044113841 0.025170838
# 2   0.2566956    2.830776        1.501197 -3.826879 0.0005219699 0.005671347
# 3   0.1756429    2.427724        1.279604 -3.268230 0.0023663363 0.015081843
# 4   0.4227716    2.792754        1.481689 -3.604410 0.0009458421 0.007645557
# 5   0.3056195    2.596286        1.376449 -2.746084 0.0091800137 0.046866386
# 6    479.9210    2.284658        1.191978 -2.410346 0.0200253888 0.106653539
#   metabolite_id   super_class       main_class  sub_class   formula HG p-value
# 1      ME231305 Sphingolipids        Ceramides 1-deoxyCer C34H69NO2 0.07169517
# 2      ME231306 Sphingolipids        Ceramides 1-deoxyCer C36H73NO2 0.07169517
# 3      ME231307 Sphingolipids        Ceramides 1-deoxyCer C38H77NO2 0.07169517
# 4      ME231308 Sphingolipids        Ceramides 1-deoxyCer C40H81NO2 0.07169517
# 5      ME231310 Sphingolipids        Ceramides 1-deoxyCer C42H85NO2 0.07169517
# 6      ME231196 Glycerolipids Diradylglycerols        DAG  C35H68O5 0.24341920
#    Metabolite       pval         super_class   main_class sub_class  HG p-value
# 1  C16DH 1-deoxyCer 0.0044113841 Sphingolipids Ceramides  1-deoxyCer 0.07169517
# 2  C18DH 1-deoxyCer 0.0005219699 Sphingolipids Ceramides  1-deoxyCer 0.07169517
# 3  C20DH 1-deoxyCer 0.0023663363 Sphingolipids Ceramides  1-deoxyCer 0.07169517
# 4  C22DH 1-deoxyCer 0.0009458421 Sphingolipids Ceramides  1-deoxyCer 0.07169517
# 5  C24DH 1-deoxyCer 0.0091800137 Sphingolipids Ceramides  1-deoxyCer 0.07169517
# 32 C24:1DH Cer      0.0472713816 Sphingolipids Ceramides  DHCer      0.80042657
# 34 C18:1 Cer        0.0052610880 Sphingolipids Ceramides  Cer        0.38125683
#  [1] "refmet_name"     "Exact mass"      "KEGG ID"         "Metabolite"
#  [5] "Cirrhosis_mean"  "Normal_mean"     "Fold_change"     "log2Fold_change"
#  [9] "t_value"         "pval"            "padj"            "metabolite_id"
# [13] "super_class"     "main_class"      "sub_class"       "formula"
# [17] "HG p-value"
#  [1] "Sphingolipids"        "Sphingolipids"        "Sphingolipids"
#  [4] "Sphingolipids"        "Sphingolipids"        "Glycerolipids"
#  [7] "Glycerolipids"        "Glycerolipids"        "Glycerolipids"
# [10] "Glycerolipids"        "Glycerolipids"        "Glycerolipids"
# [13] "Glycerolipids"        "Glycerolipids"        "Fatty Acyls"
# [16] "Fatty Acyls"          "Fatty Acyls"          "Fatty Acyls"
# [19] "Fatty Acyls"          "Sterol Lipids"        "Sterol Lipids"
# [22] "Fatty Acyls"          "Fatty Acyls"          "Fatty Acyls"
# [25] "Glycerophospholipids" "Glycerophospholipids" "Sterol Lipids"
# [28] "Sterol Lipids"        "Sterol Lipids"        "Sterol Lipids"
# [31] "Sterol Lipids"        "Sphingolipids"        "-"
# [34] "Sphingolipids"        "-"                    "-"
# [37] "-"                    "-"                    "Glycerophospholipids"
# [40] "Glycerophospholipids" "Glycerophospholipids" "Sterol Lipids"
# [43] "Sterol Lipids"        "Prenol Lipids"        "Prenol Lipids"
# [46] "Prenol Lipids"        "Prenol Lipids"        "Sphingolipids"
# [49] "Sphingolipids"        "Sphingolipids"        "Sphingolipids"
# [52] "Sphingolipids"        "Sterol Lipids"        "Fatty Acyls"
# [55] "Glycerophospholipids" "Glycerophospholipids" "Glycerophospholipids"
# [58] "Glycerophospholipids" "Glycerophospholipids" "Glycerophospholipids"
# [61] "Glycerophospholipids" "Glycerophospholipids" "Glycerophospholipids"
# [64] "Glycerophospholipids" "Fatty Acyls"          "Glycerophospholipids"
# [67] "Glycerophospholipids" "Glycerophospholipids" "Glycerophospholipids"
# [70] "Glycerophospholipids" "Glycerophospholipids" "Sphingolipids"
# [73] "Sphingolipids"        "Sphingolipids"        "Sphingolipids"
# [76] "Sphingolipids"        "Sphingolipids"        "Glycerolipids"
# [79] "Glycerolipids"        "Glycerolipids"
#  [1] "Ceramides"                   "Ceramides"
#  [3] "Ceramides"                   "Ceramides"
#  [5] "Ceramides"                   "Diradylglycerols"
#  [7] "Diradylglycerols"            "Diradylglycerols"
#  [9] "Diradylglycerols"            "Diradylglycerols"
# [11] "Diradylglycerols"            "Diradylglycerols"
# [13] "Diradylglycerols"            "Diradylglycerols"
# [15] "Eicosanoids"                 "Eicosanoids"
# [17] "Docosanoids"                 "Eicosanoids"
# [19] "Docosanoids"                 "Sterols"
# [21] "Sterols"                     "Docosanoids"
# [23] "Eicosanoids"                 "Eicosanoids"
# [25] "Glycerophosphoglycerols"     "Glycerophosphoglycerols"
# [27] "Sterol esters"               "Sterol esters"
# [29] "Sterol esters"               "Sterol esters"
# [31] "Sterol esters"               "Ceramides"
# [33] "-"                           "Ceramides"
# [35] "-"                           "-"
# [37] "-"                           "-"
# [39] "Cardiolipins"                "Cardiolipins"
# [41] "Cardiolipins"                "Sterols"
# [43] "Sterols"                     "Polyprenols"
# [45] "Polyprenols"                 "Polyprenols"
# [47] "Polyprenols"                 "Glycosphingolipids"
# [49] "Glycosphingolipids"          "Glycosphingolipids"
# [51] "Glycosphingolipids"          "Glycosphingolipids"
# [53] "Sterols"                     "Fatty acids"
# [55] "Glycerophosphocholines"      "Glycerophosphoglycerols"
# [57] "Glycerophosphoglycerols"     "Glycerophosphates"
# [59] "Glycerophosphates"           "Glycerophosphocholines"
# [61] "Glycerophosphoethanolamines" "Glycerophosphoethanolamines"
# [63] "Glycerophosphoethanolamines" "Glycerophosphoethanolamines"
# [65] "Eicosanoids"                 "Glycerophosphoinositols"
# [67] "Glycerophosphoinositols"     "Glycerophosphoserines"
# [69] "Glycerophosphoserines"       "Glycerophosphoserines"
# [71] "Glycerophosphoserines"       "Phosphosphingolipids"
# [73] "Phosphosphingolipids"        "Phosphosphingolipids"
# [75] "Phosphosphingolipids"        "Sphingoid bases"
# [77] "Sphingoid bases"             "Triradylglycerols"
# [79] "Triradylglycerols"           "Triradylglycerols"
#  [1] "1-deoxyCer"         "1-deoxyCer"         "1-deoxyCer"
#  [4] "1-deoxyCer"         "1-deoxyCer"         "DAG"
#  [7] "DAG"                "DAG"                "DAG"
# [10] "DAG"                "DAG"                "DAG"
# [13] "DAG"                "DAG"                "HEPE"
# [16] "HETE"               "Docosanoids"        "HETrE"
# [19] "Docosanoids"        "Oxysterols"         "Oxysterols"
# [22] "Docosanoids"        "Prostaglandins"     "EpETrE"
# [25] "BMP"                "BMP"                "Chol. esters"
# [28] "Chol. esters"       "Chol. esters"       "Chol. esters"
# [31] "Chol. esters"       "DHCer"              "-"
# [34] "Cer"                "-"                  "-"
# [37] "-"                  "-"                  "CL"
# [40] "CL"                 "CL"                 "Cholesterols"
# [43] "Cholesterols"       "Dolichols"          "Dolichols"
# [46] "Dolichols"          "Dolichols"          "HexCer"
# [49] "HexCer"             "HexCer"             "HexCer"
# [52] "HexCer"             "Cholesterols"       "Saturated FA"
# [55] "LPC"                "LPG"                "LPG"
# [58] "PA"                 "PA"                 "PC"
# [61] "PE"                 "PE"                 "PE"
# [64] "PE"                 "Prostaglandins"     "PI"
# [67] "PI"                 "PS"                 "PS"
# [70] "PS"                 "PS"                 "SM"
# [73] "SM"                 "SM"                 "SM"
# [76] "Sphingosines"       "Sphingoid base 1-P" "TAG"
# [79] "TAG"                "TAG"

# %% [markdown]
# #### Plot the enrichment score via function plot_met_enrichment

# %%
plot_met_enrichment(metenrichment, "sub_class","HG", no=3)
# Out:
# Warning message:
# “Use of `metclass_stats[[metclass]]` is discouraged.
# ℹ Use `.data[[metclass]]` instead.”
# Warning message:
# “Use of `metclass_stats[[enrich_stats]]` is discouraged.
# ℹ Use `.data[[enrich_stats]]` instead.”
# Warning message:
# “Use of `metclass_stats[[enrich_stats]]` is discouraged.
# ℹ Use `.data[[enrich_stats]]` instead.”
# plot without title

# %% [markdown]
# ### Check the pathways with reactions of all the significant metabolites

# %%
met_path = met_pathways(df_metenrichment = metenrichment, 'hsa')
head(met_path)
# Out:
#   rxn    refmet_name Exact mass KEGG ID Metabolite  Cirrhosis_mean Normal_mean
# 1 R01003 Dolichol-20 1381.2782  C00381  Dolichol-20 18.54100       60.64903
# 2 R01003 Dolichol-20 1381.2782  C00381  Dolichol-20 18.54100       60.64903
# 3 R01018 Dolichol-20 1381.2782  C00381  Dolichol-20 18.54100       60.64903
# 4 R01018 Dolichol-20 1381.2782  C00381  Dolichol-20 18.54100       60.64903
# 5 R01310 PA 40:5     750.5200   C00416  PA(40:5)    4.228153       7.135089
# 6 R01310 PA 40:5     750.5200   C00416  PA(40:5)    4.228153       7.135089
#   Fold_change log2Fold_change t_value   ⋯ metabolite_id super_class
# 1 3.271077    1.7097655       -7.141005 ⋯ ME231044      Prenol Lipids
# 2 3.271077    1.7097655       -7.141005 ⋯ ME231044      Prenol Lipids
# 3 3.271077    1.7097655       -7.141005 ⋯ ME231044      Prenol Lipids
# 4 3.271077    1.7097655       -7.141005 ⋯ ME231044      Prenol Lipids
# 5 1.687519    0.7549038       -2.727375 ⋯ ME231346      Glycerophospholipids
# 6 1.687519    0.7549038       -2.727375 ⋯ ME231346      Glycerophospholipids
#   main_class        sub_class formula   HG p-value   Rxn_name
# 1 Polyprenols       Dolichols C100H164O 0.0004447576 dolichyl....
# 2 Polyprenols       Dolichols C100H164O 0.0004447576 dolichyl....
# 3 Polyprenols       Dolichols C100H164O 0.0004447576 CTP:doli....
# 4 Polyprenols       Dolichols C100H164O 0.0004447576 CTP:doli....
# 5 Glycerophosphates PA        C43H75O8P 0.6760618214 phosphat....
# 6 Glycerophosphates PA        C43H75O8P 0.6760618214 phosphat....
#   PATHWAY                        pathway_id sps_path_id
# 1 N-Glycan biosynthesis          rn00510    hsa00510
# 2 Metabolic pathways             rn01100    hsa01100
# 3 N-Glycan biosynthesis          rn00510    hsa00510
# 4 Metabolic pathways             rn01100    hsa01100
# 5 Glycerophospholipid metabolism rn00564    hsa00564
# 6 Metabolic pathways             rn01100    hsa01100

# %% [markdown]
# Find metabolites for which no pathways were registered in Kegg and/or no kegg id was found

# %%
setdiff(metenrichment$Metabolite,unique(met_path$Metabolite))
# Out:
#  [1] "C16DH 1-deoxyCer" "C18DH 1-deoxyCer" "C20DH 1-deoxyCer" "C22DH 1-deoxyCer"
#  [5] "C24DH 1-deoxyCer" "12-HEPE"          "12-HETE"          "14 HDoHE"
#  [9] "15-HETrE"         "16 HDoHE"         "4 HDoHE"          "BMP(40:7)"
# [13] "BMP(40:8)"        "Cholestanol"      "Dolichol-17"      "Dolichol-18"
# [17] "Dolichol-19"

# %% [markdown]
# ### Get pathway enrichment sore.
#
# Once we have the pathway information, we can calculate enrichment score of pathways. Again, here I have used hypergeometric (HG) score. For hypergeometric score, we need to know the total number of kegg compounds that are linked to kegg pathways.
#
# N = total no. of compounds/metabolites linked to all kegg pathways (kegg_comp_path = TRUE) or the total number of metabolites detected in a study (kegg_comp_path = FALSE).
#
# In the former case, this step might take long time, so I advice to run the script comp_linkedto_pathways() just the first time or after 6 months or so if desired to run the pipeline again. Save the result from comp_linkedto_pathways() and load it. Loading from saved file would save time for another analysis with another study. However the package takes care of loading. Save the data in the data folder.
#
# L = No. of significant metabolites detected in a study
#
# M = No. of significant metabolites detected in a metabolite class or pathway
#
# k = Total no. of metabolites detected in a metabolite class/pathway
#
# p-value = phyper(M-1, L, N-L, k, lower.tail=FALSE) # as in the actual R code # originally, it was wriiten as: phyper(M, L, N-L, K)
#
# This function also utilizes korg dataset from pathview package.

# %%
load('../data/ls_path.RData')
load('../data/korg.RData')
kegg_es = path_enrichmentscore(met_path,sig_metabolites_kegg_id=sig_metabolites_kegg_id,ls_path=ls_path,refmet_class=refmet_class,sps='hsa',padj='fdr', kegg_comp_path=TRUE, debug = 1)
# Out:
#     M  L    N   k           pp
# 1   2 80 6148  44 1.115172e-01
# 2   4 80 6148  79 1.911638e-02
# 3   1 80 6148  74 6.228354e-01
# 4  20 80 6148  38 4.227123e-29
# 5  28 80 6148  56 4.715065e-40
# 6   4 80 6148  50 3.888173e-03
# 7  18 80 6148  45 1.958128e-23
# 8  12 80 6148  50 8.210597e-13
# 9   1 80 6148  29 3.166229e-01
# 10  1 80 6148  40 4.087938e-01
# 11  9 80 6148  57 3.670761e-08
# 12  1 80 6148  47 4.609381e-01
# 13  1 80 6148  25 2.797012e-01
# 14 26 80 6148  36 2.373567e-43
# 15 16 80 6148  57 5.327837e-18
# 16  1 80 6148 100 7.330004e-01
# [1] "freqtable = "
#                                              Pathway name
# 1                         alpha-Linolenic acid metabolism
# 2                             Arachidonic acid metabolism
# 3                 Biosynthesis of unsaturated fatty acids
# 4                                 Glycerolipid metabolism
# 5                          Glycerophospholipid metabolism
# 6                Glycine, serine and threonine metabolism
# 7  Glycosylphosphatidylinositol (GPI)-anchor biosynthesis
# 8                           Inositol phosphate metabolism
# 9                                Linoleic acid metabolism
# 10                                  N-Glycan biosynthesis
# 11                 Phosphonate and phosphinate metabolism
# 12                         Primary bile acid biosynthesis
# 13                                     Retinol metabolism
# 14                                Sphingolipid metabolism
# 15                                   Steroid biosynthesis
# 16                           Steroid hormone biosynthesis
#    No. of sig mets in pathway Total_no._of_comps_in_pathway
# 1                           2                            44
# 2                           4                            79
# 3                           1                            74
# 4                          20                            38
# 5                          28                            56
# 6                           4                            50
# 7                          18                            45
# 8                          12                            50
# 9                           1                            29
# 10                          1                            40
# 11                          9                            57
# 12                          1                            47
# 13                          1                            25
# 14                         26                            36
# 15                         16                            57
# 16                          1                           100
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             id
# 1                                                                                                                                                                                                                                                                                                                                                                                                          C00157;C01226;C04672;C04780;C04785;C06427;C08491;C08492;C11512;C16300;C16308;C16309;C16310;C16311;C16316;C16317;C16318;C16319;C16320;C16321;C16322;C16323;C16324;C16325;C16326;C16327;C16328;C16330;C16331;C16332;C16334;C16335;C16336;C16338;C16339;C16341;C16342;C16343;C16344;C16345;C16346;C19757;C21923;C21924
# 2                                                                                                                                                     C00157;C00219;C00427;C00584;C00639;C00696;C00909;C01312;C02165;C02166;C02198;C03577;C04577;C04671;C04707;C04742;C04758;C04805;C04822;C04835;C04853;C05356;C05949;C05950;C05951;C05952;C05953;C05954;C05955;C05956;C05957;C05958;C05959;C05960;C05961;C05962;C05963;C05964;C05965;C05966;C06314;C06315;C06462;C13809;C14717;C14732;C14748;C14749;C14768;C14769;C14770;C14771;C14772;C14773;C14774;C14775;C14776;C14777;C14778;C14779;C14780;C14781;C14782;C14794;C14795;C14807;C14808;C14809;C14810;C14811;C14812;C14813;C14814;C14815;C14820;C14821;C14822;C14823;C14824
# 3                                                                                                                                                                                        C00154;C00219;C00249;C00412;C00510;C00712;C01203;C01530;C01595;C02041;C02050;C02249;C03035;C03242;C03595;C04088;C05764;C06425;C06426;C06427;C06428;C06429;C08281;C08316;C08320;C08323;C16160;C16161;C16162;C16163;C16164;C16165;C16166;C16167;C16168;C16169;C16170;C16171;C16172;C16173;C16179;C16180;C16513;C16522;C16525;C16526;C16527;C16528;C16529;C16530;C16531;C16532;C16533;C16645;C17279;C21072;C21932;C21934;C21935;C21937;C21939;C21941;C21943;C21945;C21947;C21949;C21951;C21953;C21959;C21961;C21963;C21965;C21967;C21981
# 4                                                                                                                                                                                                                                                                                                                                                                                                                                                    C00029;C00040;C00093;C00103;C00111;C00116;C00162;C00173;C00184;C00197;C00258;C00416;C00422;C00577;C00631;C00641;C00681;C00969;C01885;C02133;C02457;C03692;C04046;C04315;C04872;C05401;C06037;C06038;C06040;C06041;C06042;C06364;C06365;C11521;C13508;C20897;C20898;C20991
# 5                                                                                                                                                                                                                                                                                                                      C00040;C00065;C00084;C00093;C00111;C00114;C00157;C00189;C00269;C00307;C00344;C00346;C00350;C00416;C00513;C00570;C00588;C00623;C00641;C00670;C00681;C01194;C01210;C01233;C01241;C01996;C02737;C03372;C03819;C03872;C03892;C03974;C04230;C04233;C04308;C04438;C04590;C04638;C05973;C05974;C05976;C05980;C06771;C06772;C13482;C18059;C18125;C18126;C18129;C18168;C18169;C20466;C20518;C22340;C22341;C22342
# 6                                                                                                                                                                                                                                                                                                                                                                C00011;C00014;C00022;C00037;C00048;C00049;C00065;C00078;C00097;C00101;C00109;C00114;C00143;C00168;C00188;C00197;C00213;C00258;C00263;C00300;C00430;C00441;C00546;C00576;C00581;C00631;C00719;C00740;C00986;C01005;C01026;C01102;C01242;C01888;C02051;C02291;C02737;C02972;C03082;C03194;C03232;C03283;C03508;C05519;C06231;C06442;C16432;C19929;C23135;C23136
# 7                                                                                                                                                                                                                                                                                                                                                                                                   C00154;C00249;C00346;C00350;C00412;C01194;C21932;C22963;C22964;C22965;C22966;C22967;C22968;C22970;C22971;C22972;G00140;G00141;G00142;G00143;G00144;G00145;G00146;G00148;G00149;G00151;G10610;G10617;G12396;G13044;G13046;G13128;G13150;G13151;G13152;G13350;G13351;G13352;G13353;G13354;G13355;G13356;G13357;G13358;G13359
# 8                                                                                                                                                                                                                                                                                                                                                                C00024;C00092;C00111;C00118;C00137;C00191;C00222;C00558;C00641;C00691;C01177;C01194;C01204;C01220;C01243;C01245;C01272;C01277;C01284;C03546;C03659;C03660;C04006;C04062;C04063;C04287;C04477;C04520;C04549;C04563;C04579;C04637;C05981;C06153;C06892;C06893;C11174;C11526;C11554;C11555;C11556;C11557;C16737;C19794;C19799;C19891;C20251;C20690;C21643;C21644
# 9                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   C00157;C00219;C01595;C03242;C04056;C04717;C06426;C07289;C07338;C07354;C14762;C14765;C14766;C14767;C14825;C14826;C14827;C14828;C14829;C14831;C14832;C14833;C14834;C14835;C14836;C14837;C19937;C20186;C22918
# 10                                                                                                                                                                                                                                                                                                                                                                                                                                     C00096;C00110;C00381;C00621;C01246;C03021;C03862;C06081;C22974;C22975;G00001;G00002;G00003;G00004;G00005;G00006;G00007;G00008;G00009;G00010;G00011;G00012;G00013;G00014;G00015;G00016;G00017;G00018;G00019;G00020;G00021;G00022;G00171;G10526;G10595;G10596;G10597;G10598;G10599;G10694
# 11                                                                                                                                                                                                                                                                                                              C00022;C00033;C00037;C00058;C00074;C00084;C00117;C01151;C01438;C02798;C03167;C03557;C04650;C05672;C05673;C05674;C05675;C05676;C05677;C05678;C05679;C05680;C05681;C05682;C05683;C06367;C06368;C06451;C06455;C06456;C06457;C06459;C17940;C17941;C17942;C17943;C17944;C17945;C17947;C17948;C17949;C17950;C17951;C17952;C17960;C17961;C17962;C20396;C20422;C20423;C20440;C20986;C21372;C21403;C21404;C21613;C22696
# 12                                                                                                                                                                                                                                                                                                                                                                                    C00037;C00187;C00245;C00695;C01301;C01794;C01921;C02528;C03594;C04554;C04722;C05122;C05337;C05444;C05445;C05446;C05447;C05448;C05449;C05451;C05452;C05453;C05454;C05455;C05460;C05465;C05466;C05467;C05468;C06341;C13550;C15518;C15519;C15520;C15610;C15613;C15614;C17331;C17332;C17333;C17335;C17336;C17337;C17339;C17343;C17345;C17346
# 13                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              C00376;C00473;C00777;C00778;C00899;C02075;C02094;C02110;C02588;C03455;C05914;C05915;C05916;C05917;C11061;C15492;C15493;C16677;C16678;C16679;C16680;C16681;C16682;C16683;C21797
# 14                                                                                                                                                                                                                                                                                                                                                                                                                                                                 C00065;C00154;C00195;C00319;C00346;C00550;C00836;C01120;C01190;C01290;C01747;C02686;C02934;C02960;C03108;C03272;C03405;C03640;C04730;C04737;C04884;C04911;C05681;C06062;C06124;C06125;C06126;C06127;C06128;C06135;C06136;C12126;C12144;C12145;C22467;C23072
# 15                                                                                                                                                                                                                                                                                                              C00187;C00448;C00751;C01054;C01164;C01189;C01561;C01673;C01694;C01724;C01753;C01789;C01802;C01902;C01943;C02141;C02530;C03428;C03845;C04525;C05103;C05107;C05108;C05109;C05437;C05439;C05440;C05441;C05442;C05443;C07712;C08813;C08821;C08830;C11455;C11508;C11522;C11523;C15776;C15777;C15780;C15781;C15782;C15783;C15808;C15816;C15915;C18231;C21106;C22112;C22116;C22119;C22120;C22121;C22122;C22123;C22136
# 16 C00187;C00280;C00410;C00468;C00523;C00535;C00674;C00735;C00762;C00951;C01124;C01176;C01227;C01780;C01953;C02140;C02373;C02537;C02538;C03205;C03681;C03772;C03852;C03917;C03935;C04042;C04295;C04373;C04518;C04555;C04676;C05138;C05139;C05140;C05141;C05284;C05285;C05290;C05291;C05293;C05294;C05295;C05296;C05297;C05298;C05299;C05300;C05301;C05302;C05469;C05470;C05471;C05472;C05473;C05474;C05475;C05476;C05477;C05478;C05479;C05480;C05481;C05482;C05483;C05484;C05485;C05487;C05488;C05489;C05490;C05497;C05498;C05499;C05500;C05501;C05502;C05503;C05504;C08357;C08358;C08359;C11131;C11132;C11133;C11134;C11135;C11136;C13712;C13713;C18038;C18039;C18040;C18041;C18042;C18043;C18044;C18045;C18075;C22831;C22832
#    pathway_HG_p_value      Padjust
# 1        1.115172e-01 1.784275e-01
# 2        1.911638e-02 3.398467e-02
# 3        6.228354e-01 6.643577e-01
# 4        4.227123e-29 2.254466e-28
# 5        4.715065e-40 3.772052e-39
# 6        3.888173e-03 7.776346e-03
# 7        1.958128e-23 7.832511e-23
# 8        8.210597e-13 2.189493e-12
# 9        3.166229e-01 4.221639e-01
# 10       4.087938e-01 5.031309e-01
# 11       3.670761e-08 8.390310e-08
# 12       4.609381e-01 5.267864e-01
# 13       2.797012e-01 4.068381e-01
# 14       2.373567e-43 3.797707e-42
# 15       5.327837e-18 1.704908e-17
# 16       7.330004e-01 7.330004e-01

# %%
head(kegg_es)
# Out:
#   Pathway name                             No. of sig mets in pathway
# 1 alpha-Linolenic acid metabolism           2
# 2 Arachidonic acid metabolism               4
# 3 Biosynthesis of unsaturated fatty acids   1
# 4 Glycerolipid metabolism                  20
# 5 Glycerophospholipid metabolism           28
# 6 Glycine, serine and threonine metabolism  4
#   Total_no._of_comps_in_pathway
# 1 44
# 2 79
# 3 74
# 4 38
# 5 56
# 6 50
#   id
# 1 C00157;C01226;C04672;C04780;C04785;C06427;C08491;C08492;C11512;C16300;C16308;C16309;C16310;C16311;C16316;C16317;C16318;C16319;C16320;C16321;C16322;C16323;C16324;C16325;C16326;C16327;C16328;C16330;C16331;C16332;C16334;C16335;C16336;C16338;C16339;C16341;C16342;C16343;C16344;C16345;C16346;C19757;C21923;C21924
# 2 C00157;C00219;C00427;C00584;C00639;C00696;C00909;C01312;C02165;C02166;C02198;C03577;C04577;C04671;C04707;C04742;C04758;C04805;C04822;C04835;C04853;C05356;C05949;C05950;C05951;C05952;C05953;C05954;C05955;C05956;C05957;C05958;C05959;C05960;C05961;C05962;C05963;C05964;C05965;C05966;C06314;C06315;C06462;C13809;C14717;C14732;C14748;C14749;C14768;C14769;C14770;C14771;C14772;C14773;C14774;C14775;C14776;C14777;C14778;C14779;C14780;C14781;C14782;C14794;C14795;C14807;C14808;C14809;C14810;C14811;C14812;C14813;C14814;C14815;C14820;C14821;C14822;C14823;C14824
# 3 C00154;C00219;C00249;C00412;C00510;C00712;C01203;C01530;C01595;C02041;C02050;C02249;C03035;C03242;C03595;C04088;C05764;C06425;C06426;C06427;C06428;C06429;C08281;C08316;C08320;C08323;C16160;C16161;C16162;C16163;C16164;C16165;C16166;C16167;C16168;C16169;C16170;C16171;C16172;C16173;C16179;C16180;C16513;C16522;C16525;C16526;C16527;C16528;C16529;C16530;C16531;C16532;C16533;C16645;C17279;C21072;C21932;C21934;C21935;C21937;C21939;C21941;C21943;C21945;C21947;C21949;C21951;C21953;C21959;C21961;C21963;C21965;C21967;C21981
# 4 C00029;C00040;C00093;C00103;C00111;C00116;C00162;C00173;C00184;C00197;C00258;C00416;C00422;C00577;C00631;C00641;C00681;C00969;C01885;C02133;C02457;C03692;C04046;C04315;C04872;C05401;C06037;C06038;C06040;C06041;C06042;C06364;C06365;C11521;C13508;C20897;C20898;C20991
# 5 C00040;C00065;C00084;C00093;C00111;C00114;C00157;C00189;C00269;C00307;C00344;C00346;C00350;C00416;C00513;C00570;C00588;C00623;C00641;C00670;C00681;C01194;C01210;C01233;C01241;C01996;C02737;C03372;C03819;C03872;C03892;C03974;C04230;C04233;C04308;C04438;C04590;C04638;C05973;C05974;C05976;C05980;C06771;C06772;C13482;C18059;C18125;C18126;C18129;C18168;C18169;C20466;C20518;C22340;C22341;C22342
# 6 C00011;C00014;C00022;C00037;C00048;C00049;C00065;C00078;C00097;C00101;C00109;C00114;C00143;C00168;C00188;C00197;C00213;C00258;C00263;C00300;C00430;C00441;C00546;C00576;C00581;C00631;C00719;C00740;C00986;C01005;C01026;C01102;C01242;C01888;C02051;C02291;C02737;C02972;C03082;C03194;C03232;C03283;C03508;C05519;C06231;C06442;C16432;C19929;C23135;C23136
#   pathway_HG_p_value Padjust
# 1 1.115172e-01       1.784275e-01
# 2 1.911638e-02       3.398467e-02
# 3 6.228354e-01       6.643577e-01
# 4 4.227123e-29       2.254466e-28
# 5 4.715065e-40       3.772052e-39
# 6 3.888173e-03       7.776346e-03

# %% [markdown]
# ### Plot pathway network
# Only plotting significant pathways (pathway with p-value significance).
#
# The pathway network is such that it shows metabolites that are connected to different pathways and same metabolite in different pathway. Color of nodes of metabolites are according to the fold change of metabolites (low expression in green and high in red) and size of pathway nodes (square nodes) are according to the number of branches (meaning no of metabolites). All metabolite are written in blue

# %%
plot_pathway_networks (met_path,kegg_es, TRUE)
# Out:
# Warning message:
# “ggrepel: 11 unlabeled data points (too many overlaps). Consider increasing max.overlaps”
# plot without title

# %% [markdown]
# ### Heatmap

# %%
plot_heatmap(met_path, shorten_name=TRUE,refmet_name=FALSE, xaxis=8, yaxis=6)
# Out:
# plot without title

# %% [markdown]
# ### Dotplot

# %%
dotplot_met_class_path (met_path, kegg_es,"sub_class",xaxis=8,yaxis=6)
# Out:
# Warning message:
# “Use of `significant_pathways[["pathway_HG_p_value"]]` is discouraged.
# ℹ Use `.data[["pathway_HG_p_value"]]` instead.”
# plot without title

# %% [markdown]
# ### Get the gene and enzyme info
#
# Here we get the information of genes involved in enriched pathways for specified organism

# %%
met_gene_info = enzyme_gene_info (metenrichment, "hsa","sub_class")
head(met_gene_info)
# Out:
#   orthology_id
# 1 K00069
# 2 K00079
# 3 K00084
# 4 K00498
# 5 K00498
# 6 K00551
#   ORTHOLOGY
# 1 15-hydroxyprostaglandin dehydrogenase (NAD) [EC:1.1.1.141]
# 2 carbonyl reductase 1 [EC:1.1.1.184 1.1.1.189 1.1.1.197]
# 3 carbonyl reductase 3 [EC:1.1.1.184]
# 4 cholesterol monooxygenase (side-chain-cleaving) [EC:1.14.15.6]
# 5 cholesterol monooxygenase (side-chain-cleaving) [EC:1.14.15.6]
# 6 phosphatidylethanolamine/phosphatidyl-N-methylethanolamine N-methyltransferase [EC:2.1.1.17 2.1.1.71]
#   gene_id gene_name    ORGANISM     PATHWAY      DBLINKS      MOTIF
# 1  3248   (RefSeq).... Homo sap.... Arachido.... NCBI-Gen.... Pfam: ad....
# 2   873   (RefSeq).... Homo sap.... Arachido.... NCBI-Gen.... Pfam: ad....
# 3   874   (RefSeq).... Homo sap.... Arachido.... NCBI-Gen.... Pfam: ad....
# 4  1583   (RefSeq).... Homo sap.... Steroid .... NCBI-Gen.... Pfam: p4....
# 5  1583   (RefSeq).... Homo sap.... Steroid .... NCBI-Gen.... Pfam: p4....
# 6 10400   (RefSeq).... Homo sap.... Glycerop.... NCBI-Gen.... Pfam: PE....
#   rxn    Metabolite              KEGG ID sub_class      Rxn_name
# 1 R02580 PGE2                    C00584  Prostaglandins (5Z,13E)....
# 2 R02581 PGE2                    C00584  Prostaglandins (5Z,13E)....
# 3 R02581 PGE2                    C00584  Prostaglandins (5Z,13E)....
# 4 R04855 22R-hydroxy-cholesterol C05502  Oxysterols     22beta-h....
# 5 R02723 22R-hydroxy-cholesterol C05502  Oxysterols
# 6 R02056 PE(38:6)                C00350  PE             S-adenos....
#   RCLASS       EQUATION     EQUATION_more ENZYME
# 1 RC00001 .... C00584 +.... Prostagl....     1.1.1.141
# 2 RC00001 .... C00639 +.... Prostagl....  1.1.1.18....
# 3 RC00001 .... C00639 +.... Prostagl....  1.1.1.18....
# 4 RC00706 .... C05502 +.... 22(R)-Hy....     1.14.15.6
# 5 RC00773 .... C00187 +.... Choleste....     1.14.15.6
# 6 RC00003 .... C00019 +.... S-Adenos....      2.1.1.17

# %% [markdown]
# #### Get the information if metabolite is a reactant or substrate

# %%
rclass_info = react_substrate(met_gene_info)
head(rclass_info)
# Out:
#   orthology_id
# 1 K00069
# 2 K00079
# 3 K00084
# 4 K00498
# 5 K00498
# 6 K00551
#   ORTHOLOGY
# 1 15-hydroxyprostaglandin dehydrogenase (NAD) [EC:1.1.1.141]
# 2 carbonyl reductase 1 [EC:1.1.1.184 1.1.1.189 1.1.1.197]
# 3 carbonyl reductase 3 [EC:1.1.1.184]
# 4 cholesterol monooxygenase (side-chain-cleaving) [EC:1.14.15.6]
# 5 cholesterol monooxygenase (side-chain-cleaving) [EC:1.14.15.6]
# 6 phosphatidylethanolamine/phosphatidyl-N-methylethanolamine N-methyltransferase [EC:2.1.1.17 2.1.1.71]
#   gene_id gene_name    ORGANISM     PATHWAY      DBLINKS      MOTIF
# 1  3248   (RefSeq).... Homo sap.... Arachido.... NCBI-Gen.... Pfam: ad....
# 2   873   (RefSeq).... Homo sap.... Arachido.... NCBI-Gen.... Pfam: ad....
# 3   874   (RefSeq).... Homo sap.... Arachido.... NCBI-Gen.... Pfam: ad....
# 4  1583   (RefSeq).... Homo sap.... Steroid .... NCBI-Gen.... Pfam: p4....
# 5  1583   (RefSeq).... Homo sap.... Steroid .... NCBI-Gen.... Pfam: p4....
# 6 10400   (RefSeq).... Homo sap.... Glycerop.... NCBI-Gen.... Pfam: PE....
#   rxn    Metabolite              KEGG ID sub_class      Rxn_name
# 1 R02580 PGE2                    C00584  Prostaglandins (5Z,13E)....
# 2 R02581 PGE2                    C00584  Prostaglandins (5Z,13E)....
# 3 R02581 PGE2                    C00584  Prostaglandins (5Z,13E)....
# 4 R04855 22R-hydroxy-cholesterol C05502  Oxysterols     22beta-h....
# 5 R02723 22R-hydroxy-cholesterol C05502  Oxysterols
# 6 R02056 PE(38:6)                C00350  PE             S-adenos....
#   RCLASS       EQUATION     EQUATION_more ENZYME       reactant_product
# 1 RC00001 .... C00584 +.... Prostagl....     1.1.1.141 Substrate
# 2 RC00001 .... C00639 +.... Prostagl....  1.1.1.18.... Product
# 3 RC00001 .... C00639 +.... Prostagl....  1.1.1.18.... Product
# 4 RC00706 .... C05502 +.... 22(R)-Hy....     1.14.15.6 Substrate
# 5 RC00773 .... C00187 +.... Choleste....     1.14.15.6 Product
# 6 RC00003 .... C00019 +.... S-Adenos....      2.1.1.17 Substrate

# %% [markdown]
# #### Get gene info in short form

# %%
met_gene_info2=data.table::data.table(rclass_info)[,lapply(.SD, function(x) toString(unique(x))), by = 'Metabolite']
