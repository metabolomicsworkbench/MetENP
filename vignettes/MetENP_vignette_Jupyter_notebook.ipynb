# %% [markdown]
# ## MetENP

# %% [markdown]
# MetENP is a R package that enables detection of significant metabolites from metabolite information
# (names or names and concentration along with metadata information) and provides
#
# 1. Enrichment score of metabolite class,
# 2. Maps to pathway of the species of choice,
# 3. Calculate enrichment score of pathways,
# 4. Plots the pathways and shows the metabolite increase or decrease
# 5. Gets gene info, reaction info, enzyme info
#
# For more info, check out the vignette.

# %%
if (!requireNamespace("KEGGREST", quietly = TRUE))
    BiocManager::install("KEGGREST", update = TRUE, ask = FALSE)

if (!requireNamespace("KEGGgraph", quietly = TRUE))
    BiocManager::install("KEGGgraph", update = TRUE, ask = FALSE)

if (!requireNamespace("pathview", quietly = TRUE))
    BiocManager::install("pathview", update = TRUE, ask = FALSE)

#if (!requireNamespace("KEGG.db", quietly = TRUE))
#    BiocManager::install("KEGG.db", update = TRUE, ask = FALSE)

#if (!requireNamespace("MetENP", quietly = TRUE))
#    devtools::install("..", upgrade = "never")
# Out:
# ##############################################################################
# Pathview is an open source software package distributed under GNU General
# Public License version 3 (GPLv3). Details of GPLv3 is available at
# http://www.gnu.org/licenses/gpl-3.0.html. Particullary, users are required to
# formally cite the original Pathview paper (not just mention it) in publications
# or products. For details, do citation("pathview") within R.
#
# The pathview downloads and uses KEGG data. Non-academic uses may require a KEGG
# license agreement (details at http://www.kegg.jp/kegg/legal.html).
# ##############################################################################

# %%
USER_HOME=Sys.getenv("HOME");
USER_PWD=Sys.getenv("PWD");
#.libPaths( c( .libPaths(), paste0(USER_HOME, "/.local/R") ))
.libPaths( c( .libPaths(), paste0(USER_PWD, "/../../R") )); # suitable path to where MetENP R package is installed
#.libPaths( c( .libPaths(), paste0("../../R") )); # suitable path to where MetENP R package is installed

library(MetENP)

# %% [markdown]
# #### If you do not wish to install, alternatively, download from github(https://github.com/metabolomicsworkbench/MetENP) and load libraries and functions

# %%
data = getmwstudies('ST000915', 'data')
head(data)
# Out:
#   analysis_id analysis_summary               metabolite_name metabolite_id
# 1 AN001485    Core G Fatty acids/Eicosanoids 10 HDoHE        ME230937
# 2 AN001485    Core G Fatty acids/Eicosanoids 11,12-diHETrE   ME230961
# 3 AN001485    Core G Fatty acids/Eicosanoids 11,12-EET       ME230954
# 4 AN001485    Core G Fatty acids/Eicosanoids 11b PGE2        ME230914
# 5 AN001485    Core G Fatty acids/Eicosanoids 11 HDoHE        ME230941
# 6 AN001485    Core G Fatty acids/Eicosanoids 11-HEPE         ME230917
#   refmet_name   NASH001 NASH002 NASH003 NASH004 NASH005 ⋯ NASH061 NASH062
# 1 10-HDoHE      0.00419 0.01396 0.00285 0.00705 0.00020 ⋯ NA      NA
# 2 11,12-DiHETrE 0.01346 1.84739 0.63897 1.87466 0.21119 ⋯ 0.12842 0.16833
# 3 11,12-EpETrE  0.20666 0.12915 0.18170 0.11368 0.06081 ⋯ 0.06934 0.06330
# 4 11beta-PGE2   0.00048 0.00128 NA      NA      NA      ⋯ 0.00165 0.00327
# 5 11-HDoHE      0.00617 0.03174 0.00958 0.00593 0.00271 ⋯ 0.03543 0.01280
# 6 11-HEPE       0.00642 NA      0.01625 0.02049 0.00115 ⋯ 0.14650 0.03245
#   NASH064 NASH065 NASH066 NASH067 NASH068 NASH069 NASH070 NASH074
# 1 NA      NA      NA      NA      NA      NA      NA      NA
# 2 0.12114 0.32882 0.10923 0.21540 0.24789 0.25932 0.03551 0.05935
# 3 0.04931 0.10011 0.10355 0.16318 0.10468 0.05115 0.08985 0.10916
# 4 0.00153 NA      NA      NA      NA      0.00445 NA      NA
# 5 0.00369 0.01844 0.00649 0.03449 0.01077 0.01869 0.00414 0.01129
# 6 0.01528 0.01148 0.03754 0.01260 0.03738 0.00957 0.00057 0.01524

# %%
metadata = getmwstudies('ST000915', 'factors')
head(metadata)
# Out:
#   study_id local_sample_id subject_type         factors             Diagnosis
# 1 ST000915 NASH005         Human clinical study Diagnosis:Cirrhosis Cirrhosis
# 2 ST000915 NASH007         Human clinical study Diagnosis:Cirrhosis Cirrhosis
# 3 ST000915 NASH009         Human clinical study Diagnosis:Cirrhosis Cirrhosis
# 4 ST000915 NASH013         Human clinical study Diagnosis:Cirrhosis Cirrhosis
# 5 ST000915 NASH016         Human clinical study Diagnosis:Cirrhosis Cirrhosis
# 6 ST000915 NASH022         Human clinical study Diagnosis:Cirrhosis Cirrhosis

# %% [markdown]
# Find the factors you would want to compare
# Multiple factors (independent variables) are formatted in multiple columns but you can get information on all the factors by "factors" column, such as 'TreatmentGroup:Prednisolone', this indicates column name 'TreatmentGroup' with factor Prednisolone. For t-test use the factors in the same column. For comparing multipe independent variables use anova by anova_ana function.

# %% [markdown]
# ### Associate metabolomics data to the refmet class

# %%
refmet_class= convert_refmet(data)
head(refmet_class)
# Out:
#   metabolite_name analysis_id analysis_summary      metabolite_id refmet_name
# 1 1,2-DG(30:0)    AN001488    Core E Neutral Lipids ME231190      1,2-DG 30:0
# 2 1,2-DG(30:1)    AN001488    Core E Neutral Lipids ME231189      1,2-DG 30:1
# 3 1,2-DG(32:0)    AN001488    Core E Neutral Lipids ME231196      1,2-DG 32:0
# 4 1,2-DG(32:1)    AN001488    Core E Neutral Lipids ME231195      1,2-DG 32:1
# 5 1,2-DG(32:2)    AN001488    Core E Neutral Lipids ME231194      1,2-DG 32:2
# 6 1,2-DG(32:3)    AN001488    Core E Neutral Lipids ME231193      1,2-DG 32:3
#   NASH001 NASH002 NASH003 NASH004 NASH005 ⋯ NASH066 NASH067 NASH068 NASH069
# 1 2.7     NA      NA      NA      NA      ⋯ 193.4   55.0    75.9    99.1
# 2 1.8     NA      NA      NA      NA      ⋯ 185.3   30.0    37.5    97.3
# 3 12.2    7.1     2.2     2.0     1.4     ⋯ 1289.5  401.0   350.9   420.2
# 4 7.6     5.7     2.1     1.4     1.1     ⋯ 844.7   187.7   266.9   436.2
# 5 2.0     1.9     NA      NA      NA      ⋯ 345.8   78.2    77.3    184.5
# 6 NA      NA      NA      NA      NA      ⋯ 63.0    12.4    7.8     52.6
#   NASH070 NASH074 formula  super_class   main_class       sub_class
# 1 173.0   591.6   C33H64O5 Glycerolipids Diradylglycerols DAG
# 2 185.6   749.1   C33H62O5 Glycerolipids Diradylglycerols DAG
# 3 713.2   1375.8  C35H68O5 Glycerolipids Diradylglycerols DAG
# 4 715.7   1932.0  C35H66O5 Glycerolipids Diradylglycerols DAG
# 5 336.2   697.2   C35H64O5 Glycerolipids Diradylglycerols DAG
# 6 63.8    124.3   C35H62O5 Glycerolipids Diradylglycerols DAG

# %%
unique(metadata$factors)
# Out:
# [[1]]
# [1] "Diagnosis:Cirrhosis"
#
# [[2]]
# [1] "Diagnosis:NASH"
#
# [[3]]
# [1] "Diagnosis:Normal"
#
# [[4]]
# [1] "Diagnosis:Steatosis"

# %%
### Find the analysis mode
unique(data$analysis_summary)
# Out:
# [[1]]
# [1] "Core G Fatty acids/Eicosanoids"
#
# [[2]]
# [1] "Core J Sterols"
#
# [[3]]
# [1] "Core K Prenols/Cardiolipins"
#
# [[4]]
# [1] "Core E Neutral Lipids"
#
# [[5]]
# [1] "Core I Sphingolipids"
#
# [[6]]
# [1] "Core H Phospholipids"

# %% [markdown]
# ### Find significant metabolites, run significance of all the analysis summary together. The analysis summary/modes you got in the previous section
# There is a normalization step which takes into account missing values, and this can be achieved via three methods:
#
# 1) half_of_min: where the NAs are replaced by half of min values in the data
#
# 2) remove_NAs: where Cols with NAs values are removed
#
# 3) 50percent: where cols with more than 50% NAs values are removed
#
# half_of_min is ideal when you wish to see which metabolites were present in either group. Very high fold change would mean it was present in either group.

# %%
stats_metabolites = significant_met(metabolomics_data=refmet_class, met_col="metabolite_name",analysis_type=c("Core G Fatty acids/Eicosanoids","Core J Sterols","Core K Prenols/Cardiolipins","Core E Neutral Lipids","Core I Sphingolipids","Core H Phospholipids"), metadata=metadata, factor1='Cirrhosis', factor2=c('Normal'), factor_col='Diagnosis',sample_col='local_sample_id', p_adjust='fdr',normalization="50percent")

sig_metabolites = stats_metabolites[which(stats_metabolites[,"pval"] <= 0.05&abs(stats_metabolites[,"log2Fold_change"])>0.5),]

# %%
plot_volcano(stats_metabolites, thres_pval= 0.05,thres_log2foldchange = 0.5, TRUE)
# Out:
# Warning message:
# “ggrepel: 57 unlabeled data points (too many overlaps). Consider increasing max.overlaps”
# plot without title

# %% [markdown]
# ### Map metabolite class of the significant metabolites utilzing refmet classification in Metabolomics Workbench
# This function not only maps metabolite to metabolite class but also to external databases such as pubchem, inchi key, smiles and kegg
#
# In this example, we will go forward with significant metabolite obtained by t-test/

# %%
sig_metabolites_kegg_id= map_keggid(sig_metabolites)

# %% [markdown]
# #### Check all your significant metabolites have not been assigned metabolite class

# %%
setdiff(sig_metabolites$refmet_name, sig_metabolites_kegg_id$refmet_name)
# Out:
# character(0)

# %% [markdown]
# ### Count metabolites in each of the metabolite class and plotting
# You may choose from sub_class, main_class and super_class

# %%
count_changes = metcountplot(df_metclass=sig_metabolites_kegg_id, metclass='sub_class', plotting=TRUE, thres_logfC = 0.0, updown_fillcolor=c("red", "green"))
print(count_changes$sig_met_count)
# Out:
#             sub_class No.of_metabolites                 color
# 1          1-deoxyCer                 5 increased metabolites
# 2                 BMP                 2 increased metabolites
# 3                 Cer                 6 increased metabolites
# 4        Chol. esters                 5 increased metabolites
# 5        Cholesterols                 1 increased metabolites
# 6                  CL                 3 increased metabolites
# 7                 DAG                 9 increased metabolites
# 8         Docosanoids                 3 increased metabolites
# 9           Dolichols                 4 increased metabolites
# 10             EpETrE                 4 increased metabolites
# 11               HEPE                 1 increased metabolites
# 12               HETE                 1 increased metabolites
# 13             HexCer                 5 increased metabolites
# 14                LPC                 1 increased metabolites
# 15                LPG                 2 increased metabolites
# 16         Oxysterols                 1 increased metabolites
# 17                 PA                 2 increased metabolites
# 18                 PC                 1 increased metabolites
# 19                 PE                 2 increased metabolites
# 20     Prostaglandins                 1 increased metabolites
# 21                 PS                 1 increased metabolites
# 22       Saturated FA                 1 increased metabolites
# 23                 SM                 3 increased metabolites
# 24 Sphingoid base 1-P                 1 increased metabolites
# 25       Sphingosines                 1 increased metabolites
# 26                TAG                 3 increased metabolites
# 27               <NA>                 1 increased metabolites
# 28       Cholesterols                -2 decreased metabolites
# 29              DHCer                -1 decreased metabolites
# 30               ETrE                -1 decreased metabolites
# 31               O-PE                -1 decreased metabolites
# 32         Oxysterols                -1 decreased metabolites
# 33                 PE                -2 decreased metabolites
# 34                 PI                -2 decreased metabolites
# 35     Prostaglandins                -1 decreased metabolites
# 36                 PS                -3 decreased metabolites
# 37                 SM                -1 decreased metabolites

# %%
count_changes$plotimg
# Out:
# Warning message:
# “Use of `count_changes[[metclass]]` is discouraged. Use `.data[[metclass]]` instead.”
# plot without title

# %% [markdown]
# ### Enrichment class score
#
# Calculate the enrichment score of each metabolite class. Enrichment score is calculated through hypergeometric method. One can specify the no. of significant metabolites in a class while calculating the enrichment score. We advice to use the number of mtabolites in each class as 3 or more. But if someone just wants to know the enrichment score and rest of the information of all the metabolites, then they can choose the number as 1.

# %%
metenrichment = metclassenrichment(df_metclass=sig_metabolites_kegg_id,refmet_class, metclass="sub_class",enrich_stats="HG",no=1)
print(head(metenrichment))
#knitr::kable(head(metenrichment))
metenrichment[metenrichment$main_class %in% c("Ceramides", "Sphingomyelins"), c("Metabolite", "pval", "super_class", "main_class", "sub_class", "HG p-value")]
colnames(metenrichment)
metenrichment$super_class
metenrichment$main_class
metenrichment$sub_class
# Out:
#               refmet_name Exact mass KEGG ID       Metabolite Cirrhosis_mean
# 1 1-DeoxyCer 18:0;O2/16:0   523.5328         C16DH 1-deoxyCer     0.05623685
# 2 1-DeoxyCer 18:0;O2/18:0   551.5641         C18DH 1-deoxyCer      0.0906803
# 3 1-DeoxyCer 18:0;O2/20:0   579.5954         C20DH 1-deoxyCer      0.0723488
# 4 1-DeoxyCer 18:0;O2/22:0   607.6267         C22DH 1-deoxyCer      0.1513816
# 5 1-DeoxyCer 18:0;O2/24:0   635.6580         C24DH 1-deoxyCer      0.1177141
# 6             1,2-DG 32:0   568.5067  C00641     1,2-DG(32:0)       210.0625
#   Normal_mean Fold_change log2Fold_change   t_value         pval        padj
# 1  0.12178748    2.165617        1.114778 -3.028001 0.0044113841 0.025170838
# 2   0.2566956    2.830776        1.501197 -3.826879 0.0005219699 0.005671347
# 3   0.1756429    2.427724        1.279604 -3.268230 0.0023663363 0.015081843
# 4   0.4227716    2.792754        1.481689 -3.604410 0.0009458421 0.007645557
# 5   0.3056195    2.596286        1.376449 -2.746084 0.0091800137 0.046866386
# 6    479.9210    2.284658        1.191978 -2.410346 0.0200253888 0.106653539
#   metabolite_id   super_class       main_class  sub_class   formula
# 1      ME231305 Sphingolipids        Ceramides 1-deoxyCer C34H69NO2
# 2      ME231306 Sphingolipids        Ceramides 1-deoxyCer C36H73NO2
# 3      ME231307 Sphingolipids        Ceramides 1-deoxyCer C38H77NO2
# 4      ME231308 Sphingolipids        Ceramides 1-deoxyCer C40H81NO2
# 5      ME231310 Sphingolipids        Ceramides 1-deoxyCer C42H85NO2
# 6      ME231196 Glycerolipids Diradylglycerols        DAG  C35H68O5
#     HG p-value
# 1 3.486997e-04
# 2 4.793168e-04
# 3 4.793168e-04
# 4 4.793168e-04
# 5 4.793168e-04
# 6 7.765032e-06
#    Metabolite          pval         super_class   main_class     sub_class
# 1  C16DH 1-deoxyCer    4.411384e-03 Sphingolipids Ceramides      1-deoxyCer
# 2  C18DH 1-deoxyCer    5.219699e-04 Sphingolipids Ceramides      1-deoxyCer
# 3  C20DH 1-deoxyCer    2.366336e-03 Sphingolipids Ceramides      1-deoxyCer
# 4  C22DH 1-deoxyCer    9.458421e-04 Sphingolipids Ceramides      1-deoxyCer
# 5  C24DH 1-deoxyCer    9.180014e-03 Sphingolipids Ceramides      1-deoxyCer
# 35 C24:1DH Cer         4.727138e-02 Sphingolipids Ceramides      DHCer
# 36 C18 Cer             2.759931e-04 Sphingolipids Ceramides      Cer
# 37 C18:1 Cer           5.261088e-03 Sphingolipids Ceramides      Cer
# 38 C20 Cer             3.586497e-04 Sphingolipids Ceramides      Cer
# 39 C22 Cer             1.351778e-05 Sphingolipids Ceramides      Cer
# 40 C24 Cer             1.231257e-04 Sphingolipids Ceramides      Cer
# 41 C26 Cer             4.782389e-02 Sphingolipids Ceramides      Cer
# 76 C16DH Sphingomyelin 3.904911e-05 Sphingolipids Sphingomyelins SM
# 77 C18:1 Sphingomyelin 3.185880e-02 Sphingolipids Sphingomyelins SM
# 78 C20 Sphingomyelin   1.441053e-03 Sphingolipids Sphingomyelins SM
# 79 C22 Sphingomyelin   1.458968e-03 Sphingolipids Sphingomyelins SM
#    HG p-value
# 1  3.486997e-04
# 2  4.793168e-04
# 3  4.793168e-04
# 4  4.793168e-04
# 5  4.793168e-04
# 35 4.417593e-01
# 36 5.413920e-06
# 37 5.413920e-06
# 38 5.413920e-06
# 39 5.413920e-06
# 40 5.413920e-06
# 41 5.413920e-06
# 76 5.603202e-03
# 77 5.603202e-03
# 78 5.603202e-03
# 79 5.603202e-03
#  [1] "refmet_name"     "Exact mass"      "KEGG ID"         "Metabolite"
#  [5] "Cirrhosis_mean"  "Normal_mean"     "Fold_change"     "log2Fold_change"
#  [9] "t_value"         "pval"            "padj"            "metabolite_id"
# [13] "super_class"     "main_class"      "sub_class"       "formula"
# [17] "HG p-value"
#  [1] "Sphingolipids"        "Sphingolipids"        "Sphingolipids"
#  [4] "Sphingolipids"        "Sphingolipids"        "Glycerolipids"
#  [7] "Glycerolipids"        "Glycerolipids"        "Glycerolipids"
# [10] "Glycerolipids"        "Glycerolipids"        "Glycerolipids"
# [13] "Glycerolipids"        "Glycerolipids"        "Fatty Acyls"
# [16] "Fatty Acyls"          "Fatty Acyls"          "Fatty Acyls"
# [19] "Fatty Acyls"          "Fatty Acyls"          "Fatty Acyls"
# [22] "Sterol Lipids"        "Sterol Lipids"        "Fatty Acyls"
# [25] "Fatty Acyls"          "Fatty Acyls"          "Fatty Acyls"
# [28] "Glycerophospholipids" "Glycerophospholipids" "Sterol Lipids"
# [31] "Sterol Lipids"        "Sterol Lipids"        "Sterol Lipids"
# [34] "Sterol Lipids"        "Sphingolipids"        "Sphingolipids"
# [37] "Sphingolipids"        "Sphingolipids"        "Sphingolipids"
# [40] "Sphingolipids"        "Sphingolipids"        "Glycerophospholipids"
# [43] "Glycerophospholipids" "Glycerophospholipids" "Sterol Lipids"
# [46] "Sterol Lipids"        "Prenol Lipids"        "Prenol Lipids"
# [49] "Prenol Lipids"        "Prenol Lipids"        "Sphingolipids"
# [52] "Sphingolipids"        "Sphingolipids"        "Sphingolipids"
# [55] "Sphingolipids"        "Sterol Lipids"        "Fatty Acyls"
# [58] "Glycerophospholipids" "Glycerophospholipids" "Glycerophospholipids"
# [61] "Glycerophospholipids" "Glycerophospholipids" "Glycerophospholipids"
# [64] "Glycerophospholipids" "Glycerophospholipids" "Glycerophospholipids"
# [67] "Glycerophospholipids" "Glycerophospholipids" "Fatty Acyls"
# [70] "Glycerophospholipids" "Glycerophospholipids" "Glycerophospholipids"
# [73] "Glycerophospholipids" "Glycerophospholipids" "Glycerophospholipids"
# [76] "Sphingolipids"        "Sphingolipids"        "Sphingolipids"
# [79] "Sphingolipids"        "Sphingolipids"        "Sphingolipids"
# [82] "Glycerolipids"        "Glycerolipids"        "Glycerolipids"
#  [1] "Ceramides"                   "Ceramides"
#  [3] "Ceramides"                   "Ceramides"
#  [5] "Ceramides"                   "Diradylglycerols"
#  [7] "Diradylglycerols"            "Diradylglycerols"
#  [9] "Diradylglycerols"            "Diradylglycerols"
# [11] "Diradylglycerols"            "Diradylglycerols"
# [13] "Diradylglycerols"            "Diradylglycerols"
# [15] "Eicosanoids"                 "Eicosanoids"
# [17] "Eicosanoids"                 "Docosanoids"
# [19] "Eicosanoids"                 "Eicosanoids"
# [21] "Docosanoids"                 "Sterols"
# [23] "Sterols"                     "Docosanoids"
# [25] "Eicosanoids"                 "Eicosanoids"
# [27] "Eicosanoids"                 "Glycerophosphoglycerols"
# [29] "Glycerophosphoglycerols"     "Sterol esters"
# [31] "Sterol esters"               "Sterol esters"
# [33] "Sterol esters"               "Sterol esters"
# [35] "Ceramides"                   "Ceramides"
# [37] "Ceramides"                   "Ceramides"
# [39] "Ceramides"                   "Ceramides"
# [41] "Ceramides"                   "Cardiolipins"
# [43] "Cardiolipins"                "Cardiolipins"
# [45] "Sterols"                     "Sterols"
# [47] "Polyprenols"                 "Polyprenols"
# [49] "Polyprenols"                 "Polyprenols"
# [51] "Glycosphingolipids"          "Glycosphingolipids"
# [53] "Glycosphingolipids"          "Glycosphingolipids"
# [55] "Glycosphingolipids"          "Sterols"
# [57] "Fatty acids"                 "Glycerophosphocholines"
# [59] "Glycerophosphoglycerols"     "Glycerophosphoglycerols"
# [61] "Glycerophosphates"           "Glycerophosphates"
# [63] "Glycerophosphocholines"      "Glycerophosphoethanolamines"
# [65] "Glycerophosphoethanolamines" "Glycerophosphoethanolamines"
# [67] "Glycerophosphoethanolamines" "Glycerophosphoethanolamines"
# [69] "Eicosanoids"                 "Glycerophosphoinositols"
# [71] "Glycerophosphoinositols"     "Glycerophosphoserines"
# [73] "Glycerophosphoserines"       "Glycerophosphoserines"
# [75] "Glycerophosphoserines"       "Sphingomyelins"
# [77] "Sphingomyelins"              "Sphingomyelins"
# [79] "Sphingomyelins"              "Sphingoid bases"
# [81] "Sphingoid bases"             "Triradylglycerols"
# [83] "Triradylglycerols"           "Triradylglycerols"
#  [1] "1-deoxyCer"         "1-deoxyCer"         "1-deoxyCer"
#  [4] "1-deoxyCer"         "1-deoxyCer"         "DAG"
#  [7] "DAG"                "DAG"                "DAG"
# [10] "DAG"                "DAG"                "DAG"
# [13] "DAG"                "DAG"                "EpETrE"
# [16] "HEPE"               "HETE"               "Docosanoids"
# [19] "EpETrE"             "ETrE"               "Docosanoids"
# [22] "Oxysterols"         "Oxysterols"         "Docosanoids"
# [25] "EpETrE"             "Prostaglandins"     "EpETrE"
# [28] "BMP"                "BMP"                "Chol. esters"
# [31] "Chol. esters"       "Chol. esters"       "Chol. esters"
# [34] "Chol. esters"       "DHCer"              "Cer"
# [37] "Cer"                "Cer"                "Cer"
# [40] "Cer"                "Cer"                "CL"
# [43] "CL"                 "CL"                 "Cholesterols"
# [46] "Cholesterols"       "Dolichols"          "Dolichols"
# [49] "Dolichols"          "Dolichols"          "HexCer"
# [52] "HexCer"             "HexCer"             "HexCer"
# [55] "HexCer"             "Cholesterols"       "Saturated FA"
# [58] "LPC"                "LPG"                "LPG"
# [61] "PA"                 "PA"                 "PC"
# [64] "PE"                 "PE"                 "PE"
# [67] "PE"                 "O-PE"               "Prostaglandins"
# [70] "PI"                 "PI"                 "PS"
# [73] "PS"                 "PS"                 "PS"
# [76] "SM"                 "SM"                 "SM"
# [79] "SM"                 "Sphingosines"       "Sphingoid base 1-P"
# [82] "TAG"                "TAG"                "TAG"

# %% [markdown]
# #### Plot the enrichment score via function plot_met_enrichment

# %%
plot_met_enrichment(metenrichment, "sub_class","HG", no=3)
# Out:
# Warning message:
# “Use of `metclass_stats[[metclass]]` is discouraged. Use `.data[[metclass]]` instead.”
# Warning message:
# “Use of `metclass_stats[[enrich_stats]]` is discouraged. Use `.data[[enrich_stats]]` instead.”
# Warning message:
# “Use of `metclass_stats[[enrich_stats]]` is discouraged. Use `.data[[enrich_stats]]` instead.”
# plot without title

# %% [markdown]
# ### Check the pathways with reactions of all the significant metabolites

# %%
met_path = met_pathways(df_metenrichment = metenrichment, 'hsa')
head(met_path)
# Out:
#   rxn    refmet_name Exact mass KEGG ID Metabolite  Cirrhosis_mean Normal_mean
# 1 R01003 Dolichol-20 1381.2782  C00381  Dolichol-20 18.54100       60.64903
# 2 R01003 Dolichol-20 1381.2782  C00381  Dolichol-20 18.54100       60.64903
# 3 R01018 Dolichol-20 1381.2782  C00381  Dolichol-20 18.54100       60.64903
# 4 R01018 Dolichol-20 1381.2782  C00381  Dolichol-20 18.54100       60.64903
# 5 R01310 PC 36:4     781.5622   C00157  PC(36:4)    1025.012       1505.988
# 6 R01310 PC 36:4     781.5622   C00157  PC(36:4)    1025.012       1505.988
#   Fold_change log2Fold_change t_value   ⋯ metabolite_id super_class
# 1 3.271077    1.7097655       -7.141005 ⋯ ME231044      Prenol Lipids
# 2 3.271077    1.7097655       -7.141005 ⋯ ME231044      Prenol Lipids
# 3 3.271077    1.7097655       -7.141005 ⋯ ME231044      Prenol Lipids
# 4 3.271077    1.7097655       -7.141005 ⋯ ME231044      Prenol Lipids
# 5 1.469239    0.5550695       -4.795876 ⋯ ME231358      Glycerophospholipids
# 6 1.469239    0.5550695       -4.795876 ⋯ ME231358      Glycerophospholipids
#   main_class             sub_class formula    HG p-value
# 1 Polyprenols            Dolichols C100H164O  0.0002832851
# 2 Polyprenols            Dolichols C100H164O  0.0002832851
# 3 Polyprenols            Dolichols C100H164O  0.0002832851
# 4 Polyprenols            Dolichols C100H164O  0.0002832851
# 5 Glycerophosphocholines PC        C44H80NO8P 0.5574425503
# 6 Glycerophosphocholines PC        C44H80NO8P 0.5574425503
#   Rxn_name                                 PATHWAY
# 1 dolichyl-phosphate phosphohydrolase      N-Glycan biosynthesis
# 2 dolichyl-phosphate phosphohydrolase      Metabolic pathways
# 3 CTP:dolichol O-phosphotransferase        N-Glycan biosynthesis
# 4 CTP:dolichol O-phosphotransferase        Metabolic pathways
# 5 phosphatidylcholine phosphatidohydrolase Glycerophospholipid metabolism
# 6 phosphatidylcholine phosphatidohydrolase Metabolic pathways
#   pathway_id sps_path_id
# 1 rn00510    hsa00510
# 2 rn01100    hsa01100
# 3 rn00510    hsa00510
# 4 rn01100    hsa01100
# 5 rn00564    hsa00564
# 6 rn01100    hsa01100

# %% [markdown]
# Find metabolites for which no pathways were registered in Kegg and/or no kegg id was found

# %%
setdiff(metenrichment$Metabolite,unique(met_path$Metabolite))
# Out:
#  [1] "C16DH 1-deoxyCer" "C18DH 1-deoxyCer" "C20DH 1-deoxyCer" "C22DH 1-deoxyCer"
#  [5] "C24DH 1-deoxyCer" "12-HEPE"          "12-HETE"          "14 HDoHE"
#  [9] "15-HETrE"         "16 HDoHE"         "4 HDoHE"          "BMP(40:7)"
# [13] "BMP(40:8)"        "CE(18:2)"         "CE(18:3)"         "CE(20:3)"
# [17] "CE(20:4)"         "CL (72:8)"        "CL (74:7)"        "CL (74:8)"
# [21] "Cholestanol"      "Dolichol-17"      "Dolichol-18"      "Dolichol-19"

# %% [markdown]
# ### Get pathway enrichment sore.
#
# Once we have the pathway information, we can calculate enrichment score of pathways. Again, here i have used hypergeometric score. For hypergeometric score, we need to know the total number of kegg compounds that are linked to kegg pathways.
# N = total no. of cmpds linked to kegg pathway (this is the step which might take long), so I advice to run the script comp_linkedto_pathways() just the first time or after 6 months or so if desired to run the pipeline again. save the result from comp_linkedto_pathways() and load it. Loading from saved file would save time for another analysis with another study. However the package takes care of loading. Save the data in the data folder.
#
# L = No. of cmpds in a pathway
# M= no. of altered cmpds in a pathway
# K =  total no. of altered cmpds
# phyper(M,L, N-L, K)
#
#
# This function also utilizes korg dataset from pathview package.

# %%
load('../data/ls_path.RData')
load('../data/korg.RData')
kegg_es = path_enrichmentscore(met_path,sig_metabolite_kegg_id=sig_metabolite_kegg_id,ls_path=ls_path,refmet_class=refmet_class,sps='hsa',padj='fdr', kegg_comp_path=FALSE)

# %%
head(kegg_es)
# Out:
#   Pathway name                            No.of mets in study
# 1 alpha-Linolenic acid metabolism          4
# 2 Arachidonic acid metabolism              8
# 3 Biosynthesis of unsaturated fatty acids  1
# 4 Ether lipid metabolism                   1
# 5 Glycerolipid metabolism                 14
# 6 Glycerophospholipid metabolism          25
#   Total_no._of_comps_in_pathway pathway_HG p-value Padjust
# 1 44                            9.380043e-01       1.000000e+00
# 2 75                            9.330122e-01       1.000000e+00
# 3 74                            9.999988e-01       1.000000e+00
# 4 25                            9.873619e-01       1.000000e+00
# 5 38                            7.720993e-04       3.281422e-03
# 6 56                            3.418221e-08       1.936992e-07

# %% [markdown]
# ### Plot pathway network
# Only plotting significant pathways (pathway with p-value significance).
#
# The pathway network is such that it shows metabolites that are connected to different pathways and same metabolite in different pathway. Color of nodes of metabolites are according to the fold change of metabolites (low expression in green and high in red) and size of pathway nodes (square nodes) are according to the number of branches (meaning no of metabolites). All metabolite are written in blue

# %%
plot_pathway_networks (met_path,kegg_es, TRUE)
# Out:
# Warning message:
# “ggrepel: 17 unlabeled data points (too many overlaps). Consider increasing max.overlaps”
# plot without title

# %% [markdown]
# ### Heatmap

# %%
plot_heatmap(met_path, shorten_name=TRUE,refmet_name=FALSE, xaxis=8, yaxis=6)
# Out:
# plot without title

# %% [markdown]
# ### Dotplot

# %%
dotplot_met_class_path (met_path, kegg_es,"sub_class",xaxis=8,yaxis=6)
# Out:
# Warning message:
# “Use of `significant_pathways[["pathway_HG p-value"]]` is discouraged. Use `.data[["pathway_HG p-value"]]` instead.”
# plot without title

# %% [markdown]
# ### Get the gene and enzyme info
#
# Here we get the information of genes involved in enriched pathways for specified organism

# %%
met_gene_info = enzyme_gene_info (metenrichment, "hsa","sub_class")
head(met_gene_info)
# Out:
#   orthology_id
# 1 K00079
# 2 K00084
# 3 K00498
# 4 K00498
# 5 K00551
# 6 K00551
#   ORTHOLOGY
# 1 carbonyl reductase 1 [EC:1.1.1.184 1.1.1.189 1.1.1.197]
# 2 carbonyl reductase 3 [EC:1.1.1.184]
# 3 cholesterol monooxygenase (side-chain-cleaving) [EC:1.14.15.6]
# 4 cholesterol monooxygenase (side-chain-cleaving) [EC:1.14.15.6]
# 5 phosphatidylethanolamine/phosphatidyl-N-methylethanolamine N-methyltransferase [EC:2.1.1.17 2.1.1.71]
# 6 phosphatidylethanolamine/phosphatidyl-N-methylethanolamine N-methyltransferase [EC:2.1.1.17 2.1.1.71]
#   gene_id gene_name
# 1 873     (RefSeq) carbonyl reductase 1
# 2 874     (RefSeq) carbonyl reductase 3
# 3 1583    (RefSeq) cytochrome P450 family 11 subfamily A member 1
# 4 1583    (RefSeq) cytochrome P450 family 11 subfamily A member 1
# 5 10400   (RefSeq) phosphatidylethanolamine N-methyltransferase
# 6 10400   (RefSeq) phosphatidylethanolamine N-methyltransferase
#   ORGANISM
# 1 Homo sapiens (human)
# 2 Homo sapiens (human)
# 3 Homo sapiens (human)
# 4 Homo sapiens (human)
# 5 Homo sapiens (human)
# 6 Homo sapiens (human)
#   PATHWAY
# 1 Arachidonic acid metabolism                      , Folate biosynthesis                              , Metabolism of xenobiotics by cytochrome P450     , Metabolic pathways                               , Chemical carcinogenesis - DNA adducts            , Chemical carcinogenesis - reactive oxygen species
# 2 Arachidonic acid metabolism                 , Metabolism of xenobiotics by cytochrome P450, Metabolic pathways
# 3 Steroid hormone biosynthesis       , Metabolic pathways                 , Ovarian steroidogenesis            , Aldosterone synthesis and secretion, Cortisol synthesis and secretion   , Cushing syndrome
# 4 Steroid hormone biosynthesis       , Metabolic pathways                 , Ovarian steroidogenesis            , Aldosterone synthesis and secretion, Cortisol synthesis and secretion   , Cushing syndrome
# 5 Glycerophospholipid metabolism, Metabolic pathways
# 6 Glycerophospholipid metabolism, Metabolic pathways
#   DBLINKS
# 1 NCBI-GeneID: 873          , NCBI-ProteinID: NP_001748 , OMIM: 114830              , HGNC: 1548                , Ensembl: ENSG00000159228  , Pharos: P16152(Tchem)     , UniProt: P16152 A0A384NL53
# 2 NCBI-GeneID: 874         , NCBI-ProteinID: NP_001227, OMIM: 603608             , HGNC: 1549               , Ensembl: ENSG00000159231 , Pharos: O75828(Tbio)     , UniProt: O75828 V9HW40
# 3 NCBI-GeneID: 1583         , NCBI-ProteinID: NP_000772 , OMIM: 118485              , HGNC: 2590                , Ensembl: ENSG00000140459  , Pharos: P05108(Tclin)     , UniProt: P05108 A0A0S2Z3R3
# 4 NCBI-GeneID: 1583         , NCBI-ProteinID: NP_000772 , OMIM: 118485              , HGNC: 2590                , Ensembl: ENSG00000140459  , Pharos: P05108(Tclin)     , UniProt: P05108 A0A0S2Z3R3
# 5 NCBI-GeneID: 10400       , NCBI-ProteinID: NP_009100, OMIM: 602391             , HGNC: 8830               , Ensembl: ENSG00000133027 , Pharos: Q9UBM1(Tbio)     , UniProt: Q9UBM1
# 6 NCBI-GeneID: 10400       , NCBI-ProteinID: NP_009100, OMIM: 602391             , HGNC: 8830               , Ensembl: ENSG00000133027 , Pharos: Q9UBM1(Tbio)     , UniProt: Q9UBM1
#   MOTIF                                                             rxn
# 1 Pfam: adh_short adh_short_C2 KR Epimerase                         R02581
# 2 Pfam: adh_short adh_short_C2 KR Epimerase DUF6513 Sacchrp_dh_NADP R02581
# 3 Pfam: p450                                                        R02723
# 4 Pfam: p450                                                        R04855
# 5 Pfam: PEMT Herpes_UL74 EptA_B_N                                   R02056
# 6 Pfam: PEMT Herpes_UL74 EptA_B_N                                   R02056
#   Metabolite              KEGG ID sub_class
# 1 PGE2                    C00584  Prostaglandins
# 2 PGE2                    C00584  Prostaglandins
# 3 22R-hydroxy-cholesterol C05502  Oxysterols
# 4 22R-hydroxy-cholesterol C05502  Oxysterols
# 5 PE(40:6)                C00350  PE
# 6 PE(36:3)                C00350  PE
#   Rxn_name
# 1 (5Z,13E)-(15S)-9alpha,11alpha,15-trihydroxyprosta-5,13-dienoate:NADP+ 9-oxidoreductase;, Prostaglandin F2alpha:NADP+ oxidoreductase
# 2 (5Z,13E)-(15S)-9alpha,11alpha,15-trihydroxyprosta-5,13-dienoate:NADP+ 9-oxidoreductase;, Prostaglandin F2alpha:NADP+ oxidoreductase
# 3 NULL
# 4 22beta-Hydroxycholesterol:oxygen oxidoreductase (side-chain-cleaving)
# 5 S-adenosyl-L-methionine:phosphatidylethanolamine N-methyltransferase
# 6 S-adenosyl-L-methionine:phosphatidylethanolamine N-methyltransferase
#   RCLASS
# 1 RC00001  C00005_C00006, RC00154  C00584_C00639
# 2 RC00001  C00005_C00006, RC00154  C00584_C00639
# 3 RC00773  C00187_C05502
# 4 RC00706  C05501_C05502
# 5 RC00003  C00019_C00021, RC00060  C00350_C01241
# 6 RC00003  C00019_C00021, RC00060  C00350_C01241
#   EQUATION
# 1 C00639 + C00006 <=> C00584 + C00005 + C00080
# 2 C00639 + C00006 <=> C00584 + C00005 + C00080
# 3 C00187 + C00007 + 2 C00662 + 2 C00080 <=> C05502 + C00001 + 2 C00667
# 4 C05502 + C00007 + 2 C00662 + 2 C00080 <=> C05501 + C00001 + 2 C00667
# 5 C00019 + C00350 <=> C00021 + C01241
# 6 C00019 + C00350 <=> C00021 + C01241
#   EQUATION_more
# 1 Prostaglandin F2alpha + NADP+ <=> Prostaglandin E2 + NADPH + H+
# 2 Prostaglandin F2alpha + NADP+ <=> Prostaglandin E2 + NADPH + H+
# 3 Cholesterol + Oxygen + 2 Reduced adrenal ferredoxin + 2 H+ <=> 22(R)-Hydroxycholesterol + H2O + 2 Oxidized adrenal ferredoxin
# 4 22(R)-Hydroxycholesterol + Oxygen + 2 Reduced adrenal ferredoxin + 2 H+ <=> 20alpha,22beta-Dihydroxycholesterol + H2O + 2 Oxidized adrenal ferredoxin
# 5 S-Adenosyl-L-methionine + Phosphatidylethanolamine <=> S-Adenosyl-L-homocysteine + Phosphatidyl-N-methylethanolamine
# 6 S-Adenosyl-L-methionine + Phosphatidylethanolamine <=> S-Adenosyl-L-homocysteine + Phosphatidyl-N-methylethanolamine
#   ENZYME
# 1 1.1.1.184, 1.1.1.189
# 2 1.1.1.184, 1.1.1.189
# 3 1.14.15.6
# 4 1.14.15.6
# 5 2.1.1.17
# 6 2.1.1.17

# %% [markdown]
# #### Get the information if metabolite is a reactant or substrate

# %%
rclass_info = react_substrate(met_gene_info)
head(rclass_info)
# Out:
#   orthology_id
# 1 K00079
# 2 K00084
# 3 K00498
# 4 K00498
# 5 K00551
# 6 K00551
#   ORTHOLOGY
# 1 carbonyl reductase 1 [EC:1.1.1.184 1.1.1.189 1.1.1.197]
# 2 carbonyl reductase 3 [EC:1.1.1.184]
# 3 cholesterol monooxygenase (side-chain-cleaving) [EC:1.14.15.6]
# 4 cholesterol monooxygenase (side-chain-cleaving) [EC:1.14.15.6]
# 5 phosphatidylethanolamine/phosphatidyl-N-methylethanolamine N-methyltransferase [EC:2.1.1.17 2.1.1.71]
# 6 phosphatidylethanolamine/phosphatidyl-N-methylethanolamine N-methyltransferase [EC:2.1.1.17 2.1.1.71]
#   gene_id gene_name
# 1 873     (RefSeq) carbonyl reductase 1
# 2 874     (RefSeq) carbonyl reductase 3
# 3 1583    (RefSeq) cytochrome P450 family 11 subfamily A member 1
# 4 1583    (RefSeq) cytochrome P450 family 11 subfamily A member 1
# 5 10400   (RefSeq) phosphatidylethanolamine N-methyltransferase
# 6 10400   (RefSeq) phosphatidylethanolamine N-methyltransferase
#   ORGANISM
# 1 Homo sapiens (human)
# 2 Homo sapiens (human)
# 3 Homo sapiens (human)
# 4 Homo sapiens (human)
# 5 Homo sapiens (human)
# 6 Homo sapiens (human)
#   PATHWAY
# 1 Arachidonic acid metabolism                      , Folate biosynthesis                              , Metabolism of xenobiotics by cytochrome P450     , Metabolic pathways                               , Chemical carcinogenesis - DNA adducts            , Chemical carcinogenesis - reactive oxygen species
# 2 Arachidonic acid metabolism                 , Metabolism of xenobiotics by cytochrome P450, Metabolic pathways
# 3 Steroid hormone biosynthesis       , Metabolic pathways                 , Ovarian steroidogenesis            , Aldosterone synthesis and secretion, Cortisol synthesis and secretion   , Cushing syndrome
# 4 Steroid hormone biosynthesis       , Metabolic pathways                 , Ovarian steroidogenesis            , Aldosterone synthesis and secretion, Cortisol synthesis and secretion   , Cushing syndrome
# 5 Glycerophospholipid metabolism, Metabolic pathways
# 6 Glycerophospholipid metabolism, Metabolic pathways
#   DBLINKS
# 1 NCBI-GeneID: 873          , NCBI-ProteinID: NP_001748 , OMIM: 114830              , HGNC: 1548                , Ensembl: ENSG00000159228  , Pharos: P16152(Tchem)     , UniProt: P16152 A0A384NL53
# 2 NCBI-GeneID: 874         , NCBI-ProteinID: NP_001227, OMIM: 603608             , HGNC: 1549               , Ensembl: ENSG00000159231 , Pharos: O75828(Tbio)     , UniProt: O75828 V9HW40
# 3 NCBI-GeneID: 1583         , NCBI-ProteinID: NP_000772 , OMIM: 118485              , HGNC: 2590                , Ensembl: ENSG00000140459  , Pharos: P05108(Tclin)     , UniProt: P05108 A0A0S2Z3R3
# 4 NCBI-GeneID: 1583         , NCBI-ProteinID: NP_000772 , OMIM: 118485              , HGNC: 2590                , Ensembl: ENSG00000140459  , Pharos: P05108(Tclin)     , UniProt: P05108 A0A0S2Z3R3
# 5 NCBI-GeneID: 10400       , NCBI-ProteinID: NP_009100, OMIM: 602391             , HGNC: 8830               , Ensembl: ENSG00000133027 , Pharos: Q9UBM1(Tbio)     , UniProt: Q9UBM1
# 6 NCBI-GeneID: 10400       , NCBI-ProteinID: NP_009100, OMIM: 602391             , HGNC: 8830               , Ensembl: ENSG00000133027 , Pharos: Q9UBM1(Tbio)     , UniProt: Q9UBM1
#   MOTIF                                                             rxn
# 1 Pfam: adh_short adh_short_C2 KR Epimerase                         R02581
# 2 Pfam: adh_short adh_short_C2 KR Epimerase DUF6513 Sacchrp_dh_NADP R02581
# 3 Pfam: p450                                                        R02723
# 4 Pfam: p450                                                        R04855
# 5 Pfam: PEMT Herpes_UL74 EptA_B_N                                   R02056
# 6 Pfam: PEMT Herpes_UL74 EptA_B_N                                   R02056
#   Metabolite              KEGG ID sub_class
# 1 PGE2                    C00584  Prostaglandins
# 2 PGE2                    C00584  Prostaglandins
# 3 22R-hydroxy-cholesterol C05502  Oxysterols
# 4 22R-hydroxy-cholesterol C05502  Oxysterols
# 5 PE(40:6)                C00350  PE
# 6 PE(36:3)                C00350  PE
#   Rxn_name
# 1 (5Z,13E)-(15S)-9alpha,11alpha,15-trihydroxyprosta-5,13-dienoate:NADP+ 9-oxidoreductase;, Prostaglandin F2alpha:NADP+ oxidoreductase
# 2 (5Z,13E)-(15S)-9alpha,11alpha,15-trihydroxyprosta-5,13-dienoate:NADP+ 9-oxidoreductase;, Prostaglandin F2alpha:NADP+ oxidoreductase
# 3 NULL
# 4 22beta-Hydroxycholesterol:oxygen oxidoreductase (side-chain-cleaving)
# 5 S-adenosyl-L-methionine:phosphatidylethanolamine N-methyltransferase
# 6 S-adenosyl-L-methionine:phosphatidylethanolamine N-methyltransferase
#   RCLASS
# 1 RC00001  C00005_C00006, RC00154  C00584_C00639
# 2 RC00001  C00005_C00006, RC00154  C00584_C00639
# 3 RC00773  C00187_C05502
# 4 RC00706  C05501_C05502
# 5 RC00003  C00019_C00021, RC00060  C00350_C01241
# 6 RC00003  C00019_C00021, RC00060  C00350_C01241
#   EQUATION
# 1 C00639 + C00006 <=> C00584 + C00005 + C00080
# 2 C00639 + C00006 <=> C00584 + C00005 + C00080
# 3 C00187 + C00007 + 2 C00662 + 2 C00080 <=> C05502 + C00001 + 2 C00667
# 4 C05502 + C00007 + 2 C00662 + 2 C00080 <=> C05501 + C00001 + 2 C00667
# 5 C00019 + C00350 <=> C00021 + C01241
# 6 C00019 + C00350 <=> C00021 + C01241
#   EQUATION_more
# 1 Prostaglandin F2alpha + NADP+ <=> Prostaglandin E2 + NADPH + H+
# 2 Prostaglandin F2alpha + NADP+ <=> Prostaglandin E2 + NADPH + H+
# 3 Cholesterol + Oxygen + 2 Reduced adrenal ferredoxin + 2 H+ <=> 22(R)-Hydroxycholesterol + H2O + 2 Oxidized adrenal ferredoxin
# 4 22(R)-Hydroxycholesterol + Oxygen + 2 Reduced adrenal ferredoxin + 2 H+ <=> 20alpha,22beta-Dihydroxycholesterol + H2O + 2 Oxidized adrenal ferredoxin
# 5 S-Adenosyl-L-methionine + Phosphatidylethanolamine <=> S-Adenosyl-L-homocysteine + Phosphatidyl-N-methylethanolamine
# 6 S-Adenosyl-L-methionine + Phosphatidylethanolamine <=> S-Adenosyl-L-homocysteine + Phosphatidyl-N-methylethanolamine
#   ENZYME               reactant_product
# 1 1.1.1.184, 1.1.1.189 Product
# 2 1.1.1.184, 1.1.1.189 Product
# 3 1.14.15.6            Product
# 4 1.14.15.6            Substrate
# 5 2.1.1.17             Substrate
# 6 2.1.1.17             Substrate

# %% [markdown]
# #### Get gene info in short form

# %%
met_gene_info2=data.table::data.table(rclass_info)[,lapply(.SD, function(x) toString(unique(x))), by = 'Metabolite']
