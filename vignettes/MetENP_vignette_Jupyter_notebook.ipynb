# %% [markdown]
# ## MetENP

# %% [markdown]
# MetENP is a R package that enables detection of significant metabolites from metabolite information
# (names or names and concentration along with metadata information) and provides
#
# 1. Enrichment score of metabolite class,
# 2. Maps to pathway of the species of choice,
# 3. Calculate enrichment score of pathways,
# 4. Plots the pathways and shows the metabolite increase or decrease
# 5. Gets gene info, reaction info, enzyme info
#
# For more info, check out the vignette.

# %%
if (!requireNamespace("KEGGREST", quietly = TRUE))
    BiocManager::install("KEGGREST", update = TRUE, ask = FALSE)

if (!requireNamespace("KEGGgraph", quietly = TRUE))
    BiocManager::install("KEGGgraph", update = TRUE, ask = FALSE)

if (!requireNamespace("pathview", quietly = TRUE))
    BiocManager::install("pathview", update = TRUE, ask = FALSE)

#if (!requireNamespace("KEGG.db", quietly = TRUE))
#    BiocManager::install("KEGG.db", update = TRUE, ask = FALSE)

#if (!requireNamespace("MetENP", quietly = TRUE))
#    devtools::install("..", upgrade = "never")
# Out:
# ##############################################################################
# Pathview is an open source software package distributed under GNU General
# Public License version 3 (GPLv3). Details of GPLv3 is available at
# http://www.gnu.org/licenses/gpl-3.0.html. Particullary, users are required to
# formally cite the original Pathview paper (not just mention it) in publications
# or products. For details, do citation("pathview") within R.
#
# The pathview downloads and uses KEGG data. Non-academic uses may require a KEGG
# license agreement (details at http://www.kegg.jp/kegg/legal.html).
# ##############################################################################

# %%
USER_HOME=Sys.getenv("HOME");
USER_PWD=Sys.getenv("PWD");
#.libPaths( c( .libPaths(), paste0(USER_HOME, "/.local/R") ))
.libPaths( c( .libPaths(), paste0(USER_PWD, "/../../R") )); # suitable path to where MetENP R package is installed
#.libPaths( c( .libPaths(), paste0("../../R") )); # suitable path to where MetENP R package is installed

library(MetENP)

# %% [markdown]
# #### If you do not wish to install, alternatively, download from github(https://github.com/metabolomicsworkbench/MetENP) and load libraries and functions

# %%
data = getmwstudies('ST000915', 'data')
head(data)
# Out:
#   analysis_id analysis_summary metabolite_name metabolite_id refmet_name
# 1 AN001485    Core G F....         10 HDoHE    ME230937          10-HDoHE
# 2 AN001485    Core G F....     11,12-di....    ME230961      11,12-Di....
# 3 AN001485    Core G F....        11,12-EET    ME230954      11,12-EpETrE
# 4 AN001485    Core G F....         11b PGE2    ME230914       11beta-PGE2
# 5 AN001485    Core G F....         11 HDoHE    ME230941          11-HDoHE
# 6 AN001485    Core G F....          11-HEPE    ME230917           11-HEPE
#   NASH001 NASH002 NASH003 NASH004 NASH005 ⋯ NASH082 NASH083 NASH084 NASH085
# 1 0.00419 0.01396 0.00285 0.00705 0.00020 ⋯ 0.00073 0.00641 0.00667 0.00143
# 2 0.01346 1.84739 0.63897 1.87466 0.21119 ⋯ 0.06045 0.03386 0.01953 0.02720
# 3 0.20666 0.12915 0.18170 0.11368 0.06081 ⋯ 0.97974 0.66245 0.19845 0.30318
# 4 0.00048 0.00128 NA      NA      NA      ⋯ 0.00098 0.00206 0.00076 0.00213
# 5 0.00617 0.03174 0.00958 0.00593 0.00271 ⋯ 0.01842 0.01902 0.01049 0.00151
# 6 0.00642 NA      0.01625 0.02049 0.00115 ⋯ 0.02481 0.00969 0.00109 NA
#   NASH086 NASH087 NASH088 NASH089 NASH090 NASH091
# 1 0.02844 0.02243 0.00915 0.00366 0.00208 0.00144
# 2 0.02104 0.06057 0.03444 0.01259 0.02891 0.05983
# 3 0.37735 0.67719 0.64060 0.39347 0.22317 0.38579
# 4 0.00093 0.02040 0.02086 0.00070 0.00136 0.00969
# 5 0.02371 0.03326 0.00267 0.00232 NA      0.00584
# 6 0.02083 0.00539 0.00666 0.00745 0.01074 0.00425

# %%
metadata = getmwstudies('ST000915', 'factors')
head(metadata)
# Out:
#   study_id local_sample_id sample_source factors      mb_sample_id raw_data
# 1 ST000915 NASH005         Liver         Diagnosi.... SA053807
# 2 ST000915 NASH007         Liver         Diagnosi.... SA053815
# 3 ST000915 NASH009         Liver         Diagnosi.... SA053817
# 4 ST000915 NASH013         Liver         Diagnosi.... SA053813
# 5 ST000915 NASH016         Liver         Diagnosi.... SA053812
# 6 ST000915 NASH022         Liver         Diagnosi.... SA053816
#   Diagnosis
# 1 Cirrhosis
# 2 Cirrhosis
# 3 Cirrhosis
# 4 Cirrhosis
# 5 Cirrhosis
# 6 Cirrhosis

# %% [markdown]
# Find the factors you would want to compare
# Multiple factors (independent variables) are formatted in multiple columns but you can get information on all the factors by "factors" column, such as 'TreatmentGroup:Prednisolone', this indicates column name 'TreatmentGroup' with factor Prednisolone. For t-test use the factors in the same column. For comparing multipe independent variables use anova by anova_ana function.

# %% [markdown]
# ### Associate metabolomics data to the refmet class

# %%
refmet_class= convert_refmet(data)
head(refmet_class)
# Out:
#   metabolite_name analysis_id analysis_summary metabolite_id refmet_name
# 1 1,2-DG(30:0)    AN001488    Core E N....     ME231190      1,2-DG 30:0
# 2 1,2-DG(30:1)    AN001488    Core E N....     ME231189      1,2-DG 30:1
# 3 1,2-DG(32:0)    AN001488    Core E N....     ME231196      1,2-DG 32:0
# 4 1,2-DG(32:1)    AN001488    Core E N....     ME231195      1,2-DG 32:1
# 5 1,2-DG(32:2)    AN001488    Core E N....     ME231194      1,2-DG 32:2
# 6 1,2-DG(32:3)    AN001488    Core E N....     ME231193      1,2-DG 32:3
#   NASH001 NASH002 NASH003 NASH004 NASH005 ⋯ NASH086 NASH087 NASH088 NASH089
# 1 2.7     NA      NA      NA      NA      ⋯ 38.3    68.2    87.9    33.1
# 2 1.8     NA      NA      NA      NA      ⋯ 36.9    24.2    34.9    15.2
# 3 12.2    7.1     2.2     2.0     1.4     ⋯ 160.3   221.6   300.8   115.0
# 4 7.6     5.7     2.1     1.4     1.1     ⋯ 226.4   134.5   217.6   88.8
# 5 2.0     1.9     NA      NA      NA      ⋯ 111.6   77.9    125.3   63.7
# 6 NA      NA      NA      NA      NA      ⋯ 11.3    7.8     16.1    8.5
#   NASH090 NASH091 formula  super_class   main_class       sub_class
# 1 45.7    9.2     C33H64O5 Glycerolipids Diradylglycerols DG
# 2 26.0    5.5     C33H62O5 Glycerolipids Diradylglycerols DG
# 3 200.2   29.4    C35H68O5 Glycerolipids Diradylglycerols DG
# 4 151.2   26.5    C35H66O5 Glycerolipids Diradylglycerols DG
# 5 92.7    18.6    C35H64O5 Glycerolipids Diradylglycerols DG
# 6 11.4    3.8     C35H62O5 Glycerolipids Diradylglycerols DG

# %%
unique(metadata$factors)
# Out:
# [[1]]
# [1] "Diagnosis:Cirrhosis"
#
# [[2]]
# [1] "Diagnosis:NASH"
#
# [[3]]
# [1] "Diagnosis:Normal"
#
# [[4]]
# [1] "Diagnosis:Steatosis"

# %%
### Find the analysis mode
unique(data$analysis_summary)
# Out:
# [[1]]
# [1] "Core G Fatty acids/Eicosanoids"
#
# [[2]]
# [1] "Core J Sterols"
#
# [[3]]
# [1] "Core K Prenols/Cardiolipins"
#
# [[4]]
# [1] "Core E Neutral Lipids"
#
# [[5]]
# [1] "Core I Sphingolipids"
#
# [[6]]
# [1] "Core H Phospholipids"

# %% [markdown]
# ### Find significant metabolites, run significance of all the analysis summary together. The analysis summary/modes you got in the previous section
# There is a normalization step which takes into account missing values, and this can be achieved via three methods:
#
# 1) half_of_min: where the NAs are replaced by half of min values in the data
#
# 2) remove_NAs: where Cols with NAs values are removed
#
# 3) 50percent: where cols with more than 50% NAs values are removed, and then the remaining NA values are replaced with half_of_min
#
# half_of_min is ideal when you wish to see which metabolites were present in either group. Very high fold change would mean it was present in either group.

# %%
stats_metabolites = significant_met(metabolomics_data=refmet_class, met_col="metabolite_name",analysis_type=c("Core G Fatty acids/Eicosanoids","Core J Sterols","Core K Prenols/Cardiolipins","Core E Neutral Lipids","Core I Sphingolipids","Core H Phospholipids"), metadata=metadata, factor1='Cirrhosis', factor2=c('Normal'), factor_col='Diagnosis',sample_col='local_sample_id', p_adjust='fdr',normalization="50percent")

sig_metabolites = stats_metabolites[which(stats_metabolites[,"pval"] <= 0.05&abs(stats_metabolites[,"log2Fold_change"])>0.5),]

# %%
plot_volcano(stats_metabolites, thres_pval= 0.05,thres_log2foldchange = 0.5, TRUE)
# Out:
# Warning message:
# “ggrepel: 57 unlabeled data points (too many overlaps). Consider increasing max.overlaps”
# plot without title

# %% [markdown]
# ### Map metabolite class of the significant metabolites utilzing refmet classification in Metabolomics Workbench
# This function not only maps metabolite to metabolite class but also to external databases such as pubchem, inchi key, smiles and kegg
#
# In this example, we will go forward with significant metabolite obtained by t-test/

# %%
sig_metabolites_kegg_id= map_keggid(sig_metabolites)

# %% [markdown]
# #### Check all your significant metabolites have not been assigned metabolite class

# %%
setdiff(sig_metabolites$refmet_name, sig_metabolites_kegg_id$refmet_name)
# Out:
# [1] ""          "PE P-36:4"

# %% [markdown]
# ### Count metabolites in each of the metabolite class and plotting
# You may choose from sub_class, main_class and super_class

# %%
count_changes = metcountplot(df_metclass=sig_metabolites_kegg_id, metclass='sub_class', plotting=TRUE, thres_logfC = 0.0, updown_fillcolor=c("red", "green"))
print(count_changes$sig_met_count)
# Out:
#             sub_class No.of_metabolites                 color
# 1          1-deoxyCer                 5 increased metabolites
# 2                 BMP                 2 increased metabolites
# 3                 Cer                 6 increased metabolites
# 4        Chol. esters                 5 increased metabolites
# 5        Cholesterols                 1 increased metabolites
# 6                  CL                 3 increased metabolites
# 7                  DG                 9 increased metabolites
# 8         Docosanoids                 3 increased metabolites
# 9           Dolichols                 4 increased metabolites
# 10             EpETrE                 4 increased metabolites
# 11               HEPE                 1 increased metabolites
# 12               HETE                 1 increased metabolites
# 13             HexCer                 5 increased metabolites
# 14                LPC                 1 increased metabolites
# 15                LPG                 2 increased metabolites
# 16         Oxysterols                 1 increased metabolites
# 17                 PA                 2 increased metabolites
# 18                 PC                 1 increased metabolites
# 19                 PE                 2 increased metabolites
# 20     Prostaglandins                 1 increased metabolites
# 21                 PS                 1 increased metabolites
# 22       Saturated FA                 1 increased metabolites
# 23                 SM                 3 increased metabolites
# 24 Sphingoid base 1-P                 1 increased metabolites
# 25       Sphingosines                 1 increased metabolites
# 26                 TG                 3 increased metabolites
# 27       Cholesterols                -2 decreased metabolites
# 28              DHCer                -1 decreased metabolites
# 29              HETrE                -1 decreased metabolites
# 30         Oxysterols                -1 decreased metabolites
# 31                 PE                -2 decreased metabolites
# 32                 PI                -2 decreased metabolites
# 33     Prostaglandins                -1 decreased metabolites
# 34                 PS                -3 decreased metabolites
# 35                 SM                -1 decreased metabolites

# %%
count_changes$plotimg
# Out:
# Warning message:
# “Use of `count_changes[[metclass]]` is discouraged.
# ℹ Use `.data[[metclass]]` instead.”
# plot without title

# %% [markdown]
# ### Enrichment class score
#
# Calculate the enrichment score of each metabolite class. Enrichment score is calculated through hypergeometric method. One can specify the no. of significant metabolites in a class while calculating the enrichment score. We advice to use the number of mtabolites in each class as 3 or more. But if someone just wants to know the enrichment score and rest of the information of all the metabolites, then they can choose the number as 1.

# %%
# pass debug = 0 below or comment some lines to suppress some print output
metenrichment = metclassenrichment(df_metclass=sig_metabolites_kegg_id,refmet_class, metclass="sub_class",enrich_stats="HG",no=1, debug = 1)
print(head(metenrichment))
#knitr::kable(head(metenrichment))
metenrichment[metenrichment$main_class %in% c("Ceramides", "Sphingomyelins"), c("Metabolite", "pval", "super_class", "main_class", "sub_class", "HG p-value")]
colnames(metenrichment)
metenrichment$super_class
metenrichment$main_class
metenrichment$sub_class
# Out:
# [1] "Name = 1-DeoxyCer 18:0;O/16:0"
# [1] "M = 5"                  "L = 83"                 "N = 542"
# [4] "k = 23"                 "pp = 0.267593457555431"
# [1] "Name = 1-DeoxyCer 18:0;O/18:0"
# [1] "M = 5"                  "L = 83"                 "N = 542"
# [4] "k = 23"                 "pp = 0.267593457555431"
# [1] "Name = 1-DeoxyCer 18:0;O/20:0"
# [1] "M = 5"                  "L = 83"                 "N = 542"
# [4] "k = 23"                 "pp = 0.267593457555431"
# [1] "Name = 1-DeoxyCer 18:0;O/22:0"
# [1] "M = 5"                  "L = 83"                 "N = 542"
# [4] "k = 23"                 "pp = 0.267593457555431"
# [1] "Name = 1-DeoxyCer 18:0;O/24:0"
# [1] "M = 5"                  "L = 83"                 "N = 542"
# [4] "k = 23"                 "pp = 0.267593457555431"
# [1] "Name = 1,2-DG 32:0"
# [1] "M = 9"                  "L = 83"                 "N = 542"
# [4] "k = 54"                 "pp = 0.448783812992083"
# [1] "Name = 1,2-DG 32:1"
# [1] "M = 9"                  "L = 83"                 "N = 542"
# [4] "k = 54"                 "pp = 0.448783812992083"
# [1] "Name = 1,2-DG 34:0"
# [1] "M = 9"                  "L = 83"                 "N = 542"
# [4] "k = 54"                 "pp = 0.448783812992083"
# [1] "Name = 1,2-DG 34:1"
# [1] "M = 9"                  "L = 83"                 "N = 542"
# [4] "k = 54"                 "pp = 0.448783812992083"
# [1] "Name = 1,2-DG 34:2"
# [1] "M = 9"                  "L = 83"                 "N = 542"
# [4] "k = 54"                 "pp = 0.448783812992083"
# [1] "Name = 1,2-DG 36:1"
# [1] "M = 9"                  "L = 83"                 "N = 542"
# [4] "k = 54"                 "pp = 0.448783812992083"
# [1] "Name = 1,2-DG 36:2"
# [1] "M = 9"                  "L = 83"                 "N = 542"
# [4] "k = 54"                 "pp = 0.448783812992083"
# [1] "Name = 1,2-DG 36:3"
# [1] "M = 9"                  "L = 83"                 "N = 542"
# [4] "k = 54"                 "pp = 0.448783812992083"
# [1] "Name = 1,2-DG 36:4"
# [1] "M = 9"                  "L = 83"                 "N = 542"
# [4] "k = 54"                 "pp = 0.448783812992083"
# [1] "Name = 11,12-EpETrE"
# [1] "M = 4"                   "L = 83"
# [3] "N = 542"                 "k = 11"
# [5] "pp = 0.0719786680891102"
# [1] "Name = 12-HEPE"
# [1] "M = 1"                  "L = 83"                 "N = 542"
# [4] "k = 11"                 "pp = 0.842288202643916"
# [1] "Name = 12-HETE"
# [1] "M = 1"                  "L = 83"                 "N = 542"
# [4] "k = 20"                 "pp = 0.966271564581372"
# [1] "Name = 14-HDoHE"
# [1] "M = 3"                 "L = 83"                "N = 542"
# [4] "k = 15"                "pp = 0.41003637426933"
# [1] "Name = 14,15-EpETrE"
# [1] "M = 4"                   "L = 83"
# [3] "N = 542"                 "k = 11"
# [5] "pp = 0.0719786680891102"
# [1] "Name = 15-HETrE"
# [1] "M = 1"                  "L = 83"                 "N = 542"
# [4] "k = 15"                 "pp = 0.920258462922311"
# [1] "Name = 16-HDoHE"
# [1] "M = 3"                 "L = 83"                "N = 542"
# [4] "k = 15"                "pp = 0.41003637426933"
# [1] "Name = 22R-Hydroxycholesterol"
# [1] "M = 2"                 "L = 83"                "N = 542"
# [4] "k = 19"                "pp = 0.81654574861412"
# [1] "Name = 25-Hydroxycholesterol"
# [1] "M = 2"                 "L = 83"                "N = 542"
# [4] "k = 19"                "pp = 0.81654574861412"
# [1] "Name = 4-HDoHE"
# [1] "M = 3"                 "L = 83"                "N = 542"
# [4] "k = 15"                "pp = 0.41003637426933"
# [1] "Name = 5,6-EpETrE"
# [1] "M = 4"                   "L = 83"
# [3] "N = 542"                 "k = 11"
# [5] "pp = 0.0719786680891102"
# [1] "Name = 6-Keto-PGF1alpha"
# [1] "M = 2"                  "L = 83"                 "N = 542"
# [4] "k = 21"                 "pp = 0.859012555395696"
# [1] "Name = 8,9-EpETrE"
# [1] "M = 4"                   "L = 83"
# [3] "N = 542"                 "k = 11"
# [5] "pp = 0.0719786680891102"
# [1] "Name = BMP 40:7"
# [1] "M = 2"                  "L = 83"                 "N = 542"
# [4] "k = 13"                 "pp = 0.616887485915176"
# [1] "Name = BMP 40:8"
# [1] "M = 2"                  "L = 83"                 "N = 542"
# [4] "k = 13"                 "pp = 0.616887485915176"
# [1] "Name = CE 18:2"
# [1] "M = 5"                  "L = 83"                 "N = 542"
# [4] "k = 29"                 "pp = 0.465174078602382"
# [1] "Name = CE 18:3"
# [1] "M = 5"                  "L = 83"                 "N = 542"
# [4] "k = 29"                 "pp = 0.465174078602382"
# [1] "Name = CE 20:3"
# [1] "M = 5"                  "L = 83"                 "N = 542"
# [4] "k = 29"                 "pp = 0.465174078602382"
# [1] "Name = CE 20:4"
# [1] "M = 5"                  "L = 83"                 "N = 542"
# [4] "k = 29"                 "pp = 0.465174078602382"
# [1] "Name = CE 22:6"
# [1] "M = 5"                  "L = 83"                 "N = 542"
# [4] "k = 29"                 "pp = 0.465174078602382"
# [1] "Name = Cer 18:0;O2/24:1"
# [1] "M = 1"                  "L = 83"                 "N = 542"
# [4] "k = 17"                 "pp = 0.943418437057147"
# [1] "Name = Cer 18:1;O2/18:0"
# [1] "M = 6"                   "L = 83"
# [3] "N = 542"                 "k = 17"
# [5] "pp = 0.0325520860627767"
# [1] "Name = Cer 18:1;O2/18:1"
# [1] "M = 6"                   "L = 83"
# [3] "N = 542"                 "k = 17"
# [5] "pp = 0.0325520860627767"
# [1] "Name = Cer 18:1;O2/20:0"
# [1] "M = 6"                   "L = 83"
# [3] "N = 542"                 "k = 17"
# [5] "pp = 0.0325520860627767"
# [1] "Name = Cer 18:1;O2/22:0"
# [1] "M = 6"                   "L = 83"
# [3] "N = 542"                 "k = 17"
# [5] "pp = 0.0325520860627767"
# [1] "Name = Cer 18:1;O2/24:0"
# [1] "M = 6"                   "L = 83"
# [3] "N = 542"                 "k = 17"
# [5] "pp = 0.0325520860627767"
# [1] "Name = Cer 18:1;O2/26:0"
# [1] "M = 6"                   "L = 83"
# [3] "N = 542"                 "k = 17"
# [5] "pp = 0.0325520860627767"
# [1] "Name = CL 72:8"
# [1] "M = 3"                  "L = 83"                 "N = 542"
# [4] "k = 11"                 "pp = 0.229409464469949"
# [1] "Name = CL 74:7"
# [1] "M = 3"                  "L = 83"                 "N = 542"
# [4] "k = 11"                 "pp = 0.229409464469949"
# [1] "Name = CL 74:8"
# [1] "M = 3"                  "L = 83"                 "N = 542"
# [4] "k = 11"                 "pp = 0.229409464469949"
# [1] "Name = Desmosterol"
# [1] "M = 3"                  "L = 83"                 "N = 542"
# [4] "k = 21"                 "pp = 0.649126176057361"
# [1] "Name = Dihydrocholesterol"
# [1] "M = 3"                  "L = 83"                 "N = 542"
# [4] "k = 21"                 "pp = 0.649126176057361"
# [1] "Name = Dolichol-17"
# [1] "M = 4"                   "L = 83"
# [3] "N = 542"                 "k = 11"
# [5] "pp = 0.0719786680891102"
# [1] "Name = Dolichol-18"
# [1] "M = 4"                   "L = 83"
# [3] "N = 542"                 "k = 11"
# [5] "pp = 0.0719786680891102"
# [1] "Name = Dolichol-19"
# [1] "M = 4"                   "L = 83"
# [3] "N = 542"                 "k = 11"
# [5] "pp = 0.0719786680891102"
# [1] "Name = Dolichol-20"
# [1] "M = 4"                   "L = 83"
# [3] "N = 542"                 "k = 11"
# [5] "pp = 0.0719786680891102"
# [1] "Name = GalCer 18:1;O2/24:0"
# [1] "M = 5"                  "L = 83"                 "N = 542"
# [4] "k = 47"                 "pp = 0.877151508594684"
# [1] "Name = GlcCer 18:1;O2/22:0"
# [1] "M = 5"                  "L = 83"                 "N = 542"
# [4] "k = 47"                 "pp = 0.877151508594684"
# [1] "Name = GlcCer 18:1;O2/24:0"
# [1] "M = 5"                  "L = 83"                 "N = 542"
# [4] "k = 47"                 "pp = 0.877151508594684"
# [1] "Name = HexCer 18:1;O2/22:0"
# [1] "M = 5"                  "L = 83"                 "N = 542"
# [4] "k = 47"                 "pp = 0.877151508594684"
# [1] "Name = HexCer 18:1;O2/24:0"
# [1] "M = 5"                  "L = 83"                 "N = 542"
# [4] "k = 47"                 "pp = 0.877151508594684"
# [1] "Name = Lanosterol"
# [1] "M = 3"                  "L = 83"                 "N = 542"
# [4] "k = 21"                 "pp = 0.649126176057361"
# [1] "Name = Lignoceric acid"
# [1] "M = 1"                  "L = 83"                 "N = 542"
# [4] "k = 17"                 "pp = 0.943418437057147"
# [1] "Name = LPC 18:0"
# [1] "M = 1"                  "L = 83"                 "N = 542"
# [4] "k = 12"                 "pp = 0.866939952513134"
# [1] "Name = LPG 18:1"
# [1] "M = 2"                  "L = 83"                 "N = 542"
# [4] "k = 9"                  "pp = 0.412071593873442"
# [1] "Name = LPG 18:2"
# [1] "M = 2"                  "L = 83"                 "N = 542"
# [4] "k = 9"                  "pp = 0.412071593873442"
# [1] "Name = PA 40:5"
# [1] "M = 2"                  "L = 83"                 "N = 542"
# [4] "k = 22"                 "pp = 0.876738084552868"
# [1] "Name = PA 40:6"
# [1] "M = 2"                  "L = 83"                 "N = 542"
# [4] "k = 22"                 "pp = 0.876738084552868"
# [1] "Name = PC 36:4"
# [1] "M = 1"                  "L = 83"                 "N = 542"
# [4] "k = 28"                 "pp = 0.991645947098045"
# [1] "Name = PE 32:1"
# [1] "M = 4"                  "L = 83"                 "N = 542"
# [4] "k = 29"                 "pp = 0.674885256564868"
# [1] "Name = PE 36:3"
# [1] "M = 4"                  "L = 83"                 "N = 542"
# [4] "k = 29"                 "pp = 0.674885256564868"
# [1] "Name = PE 38:6"
# [1] "M = 4"                  "L = 83"                 "N = 542"
# [4] "k = 29"                 "pp = 0.674885256564868"
# [1] "Name = PE 40:6"
# [1] "M = 4"                  "L = 83"                 "N = 542"
# [4] "k = 29"                 "pp = 0.674885256564868"
# [1] "Name = PGE2"
# [1] "M = 2"                  "L = 83"                 "N = 542"
# [4] "k = 21"                 "pp = 0.859012555395696"
# [1] "Name = PI 36:3"
# [1] "M = 2"                  "L = 83"                 "N = 542"
# [4] "k = 21"                 "pp = 0.859012555395696"
# [1] "Name = PI 38:5"
# [1] "M = 2"                  "L = 83"                 "N = 542"
# [4] "k = 21"                 "pp = 0.859012555395696"
# [1] "Name = PS 34:1"
# [1] "M = 4"                  "L = 83"                 "N = 542"
# [4] "k = 20"                 "pp = 0.367094901397738"
# [1] "Name = PS 36:2"
# [1] "M = 4"                  "L = 83"                 "N = 542"
# [4] "k = 20"                 "pp = 0.367094901397738"
# [1] "Name = PS 36:3"
# [1] "M = 4"                  "L = 83"                 "N = 542"
# [4] "k = 20"                 "pp = 0.367094901397738"
# [1] "Name = PS 40:6"
# [1] "M = 4"                  "L = 83"                 "N = 542"
# [4] "k = 20"                 "pp = 0.367094901397738"
# [1] "Name = SM 18:0;O2/16:0"
# [1] "M = 4"                  "L = 83"                 "N = 542"
# [4] "k = 24"                 "pp = 0.515169603961559"
# [1] "Name = SM 18:1;O2/18:1"
# [1] "M = 4"                  "L = 83"                 "N = 542"
# [4] "k = 24"                 "pp = 0.515169603961559"
# [1] "Name = SM 18:1;O2/20:0"
# [1] "M = 4"                  "L = 83"                 "N = 542"
# [4] "k = 24"                 "pp = 0.515169603961559"
# [1] "Name = SM 18:1;O2/22:0"
# [1] "M = 4"                  "L = 83"                 "N = 542"
# [4] "k = 24"                 "pp = 0.515169603961559"
# [1] "Name = Sphingosine"
# [1] "M = 1"                  "L = 83"                 "N = 542"
# [4] "k = 8"                  "pp = 0.737935084414372"
# [1] "Name = Sphingosine 1-phosphate"
# [1] "M = 1"                  "L = 83"                 "N = 542"
# [4] "k = 9"                  "pp = 0.778668020731988"
# [1] "Name = TG 51:1"
# [1] "M = 3"                  "L = 83"                 "N = 542"
# [4] "k = 127"                "pp = 0.999999985979489"
# [1] "Name = TG 52:1"
# [1] "M = 3"                  "L = 83"                 "N = 542"
# [4] "k = 127"                "pp = 0.999999985979489"
# [1] "Name = TG 52:3"
# [1] "M = 3"                  "L = 83"                 "N = 542"
# [4] "k = 127"                "pp = 0.999999985979489"
#              refmet_name Exact mass KEGG ID       Metabolite Cirrhosis_mean
# 1 1-DeoxyCer 18:0;O/16:0   523.5328         C16DH 1-deoxyCer     0.05623685
# 2 1-DeoxyCer 18:0;O/18:0   551.5641         C18DH 1-deoxyCer      0.0906803
# 3 1-DeoxyCer 18:0;O/20:0   579.5954         C20DH 1-deoxyCer      0.0723488
# 4 1-DeoxyCer 18:0;O/22:0   607.6267         C22DH 1-deoxyCer      0.1513816
# 5 1-DeoxyCer 18:0;O/24:0   635.6580         C24DH 1-deoxyCer      0.1177141
# 6            1,2-DG 32:0   568.5067  C00641     1,2-DG(32:0)       210.0625
#   Normal_mean Fold_change log2Fold_change   t_value         pval        padj
# 1  0.12178748    2.165617        1.114778 -3.028001 0.0044113841 0.025170838
# 2   0.2566956    2.830776        1.501197 -3.826879 0.0005219699 0.005671347
# 3   0.1756429    2.427724        1.279604 -3.268230 0.0023663363 0.015081843
# 4   0.4227716    2.792754        1.481689 -3.604410 0.0009458421 0.007645557
# 5   0.3056195    2.596286        1.376449 -2.746084 0.0091800137 0.046866386
# 6    479.9210    2.284658        1.191978 -2.410346 0.0200253888 0.106653539
#   metabolite_id   super_class       main_class  sub_class   formula HG p-value
# 1      ME231305 Sphingolipids        Ceramides 1-deoxyCer C34H69NO2  0.2675935
# 2      ME231306 Sphingolipids        Ceramides 1-deoxyCer C36H73NO2  0.2675935
# 3      ME231307 Sphingolipids        Ceramides 1-deoxyCer C38H77NO2  0.2675935
# 4      ME231308 Sphingolipids        Ceramides 1-deoxyCer C40H81NO2  0.2675935
# 5      ME231310 Sphingolipids        Ceramides 1-deoxyCer C42H85NO2  0.2675935
# 6      ME231196 Glycerolipids Diradylglycerols         DG  C35H68O5  0.4487838
#    Metabolite       pval         super_class   main_class sub_class  HG p-value
# 1  C16DH 1-deoxyCer 4.411384e-03 Sphingolipids Ceramides  1-deoxyCer 0.26759346
# 2  C18DH 1-deoxyCer 5.219699e-04 Sphingolipids Ceramides  1-deoxyCer 0.26759346
# 3  C20DH 1-deoxyCer 2.366336e-03 Sphingolipids Ceramides  1-deoxyCer 0.26759346
# 4  C22DH 1-deoxyCer 9.458421e-04 Sphingolipids Ceramides  1-deoxyCer 0.26759346
# 5  C24DH 1-deoxyCer 9.180014e-03 Sphingolipids Ceramides  1-deoxyCer 0.26759346
# 35 C24:1DH Cer      4.727138e-02 Sphingolipids Ceramides  DHCer      0.94341844
# 36 C18 Cer          2.759931e-04 Sphingolipids Ceramides  Cer        0.03255209
# 37 C18:1 Cer        5.261088e-03 Sphingolipids Ceramides  Cer        0.03255209
# 38 C20 Cer          3.586497e-04 Sphingolipids Ceramides  Cer        0.03255209
# 39 C22 Cer          1.351778e-05 Sphingolipids Ceramides  Cer        0.03255209
# 40 C24 Cer          1.231257e-04 Sphingolipids Ceramides  Cer        0.03255209
# 41 C26 Cer          4.782389e-02 Sphingolipids Ceramides  Cer        0.03255209
#  [1] "refmet_name"     "Exact mass"      "KEGG ID"         "Metabolite"
#  [5] "Cirrhosis_mean"  "Normal_mean"     "Fold_change"     "log2Fold_change"
#  [9] "t_value"         "pval"            "padj"            "metabolite_id"
# [13] "super_class"     "main_class"      "sub_class"       "formula"
# [17] "HG p-value"
#  [1] "Sphingolipids"        "Sphingolipids"        "Sphingolipids"
#  [4] "Sphingolipids"        "Sphingolipids"        "Glycerolipids"
#  [7] "Glycerolipids"        "Glycerolipids"        "Glycerolipids"
# [10] "Glycerolipids"        "Glycerolipids"        "Glycerolipids"
# [13] "Glycerolipids"        "Glycerolipids"        "Fatty Acyls"
# [16] "Fatty Acyls"          "Fatty Acyls"          "Fatty Acyls"
# [19] "Fatty Acyls"          "Fatty Acyls"          "Fatty Acyls"
# [22] "Sterol Lipids"        "Sterol Lipids"        "Fatty Acyls"
# [25] "Fatty Acyls"          "Fatty Acyls"          "Fatty Acyls"
# [28] "Glycerophospholipids" "Glycerophospholipids" "Sterol Lipids"
# [31] "Sterol Lipids"        "Sterol Lipids"        "Sterol Lipids"
# [34] "Sterol Lipids"        "Sphingolipids"        "Sphingolipids"
# [37] "Sphingolipids"        "Sphingolipids"        "Sphingolipids"
# [40] "Sphingolipids"        "Sphingolipids"        "Glycerophospholipids"
# [43] "Glycerophospholipids" "Glycerophospholipids" "Sterol Lipids"
# [46] "Sterol Lipids"        "Prenol Lipids"        "Prenol Lipids"
# [49] "Prenol Lipids"        "Prenol Lipids"        "Sphingolipids"
# [52] "Sphingolipids"        "Sphingolipids"        "Sphingolipids"
# [55] "Sphingolipids"        "Sterol Lipids"        "Fatty Acyls"
# [58] "Glycerophospholipids" "Glycerophospholipids" "Glycerophospholipids"
# [61] "Glycerophospholipids" "Glycerophospholipids" "Glycerophospholipids"
# [64] "Glycerophospholipids" "Glycerophospholipids" "Glycerophospholipids"
# [67] "Glycerophospholipids" "Fatty Acyls"          "Glycerophospholipids"
# [70] "Glycerophospholipids" "Glycerophospholipids" "Glycerophospholipids"
# [73] "Glycerophospholipids" "Glycerophospholipids" "Sphingolipids"
# [76] "Sphingolipids"        "Sphingolipids"        "Sphingolipids"
# [79] "Sphingolipids"        "Sphingolipids"        "Glycerolipids"
# [82] "Glycerolipids"        "Glycerolipids"
#  [1] "Ceramides"                   "Ceramides"
#  [3] "Ceramides"                   "Ceramides"
#  [5] "Ceramides"                   "Diradylglycerols"
#  [7] "Diradylglycerols"            "Diradylglycerols"
#  [9] "Diradylglycerols"            "Diradylglycerols"
# [11] "Diradylglycerols"            "Diradylglycerols"
# [13] "Diradylglycerols"            "Diradylglycerols"
# [15] "Eicosanoids"                 "Eicosanoids"
# [17] "Eicosanoids"                 "Docosanoids"
# [19] "Eicosanoids"                 "Eicosanoids"
# [21] "Docosanoids"                 "Sterols"
# [23] "Sterols"                     "Docosanoids"
# [25] "Eicosanoids"                 "Eicosanoids"
# [27] "Eicosanoids"                 "Glycerophosphoglycerols"
# [29] "Glycerophosphoglycerols"     "Sterol esters"
# [31] "Sterol esters"               "Sterol esters"
# [33] "Sterol esters"               "Sterol esters"
# [35] "Ceramides"                   "Ceramides"
# [37] "Ceramides"                   "Ceramides"
# [39] "Ceramides"                   "Ceramides"
# [41] "Ceramides"                   "Cardiolipins"
# [43] "Cardiolipins"                "Cardiolipins"
# [45] "Sterols"                     "Sterols"
# [47] "Polyprenols"                 "Polyprenols"
# [49] "Polyprenols"                 "Polyprenols"
# [51] "Glycosphingolipids"          "Glycosphingolipids"
# [53] "Glycosphingolipids"          "Glycosphingolipids"
# [55] "Glycosphingolipids"          "Sterols"
# [57] "Fatty acids"                 "Glycerophosphocholines"
# [59] "Glycerophosphoglycerols"     "Glycerophosphoglycerols"
# [61] "Glycerophosphates"           "Glycerophosphates"
# [63] "Glycerophosphocholines"      "Glycerophosphoethanolamines"
# [65] "Glycerophosphoethanolamines" "Glycerophosphoethanolamines"
# [67] "Glycerophosphoethanolamines" "Eicosanoids"
# [69] "Glycerophosphoinositols"     "Glycerophosphoinositols"
# [71] "Glycerophosphoserines"       "Glycerophosphoserines"
# [73] "Glycerophosphoserines"       "Glycerophosphoserines"
# [75] "Phosphosphingolipids"        "Phosphosphingolipids"
# [77] "Phosphosphingolipids"        "Phosphosphingolipids"
# [79] "Sphingoid bases"             "Sphingoid bases"
# [81] "Triradylglycerols"           "Triradylglycerols"
# [83] "Triradylglycerols"
#  [1] "1-deoxyCer"         "1-deoxyCer"         "1-deoxyCer"
#  [4] "1-deoxyCer"         "1-deoxyCer"         "DG"
#  [7] "DG"                 "DG"                 "DG"
# [10] "DG"                 "DG"                 "DG"
# [13] "DG"                 "DG"                 "EpETrE"
# [16] "HEPE"               "HETE"               "Docosanoids"
# [19] "EpETrE"             "HETrE"              "Docosanoids"
# [22] "Oxysterols"         "Oxysterols"         "Docosanoids"
# [25] "EpETrE"             "Prostaglandins"     "EpETrE"
# [28] "BMP"                "BMP"                "Chol. esters"
# [31] "Chol. esters"       "Chol. esters"       "Chol. esters"
# [34] "Chol. esters"       "DHCer"              "Cer"
# [37] "Cer"                "Cer"                "Cer"
# [40] "Cer"                "Cer"                "CL"
# [43] "CL"                 "CL"                 "Cholesterols"
# [46] "Cholesterols"       "Dolichols"          "Dolichols"
# [49] "Dolichols"          "Dolichols"          "HexCer"
# [52] "HexCer"             "HexCer"             "HexCer"
# [55] "HexCer"             "Cholesterols"       "Saturated FA"
# [58] "LPC"                "LPG"                "LPG"
# [61] "PA"                 "PA"                 "PC"
# [64] "PE"                 "PE"                 "PE"
# [67] "PE"                 "Prostaglandins"     "PI"
# [70] "PI"                 "PS"                 "PS"
# [73] "PS"                 "PS"                 "SM"
# [76] "SM"                 "SM"                 "SM"
# [79] "Sphingosines"       "Sphingoid base 1-P" "TG"
# [82] "TG"                 "TG"

# %% [markdown]
# #### Plot the enrichment score via function plot_met_enrichment

# %%
plot_met_enrichment(metenrichment, "sub_class","HG", no=3)
# Out:
# Warning message:
# “Use of `metclass_stats[[metclass]]` is discouraged.
# ℹ Use `.data[[metclass]]` instead.”
# Warning message:
# “Use of `metclass_stats[[enrich_stats]]` is discouraged.
# ℹ Use `.data[[enrich_stats]]` instead.”
# Warning message:
# “Use of `metclass_stats[[enrich_stats]]` is discouraged.
# ℹ Use `.data[[enrich_stats]]` instead.”
# plot without title

# %% [markdown]
# ### Check the pathways with reactions of all the significant metabolites

# %%
met_path = met_pathways(df_metenrichment = metenrichment, 'hsa')
head(met_path)
# Out:
#   rxn    refmet_name Exact mass KEGG ID Metabolite  Cirrhosis_mean Normal_mean
# 1 R01003 Dolichol-20 1381.2782  C00381  Dolichol-20 18.54100       60.64903
# 2 R01003 Dolichol-20 1381.2782  C00381  Dolichol-20 18.54100       60.64903
# 3 R01018 Dolichol-20 1381.2782  C00381  Dolichol-20 18.54100       60.64903
# 4 R01018 Dolichol-20 1381.2782  C00381  Dolichol-20 18.54100       60.64903
# 5 R01310 PC 36:4     781.5622   C00157  PC(36:4)    1025.012       1505.988
# 6 R01310 PC 36:4     781.5622   C00157  PC(36:4)    1025.012       1505.988
#   Fold_change log2Fold_change t_value   ⋯ metabolite_id super_class
# 1 3.271077    1.7097655       -7.141005 ⋯ ME231044      Prenol Lipids
# 2 3.271077    1.7097655       -7.141005 ⋯ ME231044      Prenol Lipids
# 3 3.271077    1.7097655       -7.141005 ⋯ ME231044      Prenol Lipids
# 4 3.271077    1.7097655       -7.141005 ⋯ ME231044      Prenol Lipids
# 5 1.469239    0.5550695       -4.795876 ⋯ ME231358      Glycerophospholipids
# 6 1.469239    0.5550695       -4.795876 ⋯ ME231358      Glycerophospholipids
#   main_class             sub_class formula    HG p-value Rxn_name
# 1 Polyprenols            Dolichols C100H164O  0.07197867 dolichyl....
# 2 Polyprenols            Dolichols C100H164O  0.07197867 dolichyl....
# 3 Polyprenols            Dolichols C100H164O  0.07197867 CTP:doli....
# 4 Polyprenols            Dolichols C100H164O  0.07197867 CTP:doli....
# 5 Glycerophosphocholines PC        C44H80NO8P 0.99164595 phosphat....
# 6 Glycerophosphocholines PC        C44H80NO8P 0.99164595 phosphat....
#   PATHWAY                        pathway_id sps_path_id
# 1 N-Glycan biosynthesis          rn00510    hsa00510
# 2 Metabolic pathways             rn01100    hsa01100
# 3 N-Glycan biosynthesis          rn00510    hsa00510
# 4 Metabolic pathways             rn01100    hsa01100
# 5 Glycerophospholipid metabolism rn00564    hsa00564
# 6 Metabolic pathways             rn01100    hsa01100

# %% [markdown]
# Find metabolites for which no pathways were registered in Kegg and/or no kegg id was found

# %%
setdiff(metenrichment$Metabolite,unique(met_path$Metabolite))
# Out:
#  [1] "C16DH 1-deoxyCer" "C18DH 1-deoxyCer" "C20DH 1-deoxyCer" "C22DH 1-deoxyCer"
#  [5] "C24DH 1-deoxyCer" "12-HEPE"          "12-HETE"          "14 HDoHE"
#  [9] "15-HETrE"         "16 HDoHE"         "4 HDoHE"          "BMP(40:7)"
# [13] "BMP(40:8)"        "CE(18:2)"         "CE(18:3)"         "CE(20:3)"
# [17] "CE(20:4)"         "CL (72:8)"        "CL (74:7)"        "CL (74:8)"
# [21] "Cholestanol"      "Dolichol-17"      "Dolichol-18"      "Dolichol-19"

# %% [markdown]
# ### Get pathway enrichment sore.
#
# Once we have the pathway information, we can calculate enrichment score of pathways. Again, here I have used hypergeometric (HG) score. For hypergeometric score, we need to know the total number of kegg compounds that are linked to kegg pathways.
#
# N = total no. of compounds/metabolites linked to all kegg pathways or the total number of metabolites detected in a study.
#
# In the former case, this step might take long time, so I advice to run the script comp_linkedto_pathways() just the first time or after 6 months or so if desired to run the pipeline again. Save the result from comp_linkedto_pathways() and load it. Loading from saved file would save time for another analysis with another study. However the package takes care of loading. Save the data in the data folder.
#
# L = No. of significant metabolites detected in a study
#
# M = No. of significant metabolites detected in a metabolite class or pathway
#
# k = Total no. of metabolites detected in a metabolite class/pathway
#
# p-value = phyper(M-1, L, N-L, k, lower.tail=FALSE) # as in the actual R code # originally, it was wriiten as: phyper(M, L, N-L, K)
#
# This function also utilizes korg dataset from pathview package.

# %%
load('../data/ls_path.RData')
load('../data/korg.RData')
kegg_es = path_enrichmentscore(met_path,sig_metabolite_kegg_id=sig_metabolite_kegg_id,ls_path=ls_path,refmet_class=refmet_class,sps='hsa',padj='fdr', kegg_comp_path=FALSE)

# %%
head(kegg_es)
# Out:
#   Pathway name                             No.of mets in study
# 1 alpha-Linolenic acid metabolism           4
# 2 Arachidonic acid metabolism               8
# 3 Biosynthesis of unsaturated fatty acids   1
# 4 Glycerolipid metabolism                  14
# 5 Glycerophospholipid metabolism           25
# 6 Glycine, serine and threonine metabolism  4
#   Total_no._of_comps_in_pathway pathway_HG p-value Padjust
# 1 44                            9.296605e-01       1.000000e+00
# 2 79                            9.456869e-01       1.000000e+00
# 3 74                            9.999983e-01       1.000000e+00
# 4 38                            5.921932e-04       2.368773e-03
# 5 56                            1.935226e-08       1.032121e-07
# 6 48                            9.561732e-01       1.000000e+00

# %% [markdown]
# ### Plot pathway network
# Only plotting significant pathways (pathway with p-value significance).
#
# The pathway network is such that it shows metabolites that are connected to different pathways and same metabolite in different pathway. Color of nodes of metabolites are according to the fold change of metabolites (low expression in green and high in red) and size of pathway nodes (square nodes) are according to the number of branches (meaning no of metabolites). All metabolite are written in blue

# %%
plot_pathway_networks (met_path,kegg_es, TRUE)
# Out:
# Warning message:
# “ggrepel: 15 unlabeled data points (too many overlaps). Consider increasing max.overlaps”
# plot without title

# %% [markdown]
# ### Heatmap

# %%
plot_heatmap(met_path, shorten_name=TRUE,refmet_name=FALSE, xaxis=8, yaxis=6)
# Out:
# plot without title

# %% [markdown]
# ### Dotplot

# %%
dotplot_met_class_path (met_path, kegg_es,"sub_class",xaxis=8,yaxis=6)
# Out:
# Warning message:
# “Use of `significant_pathways[["pathway_HG p-value"]]` is discouraged.
# ℹ Use `.data[["pathway_HG p-value"]]` instead.”
# plot without title

# %% [markdown]
# ### Get the gene and enzyme info
#
# Here we get the information of genes involved in enriched pathways for specified organism

# %%
met_gene_info = enzyme_gene_info (metenrichment, "hsa","sub_class")
head(met_gene_info)
# Out:
#   orthology_id
# 1 K00069
# 2 K00079
# 3 K00084
# 4 K00498
# 5 K00498
# 6 K00551
#   ORTHOLOGY
# 1 15-hydroxyprostaglandin dehydrogenase (NAD) [EC:1.1.1.141]
# 2 carbonyl reductase 1 [EC:1.1.1.184 1.1.1.189 1.1.1.197]
# 3 carbonyl reductase 3 [EC:1.1.1.184]
# 4 cholesterol monooxygenase (side-chain-cleaving) [EC:1.14.15.6]
# 5 cholesterol monooxygenase (side-chain-cleaving) [EC:1.14.15.6]
# 6 phosphatidylethanolamine/phosphatidyl-N-methylethanolamine N-methyltransferase [EC:2.1.1.17 2.1.1.71]
#   gene_id gene_name    ORGANISM     PATHWAY      DBLINKS      MOTIF
# 1  3248   (RefSeq).... Homo sap.... Arachido.... NCBI-Gen.... Pfam: ad....
# 2   873   (RefSeq).... Homo sap.... Arachido.... NCBI-Gen.... Pfam: ad....
# 3   874   (RefSeq).... Homo sap.... Arachido.... NCBI-Gen.... Pfam: ad....
# 4  1583   (RefSeq).... Homo sap.... Steroid .... NCBI-Gen.... Pfam: p4....
# 5  1583   (RefSeq).... Homo sap.... Steroid .... NCBI-Gen.... Pfam: p4....
# 6 10400   (RefSeq).... Homo sap.... Glycerop.... NCBI-Gen.... Pfam: PE....
#   rxn    Metabolite              KEGG ID sub_class      Rxn_name
# 1 R02580 PGE2                    C00584  Prostaglandins (5Z,13E)....
# 2 R02581 PGE2                    C00584  Prostaglandins (5Z,13E)....
# 3 R02581 PGE2                    C00584  Prostaglandins (5Z,13E)....
# 4 R04855 22R-hydroxy-cholesterol C05502  Oxysterols     22beta-h....
# 5 R02723 22R-hydroxy-cholesterol C05502  Oxysterols
# 6 R02056 PE(32:1)                C00350  PE             S-adenos....
#   RCLASS       EQUATION     EQUATION_more ENZYME
# 1 RC00001 .... C00584 +.... Prostagl....     1.1.1.141
# 2 RC00001 .... C00639 +.... Prostagl....  1.1.1.18....
# 3 RC00001 .... C00639 +.... Prostagl....  1.1.1.18....
# 4 RC00706 .... C05502 +.... 22(R)-Hy....     1.14.15.6
# 5 RC00773 .... C00187 +.... Choleste....     1.14.15.6
# 6 RC00003 .... C00019 +.... S-Adenos....      2.1.1.17

# %% [markdown]
# #### Get the information if metabolite is a reactant or substrate

# %%
rclass_info = react_substrate(met_gene_info)
head(rclass_info)
# Out:
#   orthology_id
# 1 K00069
# 2 K00079
# 3 K00084
# 4 K00498
# 5 K00498
# 6 K00551
#   ORTHOLOGY
# 1 15-hydroxyprostaglandin dehydrogenase (NAD) [EC:1.1.1.141]
# 2 carbonyl reductase 1 [EC:1.1.1.184 1.1.1.189 1.1.1.197]
# 3 carbonyl reductase 3 [EC:1.1.1.184]
# 4 cholesterol monooxygenase (side-chain-cleaving) [EC:1.14.15.6]
# 5 cholesterol monooxygenase (side-chain-cleaving) [EC:1.14.15.6]
# 6 phosphatidylethanolamine/phosphatidyl-N-methylethanolamine N-methyltransferase [EC:2.1.1.17 2.1.1.71]
#   gene_id gene_name    ORGANISM     PATHWAY      DBLINKS      MOTIF
# 1  3248   (RefSeq).... Homo sap.... Arachido.... NCBI-Gen.... Pfam: ad....
# 2   873   (RefSeq).... Homo sap.... Arachido.... NCBI-Gen.... Pfam: ad....
# 3   874   (RefSeq).... Homo sap.... Arachido.... NCBI-Gen.... Pfam: ad....
# 4  1583   (RefSeq).... Homo sap.... Steroid .... NCBI-Gen.... Pfam: p4....
# 5  1583   (RefSeq).... Homo sap.... Steroid .... NCBI-Gen.... Pfam: p4....
# 6 10400   (RefSeq).... Homo sap.... Glycerop.... NCBI-Gen.... Pfam: PE....
#   rxn    Metabolite              KEGG ID sub_class      Rxn_name
# 1 R02580 PGE2                    C00584  Prostaglandins (5Z,13E)....
# 2 R02581 PGE2                    C00584  Prostaglandins (5Z,13E)....
# 3 R02581 PGE2                    C00584  Prostaglandins (5Z,13E)....
# 4 R04855 22R-hydroxy-cholesterol C05502  Oxysterols     22beta-h....
# 5 R02723 22R-hydroxy-cholesterol C05502  Oxysterols
# 6 R02056 PE(32:1)                C00350  PE             S-adenos....
#   RCLASS       EQUATION     EQUATION_more ENZYME       reactant_product
# 1 RC00001 .... C00584 +.... Prostagl....     1.1.1.141 Substrate
# 2 RC00001 .... C00639 +.... Prostagl....  1.1.1.18.... Product
# 3 RC00001 .... C00639 +.... Prostagl....  1.1.1.18.... Product
# 4 RC00706 .... C05502 +.... 22(R)-Hy....     1.14.15.6 Substrate
# 5 RC00773 .... C00187 +.... Choleste....     1.14.15.6 Product
# 6 RC00003 .... C00019 +.... S-Adenos....      2.1.1.17 Substrate

# %% [markdown]
# #### Get gene info in short form

# %%
met_gene_info2=data.table::data.table(rclass_info)[,lapply(.SD, function(x) toString(unique(x))), by = 'Metabolite']
