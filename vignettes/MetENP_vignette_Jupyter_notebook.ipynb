# %% [markdown]
# ## MetENP

# %% [markdown]
# MetENP is a R package that enables detection of significant metabolites from metabolite information
# (names or names and concentration along with metadata information) and provides
#
# 1. Enrichment score of metabolite class,
# 2. Maps to pathway of the species of choice,
# 3. Calculate enrichment score of pathways,
# 4. Plots the pathways and shows the metabolite increase or decrease
# 5. Gets gene info, reaction info, enzyme info
#
# For more info, check out the vignette.

# %%
library(MetENP)
# Out:
# Warning message:
# "package 'MetENP' was built under R version 3.6.3"

# %% [markdown]
# #### If you do not wish to install, alternatively, download from github(https://github.com/metabolomicsworkbench/MetENP) and load libraries and functions

# %%
data = getmwstudies('ST000915', 'data')
head(data)
# Out:
#   analysis_id analysis_summary               metabolite_name metabolite_id
# 1 AN001485    Core G Fatty acids/Eicosanoids 10 HDoHE        ME230937
# 2 AN001485    Core G Fatty acids/Eicosanoids 11,12-diHETrE   ME230961
# 3 AN001485    Core G Fatty acids/Eicosanoids 11,12-EET       ME230954
# 4 AN001485    Core G Fatty acids/Eicosanoids 11b PGE2        ME230914
# 5 AN001485    Core G Fatty acids/Eicosanoids 11 HDoHE        ME230941
# 6 AN001485    Core G Fatty acids/Eicosanoids 11-HEPE         ME230917
#   refmet_name   NASH001 NASH002 NASH003 NASH004 NASH005 ... NASH061 NASH062
# 1 10-HDoHE      0.00419 0.01396 0.00285 0.00705 0.00020 ... NA      NA
# 2 11,12-DiHETrE 0.01346 1.84739 0.63897 1.87466 0.21119 ... 0.12842 0.16833
# 3 11,12-EpETrE  0.20666 0.12915 0.18170 0.11368 0.06081 ... 0.06934 0.06330
# 4 11beta-PGE2   0.00048 0.00128 NA      NA      NA      ... 0.00165 0.00327
# 5 11-HDoHE      0.00617 0.03174 0.00958 0.00593 0.00271 ... 0.03543 0.01280
# 6 11-HEPE       0.00642 NA      0.01625 0.02049 0.00115 ... 0.14650 0.03245
#   NASH064 NASH065 NASH066 NASH067 NASH068 NASH069 NASH070 NASH074
# 1 NA      NA      NA      NA      NA      NA      NA      NA
# 2 0.12114 0.32882 0.10923 0.21540 0.24789 0.25932 0.03551 0.05935
# 3 0.04931 0.10011 0.10355 0.16318 0.10468 0.05115 0.08985 0.10916
# 4 0.00153 NA      NA      NA      NA      0.00445 NA      NA
# 5 0.00369 0.01844 0.00649 0.03449 0.01077 0.01869 0.00414 0.01129
# 6 0.01528 0.01148 0.03754 0.01260 0.03738 0.00957 0.00057 0.01524

# %%
metadata = getmwstudies('ST000915', 'factors')
head(metadata)
# Out:
#   study_id local_sample_id subject_type         factors             Diagnosis
# 1 ST000915 NASH005         Human clinical study Diagnosis:Cirrhosis Cirrhosis
# 2 ST000915 NASH007         Human clinical study Diagnosis:Cirrhosis Cirrhosis
# 3 ST000915 NASH009         Human clinical study Diagnosis:Cirrhosis Cirrhosis
# 4 ST000915 NASH013         Human clinical study Diagnosis:Cirrhosis Cirrhosis
# 5 ST000915 NASH016         Human clinical study Diagnosis:Cirrhosis Cirrhosis
# 6 ST000915 NASH022         Human clinical study Diagnosis:Cirrhosis Cirrhosis

# %% [markdown]
# Find the factors you would want to compare
# Multiple factors (independent variables) are formatted in multiple columns but you can get information on all the factors by "factors" column, such as 'TreatmentGroup:Prednisolone', this indicates column name 'TreatmentGroup' with factor Prednisolone. For t-test use the factors in the same column. For comparing multipe independent variables use anova by anova_ana function.

# %% [markdown]
# ### Associate metabolomics data to the refmet class

# %%
refmet_class= convert_refmet(data)
head(refmet_class)
# Out:
#   metabolite_name analysis_id analysis_summary      metabolite_id refmet_name
# 1 1,2-DG(30:0)    AN001488    Core E Neutral Lipids ME231190      1,2-DG 30:0
# 2 1,2-DG(30:1)    AN001488    Core E Neutral Lipids ME231189      1,2-DG 30:1
# 3 1,2-DG(32:0)    AN001488    Core E Neutral Lipids ME231196      1,2-DG 32:0
# 4 1,2-DG(32:1)    AN001488    Core E Neutral Lipids ME231195      1,2-DG 32:1
# 5 1,2-DG(32:2)    AN001488    Core E Neutral Lipids ME231194      1,2-DG 32:2
# 6 1,2-DG(32:3)    AN001488    Core E Neutral Lipids ME231193      1,2-DG 32:3
#   NASH001 NASH002 NASH003 NASH004 NASH005 ... NASH066 NASH067 NASH068 NASH069
# 1 2.7     NA      NA      NA      NA      ... 193.4   55.0    75.9    99.1
# 2 1.8     NA      NA      NA      NA      ... 185.3   30.0    37.5    97.3
# 3 12.2    7.1     2.2     2.0     1.4     ... 1289.5  401.0   350.9   420.2
# 4 7.6     5.7     2.1     1.4     1.1     ... 844.7   187.7   266.9   436.2
# 5 2.0     1.9     NA      NA      NA      ... 345.8   78.2    77.3    184.5
# 6 NA      NA      NA      NA      NA      ... 63.0    12.4    7.8     52.6
#   NASH070 NASH074 formula  super_class   main_class       sub_class
# 1 173.0   591.6   C33H64O5 Glycerolipids Diradylglycerols DAG
# 2 185.6   749.1   C33H62O5 Glycerolipids Diradylglycerols DAG
# 3 713.2   1375.8  C35H68O5 Glycerolipids Diradylglycerols DAG
# 4 715.7   1932.0  C35H66O5 Glycerolipids Diradylglycerols DAG
# 5 336.2   697.2   C35H64O5 Glycerolipids Diradylglycerols DAG
# 6 63.8    124.3   C35H62O5 Glycerolipids Diradylglycerols DAG

# %%
unique(metadata$factors)
# Out:
# [[1]]
# [1] "Diagnosis:Cirrhosis"
#
# [[2]]
# [1] "Diagnosis:NASH"
#
# [[3]]
# [1] "Diagnosis:Normal"
#
# [[4]]
# [1] "Diagnosis:Steatosis"

# %%
### Find the analysis mode
unique(data$analysis_summary)
# Out:
# [[1]]
# [1] "Core G Fatty acids/Eicosanoids"
#
# [[2]]
# [1] "Core J Sterols"
#
# [[3]]
# [1] "Core K Prenols/Cardiolipins"
#
# [[4]]
# [1] "Core E Neutral Lipids"
#
# [[5]]
# [1] "Core I Sphingolipids"
#
# [[6]]
# [1] "Core H Phospholipids"

# %% [markdown]
# ### Find significant metabolites, run significance of all the analysis summary together. The analysis summary/modes you got in the previous section
# There is a normalization step which takes into account missing values, and this can be achieved via three methods:
#
# 1) half_of_min: where the NAs are replaced by half of min values in the data
#
# 2) remove_NAs: where Cols with NAs values are removed
#
# 3) 50percent: where cols with more than 50% NAs values are removed
#
# half_of_min is ideal when you wish to see which metabolites were present in either group. Very high fold change would mean it was present in either group.

# %%
stats_metabolites = significant_met(metabolomics_data=refmet_class, met_col="metabolite_name",analysis_type=c("Core G Fatty acids/Eicosanoids","Core J Sterols","Core K Prenols/Cardiolipins","Core E Neutral Lipids","Core I Sphingolipids","Core H Phospholipids"), metadata=metadata, factor1='Cirrhosis', factor2=c('Normal'), factor_col='Diagnosis',sample_col='local_sample_id', p_adjust='fdr',normalization="50percent")

sig_metabolites = stats_metabolites[which(stats_metabolites[,"pval"] <= 0.05&abs(stats_metabolites[,"log2Fold_change"])>0.5),]

# %%
plot_volcano(stats_metabolites, thres_pval= 0.05,thres_log2foldchange = 0.5, TRUE)
# Out:
# plot without title

# %% [markdown]
# ### Map metabolite class of the significant metabolites utilzing refmet classification in Metabolomics Workbench
# This function not only maps metabolite to metabolite class but also to external databases such as pubchem, inchi key, smiles and kegg
#
# In this example, we will go forward with significant metabolite obtained by t-test/

# %%
sig_metabolites_kegg_id= map_keggid(sig_metabolites)

# %% [markdown]
# #### Check all your significant metabolites have not been assigned metabolite class

# %%
setdiff(sig_metabolites$refmet_name, sig_metabolites_kegg_id$refmet_name)
# Out:
# character(0)

# %% [markdown]
# ### Count metabolites in each of the metabolite class and plotting
# You may choose from sub_class, main_class and super_class

# %%
count_changes = metcountplot(df_metclass=sig_metabolites_kegg_id, metclass='sub_class', plotting=TRUE, thres_logfC = 0.5)

# %%
count_changes$plotimg
# Out:
# plot without title

# %% [markdown]
# ### Enrichment class score
#
# Calculate the enrichment score of each metabolite class. Enrichment score is calculated through hypergeometric method. One can specify the no. of significant metabolites in a class while calculating the enrichment score. We advice to use the number of mtabolites in each class as 3 or more. But if someone just wants to know the enrichment score and rest of the information of all the metabolites, then they can choose the number as 1.

# %%
metenrichment = metclassenrichment(df_metclass=sig_metabolites_kegg_id,refmet_class, metclass="sub_class",enrich_stats="HG",no=3)

# %% [markdown]
# #### Plot the enrichment score via function plot_met_enrichment

# %%
plot_met_enrichment(metenrichment, "sub_class","HG", no=3)
# Out:
# plot without title

# %% [markdown]
# ### Check the pathways with reactions of all the significant metabolites

# %%
met_path = met_pathways(df_metenrichment = metenrichment, 'hsa')
head(met_path)
# Out:
#   rxn    refmet_name Exact mass KEGG ID Metabolite   Cirrhosis_mean Normal_mean
# 1 R01312 1,2-DG 34:1 594.5223   C00641  1,2-DG(34:1)  601.8775      1256.7161
# 2 R01312 1,2-DG 36:4 616.5067   C00641  1,2-DG(36:4) 165.5750       383.1855
# 3 R01312 1,2-DG 32:1 566.4910   C00641  1,2-DG(32:1) 210.1550       459.3081
# 4 R01312 1,2-DG 34:2 592.5067   C00641  1,2-DG(34:2)  485.6675      1006.3597
# 5 R01312 1,2-DG 32:0 568.5067   C00641  1,2-DG(32:0) 210.0625       479.9210
# 6 R01312 1,2-DG 36:2 620.5380   C00641  1,2-DG(36:2) 408.4525       968.4145
#   Fold_change log2Fold_change t_value   ... metabolite_id super_class
# 1 2.087993    1.062117        -2.284839 ... ME231202      Glycerolipids
# 2 2.314271    1.210558        -2.453312 ... ME231210      Glycerolipids
# 3 2.185568    1.128008        -2.126083 ... ME231195      Glycerolipids
# 4 2.072117    1.051105        -2.372477 ... ME231201      Glycerolipids
# 5 2.284658    1.191978        -2.410346 ... ME231196      Glycerolipids
# 6 2.370935    1.245456        -2.651684 ... ME231212      Glycerolipids
#   main_class       sub_class formula  HG p-value
# 1 Diradylglycerols DAG       C37H70O5 7.765032e-06
# 2 Diradylglycerols DAG       C39H68O5 7.765032e-06
# 3 Diradylglycerols DAG       C35H66O5 7.765032e-06
# 4 Diradylglycerols DAG       C37H68O5 7.765032e-06
# 5 Diradylglycerols DAG       C35H68O5 7.765032e-06
# 6 Diradylglycerols DAG       C39H72O5 7.765032e-06
#   Rxn_name                                    PATHWAY
# 1 Phosphatidylcholine cholinephosphohydrolase Glycerophospholipid metabolism
# 2 Phosphatidylcholine cholinephosphohydrolase Glycerophospholipid metabolism
# 3 Phosphatidylcholine cholinephosphohydrolase Glycerophospholipid metabolism
# 4 Phosphatidylcholine cholinephosphohydrolase Glycerophospholipid metabolism
# 5 Phosphatidylcholine cholinephosphohydrolase Glycerophospholipid metabolism
# 6 Phosphatidylcholine cholinephosphohydrolase Glycerophospholipid metabolism
#   pathway_id sps_path_id
# 1 rn00564    hsa00564
# 2 rn00564    hsa00564
# 3 rn00564    hsa00564
# 4 rn00564    hsa00564
# 5 rn00564    hsa00564
# 6 rn00564    hsa00564

# %% [markdown]
# Find metabolites for which no pathways were registered in Kegg and/or no kegg id was found

# %%
setdiff(metenrichment$Metabolite,unique(met_path$Metabolite))
# Out:
#  [1] "C16DH 1-deoxyCer" "C18DH 1-deoxyCer" "C20DH 1-deoxyCer" "C22DH 1-deoxyCer"
#  [5] "C24DH 1-deoxyCer" "14 HDoHE"         "16 HDoHE"         "4 HDoHE"
#  [9] "CE(18:2)"         "CE(18:3)"         "CE(20:3)"         "CE(20:4)"
# [13] "CE(22:6)"         "CL (72:8)"        "CL (74:7)"        "CL (74:8)"
# [17] "Cholestanol"      "Dolichol-17"      "Dolichol-18"      "Dolichol-19"
# [21] "Dolichol-20"

# %% [markdown]
# ### Get pathway enrichment sore.
#
# Once we have the pathway information, we can calculate enrichment score of pathways. Again, here i have used hypergeometric score. For hypergeometric score, we need to know the total number of kegg compounds that are linked to kegg pathways.
# N = total no. of cmpds linked to kegg pathway (this is the step which might take long), so I advice to run the script comp_linkedto_pathways() just the first time or after 6 months or so if desired to run the pipeline again. save the result from comp_linkedto_pathways() and load it. Loading from saved file would save time for another analysis with another study. However the package takes care of loading. Save the data in the data folder.
#
# L = No. of cmpds in a pathway
# M= no. of altered cmpds in a pathway
# K =  total no. of altered cmpds
# phyper(M,L, N-L, K)
#
#
# This function also utilizes korg dataset from pathview package.

# %%
load('C:/Users/bioso/Documents/MetENP/data/ls_path.RData')
load('C:/Users/bioso/Documents/MetENP/data/korg.RData')
kegg_es = path_enrichmentscore(met_path,sig_metabolite_kegg_id=sig_metabolite_kegg_id,ls_path=ls_path,refmet_class=refmet_class,sps='hsa',padj='fdr', kegg_comp_path=FALSE)

# %%
head(kegg_es)
# Out:
#     Pathway name                                           No.of mets in study
# 110 Arachidonic acid metabolism                             4
# 13  Glycerolipid metabolism                                12
# 11  Glycerophospholipid metabolism                         17
# 16  Glycine, serine and threonine metabolism                4
# 19  Glycosylphosphatidylinositol (GPI)-anchor biosynthesis 13
# 17  Inositol phosphate metabolism                           9
#     Total_no._of_comps_in_pathway pathway_HG p-value Padjust
# 110 75                            9.991730e-01       9.991730e-01
# 13  38                            8.469408e-03       1.905617e-02
# 11  52                            9.973045e-04       2.991914e-03
# 16  50                            9.705819e-01       9.991730e-01
# 19  16                            5.698536e-09       2.564341e-08
# 17  47                            3.070207e-01       3.947409e-01

# %% [markdown]
# ### Plot pathway network
# Only plotting significant pathways (pathway with p-value significance).
#
# The pathway network is such that it shows metabolites that are connected to different pathways and same metabolite in different pathway. Color of nodes of metabolites are according to the fold change of metabolites (low expression in green and high in red) and size of pathway nodes (square nodes) are according to the number of branches (meaning no of metabolites). All metabolite are written in blue

# %%
plot_pathway_networks (met_path,kegg_es, TRUE)
# Out:
# plot without title

# %% [markdown]
# ### Heatmap

# %%
plot_heatmap(met_path)
# Out:
# plot without title

# %% [markdown]
# ### Dotplot

# %%
dotplot_met_class_path (met_path, kegg_es,"sub_class")
# Out:
# plot without title

# %% [markdown]
# ### Get the gene and enzyme info
#
# Here we get the information of genes involved in enriched pathways for specified organism

# %%
met_gene_info = enzyme_gene_info (metenrichment, "hsa","sub_class")
head(met_gene_info)
# Out:
#   orthology_id
# 1 K00551
# 2 K00551
# 3 K00551
# 4 K00551
# 5 K00720
# 6 K00720
#   ORTHOLOGY
# 1 phosphatidylethanolamine/phosphatidyl-N-methylethanolamine N-methyltransferase [EC:2.1.1.17 2.1.1.71]
# 2 phosphatidylethanolamine/phosphatidyl-N-methylethanolamine N-methyltransferase [EC:2.1.1.17 2.1.1.71]
# 3 phosphatidylethanolamine/phosphatidyl-N-methylethanolamine N-methyltransferase [EC:2.1.1.17 2.1.1.71]
# 4 phosphatidylethanolamine/phosphatidyl-N-methylethanolamine N-methyltransferase [EC:2.1.1.17 2.1.1.71]
# 5 ceramide glucosyltransferase [EC:2.4.1.80]
# 6 ceramide glucosyltransferase [EC:2.4.1.80]
#   gene_id gene_name
# 1 10400   PEMT, PEAMT, PEMPT, PEMT2, PLMT, PNMT
# 2 10400   PEMT, PEAMT, PEMPT, PEMT2, PLMT, PNMT
# 3 10400   PEMT, PEAMT, PEMPT, PEMT2, PLMT, PNMT
# 4 10400   PEMT, PEAMT, PEMPT, PEMT2, PLMT, PNMT
# 5 7357    UGCG, GCS, GLCT1
# 6 7357    UGCG, GCS, GLCT1
#   DEFINITION                                            ORGANISM
# 1 (RefSeq) phosphatidylethanolamine N-methyltransferase Homo sapiens (human)
# 2 (RefSeq) phosphatidylethanolamine N-methyltransferase Homo sapiens (human)
# 3 (RefSeq) phosphatidylethanolamine N-methyltransferase Homo sapiens (human)
# 4 (RefSeq) phosphatidylethanolamine N-methyltransferase Homo sapiens (human)
# 5 (RefSeq) UDP-glucose ceramide glucosyltransferase     Homo sapiens (human)
# 6 (RefSeq) UDP-glucose ceramide glucosyltransferase     Homo sapiens (human)
#   PATHWAY
# 1 Glycerophospholipid metabolism, Metabolic pathways
# 2 Glycerophospholipid metabolism, Metabolic pathways
# 3 Glycerophospholipid metabolism, Metabolic pathways
# 4 Glycerophospholipid metabolism, Metabolic pathways
# 5 Sphingolipid metabolism, Metabolic pathways
# 6 Sphingolipid metabolism, Metabolic pathways
#   DBLINKS
# 1 NCBI-GeneID: 10400       , NCBI-ProteinID: NP_009100, OMIM: 602391             , HGNC: 8830               , Ensembl: ENSG00000133027 , Vega: OTTHUMG00000059290 , Pharos: Q9UBM1(Tbio)     , UniProt: Q9UBM1
# 2 NCBI-GeneID: 10400       , NCBI-ProteinID: NP_009100, OMIM: 602391             , HGNC: 8830               , Ensembl: ENSG00000133027 , Vega: OTTHUMG00000059290 , Pharos: Q9UBM1(Tbio)     , UniProt: Q9UBM1
# 3 NCBI-GeneID: 10400       , NCBI-ProteinID: NP_009100, OMIM: 602391             , HGNC: 8830               , Ensembl: ENSG00000133027 , Vega: OTTHUMG00000059290 , Pharos: Q9UBM1(Tbio)     , UniProt: Q9UBM1
# 4 NCBI-GeneID: 10400       , NCBI-ProteinID: NP_009100, OMIM: 602391             , HGNC: 8830               , Ensembl: ENSG00000133027 , Vega: OTTHUMG00000059290 , Pharos: Q9UBM1(Tbio)     , UniProt: Q9UBM1
# 5 NCBI-GeneID: 7357         , NCBI-ProteinID: NP_003349 , OMIM: 602874              , HGNC: 12524               , Ensembl: ENSG00000148154  , Vega: OTTHUMG00000020498  , Pharos: Q16739(Tclin)     , UniProt: Q16739 A0A024R157
# 6 NCBI-GeneID: 7357         , NCBI-ProteinID: NP_003349 , OMIM: 602874              , HGNC: 12524               , Ensembl: ENSG00000148154  , Vega: OTTHUMG00000020498  , Pharos: Q16739(Tclin)     , UniProt: Q16739 A0A024R157
#   MOTIF
# 1 Pfam: PEMT Herpes_UL74
# 2 Pfam: PEMT Herpes_UL74
# 3 Pfam: PEMT Herpes_UL74
# 4 Pfam: PEMT Herpes_UL74
# 5 Pfam: Glyco_transf_21 Glyco_tranf_2_3 Glyco_trans_2_3 Glycos_transf_2 Chitin_synth_2
# 6 Pfam: Glyco_transf_21 Glyco_tranf_2_3 Glyco_trans_2_3 Glycos_transf_2 Chitin_synth_2
#   rxn    Metabolite KEGG ID sub_class
# 1 R02056 PE(40:6)   C00350  PE
# 2 R02056 PE(36:3)   C00350  PE
# 3 R02056 PE(38:6)   C00350  PE
# 4 R02056 PE(32:1)   C00350  PE
# 5 R06275 C22 Cer    C00195  Cer
# 6 R01497 C22 Cer    C00195  Cer
#   Rxn_name
# 1 S-adenosyl-L-methionine:phosphatidylethanolamine N-methyltransferase
# 2 S-adenosyl-L-methionine:phosphatidylethanolamine N-methyltransferase
# 3 S-adenosyl-L-methionine:phosphatidylethanolamine N-methyltransferase
# 4 S-adenosyl-L-methionine:phosphatidylethanolamine N-methyltransferase
# 5 NULL
# 6 UDP-glucose:N-acylsphingosine D-glucosyltransferase
#   RCLASS
# 1 RC00003  C00019_C00021, RC00060  C00350_C01241
# 2 RC00003  C00019_C00021, RC00060  C00350_C01241
# 3 RC00003  C00019_C00021, RC00060  C00350_C01241
# 4 RC00003  C00019_C00021, RC00060  C00350_C01241
# 5 NULL
# 6 RC00005  C00015_C00029, RC00059  C00195_C01190
#   EQUATION
# 1 C00019 + C00350 <=> C00021 + C01241
# 2 C00019 + C00350 <=> C00021 + C01241
# 3 C00019 + C00350 <=> C00021 + C01241
# 4 C00019 + C00350 <=> C00021 + C01241
# 5 G10608 + C00195 <=> G10619 + G10238
# 6 C00029 + C00195 <=> C00015 + C01190
#   EQUATION_more
# 1 S-Adenosyl-L-methionine + Phosphatidylethanolamine <=> S-Adenosyl-L-homocysteine + Phosphatidyl-N-methylethanolamine
# 2 S-Adenosyl-L-methionine + Phosphatidylethanolamine <=> S-Adenosyl-L-homocysteine + Phosphatidyl-N-methylethanolamine
# 3 S-Adenosyl-L-methionine + Phosphatidylethanolamine <=> S-Adenosyl-L-homocysteine + Phosphatidyl-N-methylethanolamine
# 4 S-Adenosyl-L-methionine + Phosphatidylethanolamine <=> S-Adenosyl-L-homocysteine + Phosphatidyl-N-methylethanolamine
# 5 UDP-D-glucose + N-Acylsphingosine <=> UDP + Glucosylceramide
# 6 UDP-glucose + N-Acylsphingosine <=> UDP + Glucosylceramide
#   ENZYME
# 1 2.1.1.17
# 2 2.1.1.17
# 3 2.1.1.17
# 4 2.1.1.17
# 5 2.4.1.80
# 6 2.4.1.80

# %% [markdown]
# #### Get the information if metabolite is a reactant or substrate

# %%
rclass_info = react_substrate(met_gene_info)
head(rclass_info)
# Out:
#   orthology_id
# 1 K00551
# 2 K00551
# 3 K00551
# 4 K00551
# 5 K00720
# 6 K00720
#   ORTHOLOGY
# 1 phosphatidylethanolamine/phosphatidyl-N-methylethanolamine N-methyltransferase [EC:2.1.1.17 2.1.1.71]
# 2 phosphatidylethanolamine/phosphatidyl-N-methylethanolamine N-methyltransferase [EC:2.1.1.17 2.1.1.71]
# 3 phosphatidylethanolamine/phosphatidyl-N-methylethanolamine N-methyltransferase [EC:2.1.1.17 2.1.1.71]
# 4 phosphatidylethanolamine/phosphatidyl-N-methylethanolamine N-methyltransferase [EC:2.1.1.17 2.1.1.71]
# 5 ceramide glucosyltransferase [EC:2.4.1.80]
# 6 ceramide glucosyltransferase [EC:2.4.1.80]
#   gene_id gene_name
# 1 10400   PEMT, PEAMT, PEMPT, PEMT2, PLMT, PNMT
# 2 10400   PEMT, PEAMT, PEMPT, PEMT2, PLMT, PNMT
# 3 10400   PEMT, PEAMT, PEMPT, PEMT2, PLMT, PNMT
# 4 10400   PEMT, PEAMT, PEMPT, PEMT2, PLMT, PNMT
# 5 7357    UGCG, GCS, GLCT1
# 6 7357    UGCG, GCS, GLCT1
#   DEFINITION                                            ORGANISM
# 1 (RefSeq) phosphatidylethanolamine N-methyltransferase Homo sapiens (human)
# 2 (RefSeq) phosphatidylethanolamine N-methyltransferase Homo sapiens (human)
# 3 (RefSeq) phosphatidylethanolamine N-methyltransferase Homo sapiens (human)
# 4 (RefSeq) phosphatidylethanolamine N-methyltransferase Homo sapiens (human)
# 5 (RefSeq) UDP-glucose ceramide glucosyltransferase     Homo sapiens (human)
# 6 (RefSeq) UDP-glucose ceramide glucosyltransferase     Homo sapiens (human)
#   PATHWAY
# 1 Glycerophospholipid metabolism, Metabolic pathways
# 2 Glycerophospholipid metabolism, Metabolic pathways
# 3 Glycerophospholipid metabolism, Metabolic pathways
# 4 Glycerophospholipid metabolism, Metabolic pathways
# 5 Sphingolipid metabolism, Metabolic pathways
# 6 Sphingolipid metabolism, Metabolic pathways
#   DBLINKS
# 1 NCBI-GeneID: 10400       , NCBI-ProteinID: NP_009100, OMIM: 602391             , HGNC: 8830               , Ensembl: ENSG00000133027 , Vega: OTTHUMG00000059290 , Pharos: Q9UBM1(Tbio)     , UniProt: Q9UBM1
# 2 NCBI-GeneID: 10400       , NCBI-ProteinID: NP_009100, OMIM: 602391             , HGNC: 8830               , Ensembl: ENSG00000133027 , Vega: OTTHUMG00000059290 , Pharos: Q9UBM1(Tbio)     , UniProt: Q9UBM1
# 3 NCBI-GeneID: 10400       , NCBI-ProteinID: NP_009100, OMIM: 602391             , HGNC: 8830               , Ensembl: ENSG00000133027 , Vega: OTTHUMG00000059290 , Pharos: Q9UBM1(Tbio)     , UniProt: Q9UBM1
# 4 NCBI-GeneID: 10400       , NCBI-ProteinID: NP_009100, OMIM: 602391             , HGNC: 8830               , Ensembl: ENSG00000133027 , Vega: OTTHUMG00000059290 , Pharos: Q9UBM1(Tbio)     , UniProt: Q9UBM1
# 5 NCBI-GeneID: 7357         , NCBI-ProteinID: NP_003349 , OMIM: 602874              , HGNC: 12524               , Ensembl: ENSG00000148154  , Vega: OTTHUMG00000020498  , Pharos: Q16739(Tclin)     , UniProt: Q16739 A0A024R157
# 6 NCBI-GeneID: 7357         , NCBI-ProteinID: NP_003349 , OMIM: 602874              , HGNC: 12524               , Ensembl: ENSG00000148154  , Vega: OTTHUMG00000020498  , Pharos: Q16739(Tclin)     , UniProt: Q16739 A0A024R157
#   MOTIF
# 1 Pfam: PEMT Herpes_UL74
# 2 Pfam: PEMT Herpes_UL74
# 3 Pfam: PEMT Herpes_UL74
# 4 Pfam: PEMT Herpes_UL74
# 5 Pfam: Glyco_transf_21 Glyco_tranf_2_3 Glyco_trans_2_3 Glycos_transf_2 Chitin_synth_2
# 6 Pfam: Glyco_transf_21 Glyco_tranf_2_3 Glyco_trans_2_3 Glycos_transf_2 Chitin_synth_2
#   rxn    Metabolite KEGG ID sub_class
# 1 R02056 PE(40:6)   C00350  PE
# 2 R02056 PE(36:3)   C00350  PE
# 3 R02056 PE(38:6)   C00350  PE
# 4 R02056 PE(32:1)   C00350  PE
# 5 R06275 C22 Cer    C00195  Cer
# 6 R01497 C22 Cer    C00195  Cer
#   Rxn_name
# 1 S-adenosyl-L-methionine:phosphatidylethanolamine N-methyltransferase
# 2 S-adenosyl-L-methionine:phosphatidylethanolamine N-methyltransferase
# 3 S-adenosyl-L-methionine:phosphatidylethanolamine N-methyltransferase
# 4 S-adenosyl-L-methionine:phosphatidylethanolamine N-methyltransferase
# 5 NULL
# 6 UDP-glucose:N-acylsphingosine D-glucosyltransferase
#   RCLASS
# 1 RC00003  C00019_C00021, RC00060  C00350_C01241
# 2 RC00003  C00019_C00021, RC00060  C00350_C01241
# 3 RC00003  C00019_C00021, RC00060  C00350_C01241
# 4 RC00003  C00019_C00021, RC00060  C00350_C01241
# 5 NULL
# 6 RC00005  C00015_C00029, RC00059  C00195_C01190
#   EQUATION
# 1 C00019 + C00350 <=> C00021 + C01241
# 2 C00019 + C00350 <=> C00021 + C01241
# 3 C00019 + C00350 <=> C00021 + C01241
# 4 C00019 + C00350 <=> C00021 + C01241
# 5 G10608 + C00195 <=> G10619 + G10238
# 6 C00029 + C00195 <=> C00015 + C01190
#   EQUATION_more
# 1 S-Adenosyl-L-methionine + Phosphatidylethanolamine <=> S-Adenosyl-L-homocysteine + Phosphatidyl-N-methylethanolamine
# 2 S-Adenosyl-L-methionine + Phosphatidylethanolamine <=> S-Adenosyl-L-homocysteine + Phosphatidyl-N-methylethanolamine
# 3 S-Adenosyl-L-methionine + Phosphatidylethanolamine <=> S-Adenosyl-L-homocysteine + Phosphatidyl-N-methylethanolamine
# 4 S-Adenosyl-L-methionine + Phosphatidylethanolamine <=> S-Adenosyl-L-homocysteine + Phosphatidyl-N-methylethanolamine
# 5 UDP-D-glucose + N-Acylsphingosine <=> UDP + Glucosylceramide
# 6 UDP-glucose + N-Acylsphingosine <=> UDP + Glucosylceramide
#   ENZYME   reactant_product
# 1 2.1.1.17 Substrate
# 2 2.1.1.17 Substrate
# 3 2.1.1.17 Substrate
# 4 2.1.1.17 Substrate
# 5 2.4.1.80 Substrate
# 6 2.4.1.80 Substrate

# %% [markdown]
# #### Get gene info in short form

# %%
met_gene_info2=data.table::data.table(rclass_info)[,lapply(.SD, function(x) toString(unique(x))), by = 'Metabolite']
