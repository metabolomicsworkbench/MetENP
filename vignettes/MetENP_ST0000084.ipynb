# %% [markdown]
# ## MetENP

# %% [markdown]
# MetENP is a R package that enables detection of significant metabolites from metabolite information
# (names or names and concentration along with metadata information) and provides
#
# 1. Enrichment score of metabolite class,
# 2. Maps to pathway of the species of choice,
# 3. Calculate enrichment score of pathways,
# 4. Plots the pathways and shows the metabolite increase or decrease
# 5. Gets gene info, reaction info, enzyme info
#
# For more info, check out the vignette.

# %%
if (!requireNamespace("KEGGREST", quietly = TRUE))
    BiocManager::install("KEGGREST", update = TRUE, ask = FALSE)

if (!requireNamespace("KEGGgraph", quietly = TRUE))
    BiocManager::install("KEGGgraph", update = TRUE, ask = FALSE)

if (!requireNamespace("pathview", quietly = TRUE))
    BiocManager::install("pathview", update = TRUE, ask = FALSE)

#if (!requireNamespace("KEGG.db", quietly = TRUE))
#    BiocManager::install("KEGG.db", update = TRUE, ask = FALSE)

#if (!requireNamespace("MetENP", quietly = TRUE))
#    devtools::install("..", upgrade = "never")
# Out:
# ##############################################################################
# Pathview is an open source software package distributed under GNU General
# Public License version 3 (GPLv3). Details of GPLv3 is available at
# http://www.gnu.org/licenses/gpl-3.0.html. Particullary, users are required to
# formally cite the original Pathview paper (not just mention it) in publications
# or products. For details, do citation("pathview") within R.
#
# The pathview downloads and uses KEGG data. Non-academic uses may require a KEGG
# license agreement (details at http://www.kegg.jp/kegg/legal.html).
# ##############################################################################

# %%
USER_HOME=Sys.getenv("HOME");
.libPaths( c( .libPaths(), paste0(USER_HOME, "/.local/R") ))
#.libPaths( c( .libPaths(), paste0("../../R") )); # suitable path to where MetENP R package is installed

library(MetENP)

# %% [markdown]
# #### If you do not wish to install, alternatively, download from github(https://github.com/metabolomicsworkbench/MetENP) and load libraries and functions
# #### Complete information for this study is at Metabolomics Workbench: https://www.metabolomicsworkbench.org/data/DRCCMetadata.php?Mode=Study&StudyID=ST000084&StudyType=MS&ResultType=1

# %%
data = getmwstudies('ST000084', 'data')
head(data)
# Out:
#   analysis_id analysis_summary       metabolite_name
# 1 AN000136    GCMS positive ion mode 1-methyl nicotinamide
# 2 AN000136    GCMS positive ion mode 2-aminoethanethiol
# 3 AN000136    GCMS positive ion mode 3-hydroxybenzaldehyde
# 4 AN000136    GCMS positive ion mode 3-phosphoglyceric acid
# 5 AN000136    GCMS positive ion mode 4-guanidinobutyric acid
# 6 AN000136    GCMS positive ion mode 4-hydroxyquinoline-2-carboxylic acid
#   metabolite_id refmet_name              SBEP_Metab_Control1
# 1 ME056499      1-Methyl nicotinamide    1239983.871
# 2 ME056500      Cysteamine               1978223.421
# 3 ME056560      3-Hydroxybenzaldehyde    NA
# 4 ME056501      3-Phosphoglyceric acid   939105.598
# 5 ME056502      4-Guanidinobutanoic acid 2503735.814
# 6 ME056503      Kynurenic acid           2242776.722
#   SBEP_Metab_Control2 SBEP_Metab_Control3 SBEP_Metab_LPSactivated1
# 1 1254663.088         1489471.315         1062991.62
# 2 1627360.314         1706353.61          860066
# 3 NA                  NA                  NA
# 4 1126254.388         1209267.302         1378750.809
# 5 2524316.133         3831232.635         1691148.95
# 6 2044760.803         2387892.728         170138.6278
#   SBEP_Metab_LPSactivated2 SBEP_Metab_LPSactivated3
# 1 919285.1031              1110010.624
# 2 824243                   1110568.372
# 3 440476.8001              450894.3104
# 4 1600810.737              1659251.931
# 5 1629745.89               1948152.502
# 6 162000.6772              200927.2684

# %%
metadata = getmwstudies('ST000084', 'factors')
head(metadata)
# Out:
#   study_id local_sample_id          subject_type
# 1 ST000084 SBEP_Metab_LPSactivated1 Animal cells
# 2 ST000084 SBEP_Metab_LPSactivated2 Animal cells
# 3 ST000084 SBEP_Metab_LPSactivated3 Animal cells
# 4 ST000084 SBEP_Metab_Control1      Animal cells
# 5 ST000084 SBEP_Metab_Control2      Animal cells
# 6 ST000084 SBEP_Metab_Control3      Animal cells
#   factors                                Lipopolysaccharide Treatment
# 1 Lipopolysaccharide Treatment:100 ng/ml 100 ng/ml
# 2 Lipopolysaccharide Treatment:100 ng/ml 100 ng/ml
# 3 Lipopolysaccharide Treatment:100 ng/ml 100 ng/ml
# 4 Lipopolysaccharide Treatment:None      None
# 5 Lipopolysaccharide Treatment:None      None
# 6 Lipopolysaccharide Treatment:None      None

# %% [markdown]
# Find the factors you would want to compare
# Multiple factors (independent variables) are formatted in multiple columns but you can get information on all the factors by "factors" column, such as 'TreatmentGroup:Prednisolone', this indicates column name 'TreatmentGroup' with factor Prednisolone. For t-test use the factors in the same column. For comparing multipe independent variables use anova by anova_ana function.

# %% [markdown]
# ### Associate metabolomics data to the refmet class

# %%
refmet_class= convert_refmet(data)
head(refmet_class)
# Out:
#   metabolite_name                      analysis_id analysis_summary
# 1 1-methyl nicotinamide                AN000136    GCMS positive ion mode
# 2 2-aminoethanethiol                   AN000136    GCMS positive ion mode
# 3 3-hydroxybenzaldehyde                AN000136    GCMS positive ion mode
# 4 3-phosphoglyceric acid               AN000136    GCMS positive ion mode
# 5 4-guanidinobutyric acid              AN000136    GCMS positive ion mode
# 6 4-hydroxyquinoline-2-carboxylic acid AN000136    GCMS positive ion mode
#   metabolite_id refmet_name              SBEP_Metab_Control1
# 1 ME056499      1-Methyl nicotinamide    1239983.871
# 2 ME056500      Cysteamine               1978223.421
# 3 ME056560      3-Hydroxybenzaldehyde    NA
# 4 ME056501      3-Phosphoglyceric acid   939105.598
# 5 ME056502      4-Guanidinobutanoic acid 2503735.814
# 6 ME056503      Kynurenic acid           2242776.722
#   SBEP_Metab_Control2 SBEP_Metab_Control3 SBEP_Metab_LPSactivated1
# 1 1254663.088         1489471.315         1062991.62
# 2 1627360.314         1706353.61          860066
# 3 NA                  NA                  NA
# 4 1126254.388         1209267.302         1378750.809
# 5 2524316.133         3831232.635         1691148.95
# 6 2044760.803         2387892.728         170138.6278
#   SBEP_Metab_LPSactivated2 SBEP_Metab_LPSactivated3 formula
# 1 919285.1031              1110010.624              C7H9N2O
# 2 824243                   1110568.372              C2H7NS
# 3 440476.8001              450894.3104              C7H6O2
# 4 1600810.737              1659251.931              C3H7O7P
# 5 1629745.89               1948152.502              C5H11N3O2
# 6 162000.6772              200927.2684              C10H7NO3
#   super_class                  main_class
# 1 Organoheterocyclic compounds Pyridinecarboxylic acids
# 2 Organosulfur compounds       Thiols
# 3 Organic oxygen compounds     Benzaldehydes
# 4 Organic acids                Short-chain acids
# 5 Organic acids                Amino acids and peptides
# 6 Organoheterocyclic compounds Quinolines
#   sub_class
# 1 Nicotinamides
# 2 Alkylthiols
# 3 Hydroxybenzaldehydes
# 4 Short-chain acids
# 5 Amino acids
# 6 Quinoline carboxylic acids

# %%
unique(metadata$factors)
# Out:
# [[1]]
# [1] "Lipopolysaccharide Treatment:100 ng/ml"
#
# [[2]]
# [1] "Lipopolysaccharide Treatment:None"

# %%
### Find the analysis mode
unique(data$analysis_summary)
# Out:
# [[1]]
# [1] "GCMS positive ion mode"

# %% [markdown]
# ### Find significant metabolites, run significance of all the analysis summary together. The analysis summary/modes you got in the previous section
# There is a normalization step which takes into account missing values, and this can be achieved via three methods:
#
# 1) half_of_min: where the NAs are replaced by half of min values in the data
#
# 2) remove_NAs: where Cols with NAs values are removed
#
# 3) 50percent: where cols with more than 50% NAs values are removed
#
# half_of_min is ideal when you wish to see which metabolites were present in either group. Very high fold change would mean it was present in either group.

# %%
stats_metabolites = significant_met(metabolomics_data=refmet_class, met_col="metabolite_name",analysis_type=c('GCMS positive ion mode'), metadata=metadata, factor1='100 ng/ml', factor2=c('None'), factor_col='Lipopolysaccharide Treatment',sample_col='local_sample_id', p_adjust='fdr',normalization="50percent")

sig_metabolites = stats_metabolites[which(stats_metabolites[,"pval"] <= 0.05&abs(stats_metabolites[,"log2Fold_change"])>0.5),]

# %%
plot_volcano(stats_metabolites, thres_pval= 0.05,thres_log2foldchange = 0.0, TRUE)
# Out:
# Warning message:
# “ggrepel: 5 unlabeled data points (too many overlaps). Consider increasing max.overlaps”
# plot without title

# %% [markdown]
# ### Map metabolite class of the significant metabolites utilzing refmet classification in Metabolomics Workbench
# This function not only maps metabolite to metabolite class but also to external databases such as pubchem, inchi key, smiles and kegg
#
# In this example, we will go forward with significant metabolite obtained by t-test/

# %%
sig_metabolites_kegg_id= map_keggid(sig_metabolites)

# %% [markdown]
# #### Check all your significant metabolites have not been assigned metabolite class

# %%
setdiff(sig_metabolites$refmet_name, sig_metabolites_kegg_id$refmet_name)
# Out:
# character(0)

# %% [markdown]
# ### Count metabolites in each of the metabolite class and plotting
# You may choose from sub_class, main_class and super_class

# %%
count_changes = metcountplot(df_metclass=sig_metabolites_kegg_id, metclass='sub_class', plotting=TRUE, thres_logfC = 0.0)

# %%
count_changes$plotimg
# Out:
# Warning message:
# “Use of `count_changes[[metclass]]` is discouraged. Use `.data[[metclass]]` instead.”
# plot without title

# %% [markdown]
# ### Enrichment class score
#
# Calculate the enrichment score of each metabolite class. Enrichment score is calculated through hypergeometric method. One can specify the no. of significant metabolites in a class while calculating the enrichment score. We advice to use the number of mtabolites in each class as 3 or more. But if someone just wants to know the enrichment score and rest of the information of all the metabolites, then they can choose the number as 1.

# %%
metenrichment = metclassenrichment(df_metclass=sig_metabolites_kegg_id,refmet_class, metclass="sub_class",enrich_stats="HG",no=1)

# %% [markdown]
# #### Plot the enrichment score via function plot_met_enrichment

# %%
plot_met_enrichment(metenrichment, "sub_class","HG", no=1)
# Out:
# Warning message:
# “Use of `metclass_stats[[metclass]]` is discouraged. Use `.data[[metclass]]` instead.”
# Warning message:
# “Use of `metclass_stats[[enrich_stats]]` is discouraged. Use `.data[[enrich_stats]]` instead.”
# Warning message:
# “Use of `metclass_stats[[enrich_stats]]` is discouraged. Use `.data[[enrich_stats]]` instead.”
# plot without title

# %% [markdown]
# ### Check the pathways with reactions of all the significant metabolites

# %%
met_path = met_pathways(df_metenrichment = metenrichment, 'hsa')
head(met_path)
# Out:
#   rxn    refmet_name   Exact mass KEGG ID Metabolite      100 ng/ml_mean
# 1 R00008 Pyruvic acid  88.0160    C00022  pyruvic acid     832822.7
# 2 R00014 Pyruvic acid  88.0160    C00022  pyruvic acid     832822.7
# 3 R00014 Pyruvic acid  88.0160    C00022  pyruvic acid     832822.7
# 4 R00014 Pyruvic acid  88.0160    C00022  pyruvic acid     832822.7
# 5 R00021 Glutamic acid 147.0532   C00025  L-glutamic acid 19334273
# 6 R00021 Glutamic acid 147.0532   C00025  L-glutamic acid 19334273
#   None_mean Fold_change log2Fold_change t_value   ⋯ metabolite_id super_class
# 1 1329176.8 1.595990    0.6744517       -4.517032 ⋯ ME056540      Organic acids
# 2 1329176.8 1.595990    0.6744517       -4.517032 ⋯ ME056540      Organic acids
# 3 1329176.8 1.595990    0.6744517       -4.517032 ⋯ ME056540      Organic acids
# 4 1329176.8 1.595990    0.6744517       -4.517032 ⋯ ME056540      Organic acids
# 5 33246732  1.719575    0.7820520       -5.288951 ⋯ ME056491      Organic acids
# 6 33246732  1.719575    0.7820520       -5.288951 ⋯ ME056491      Organic acids
#   main_class               sub_class         formula HG p-value
# 1 Short-chain acids        Short-chain acids C3H4O3  0.3671067738
# 2 Short-chain acids        Short-chain acids C3H4O3  0.3671067738
# 3 Short-chain acids        Short-chain acids C3H4O3  0.3671067738
# 4 Short-chain acids        Short-chain acids C3H4O3  0.3671067738
# 5 Amino acids and peptides Amino acids       C5H9NO4 0.0005100148
# 6 Amino acids and peptides Amino acids       C5H9NO4 0.0005100148
#   Rxn_name
# 1 4-hydroxy-4-methyl-2-oxoglutarate pyruvate-lyase (pyruvate-forming)
# 2 pyruvate:thiamin diphosphate acetaldehydetransferase (decarboxylating)
# 3 pyruvate:thiamin diphosphate acetaldehydetransferase (decarboxylating)
# 4 pyruvate:thiamin diphosphate acetaldehydetransferase (decarboxylating)
# 5 L-glutamate:ferredoxin oxidoreductase (transaminating)
# 6 L-glutamate:ferredoxin oxidoreductase (transaminating)
#   PATHWAY                                 pathway_id sps_path_id
# 1 Metabolic pathways                      rn01100    hsa01100
# 2 Glycolysis / Gluconeogenesis            rn00010    hsa00010
# 3 Citrate cycle (TCA cycle)               rn00020    hsa00020
# 4 Pyruvate metabolism                     rn00620    hsa00620
# 5 Glyoxylate and dicarboxylate metabolism rn00630    hsa00630
# 6 Nitrogen metabolism                     rn00910    hsa00910

# %% [markdown]
# Find metabolites for which no pathways were registered in Kegg and/or no kegg id was found

# %%
setdiff(metenrichment$Metabolite,unique(met_path$Metabolite))
# Out:
# [1] "glucoheptonic acid" "maltitol"

# %% [markdown]
# ### Get pathway enrichment sore.
#
# Once we have the pathway information, we can calculate enrichment score of pathways. Again, here i have used hypergeometric score. For hypergeometric score, we need to know the total number of kegg compounds that are linked to kegg pathways.
# N = total no. of cmpds linked to kegg pathway (this is the step which might take long), so I advice to run the script comp_linkedto_pathways() just the first time or after 6 months or so if desired to run the pipeline again. save the result from comp_linkedto_pathways() and load it. Loading from saved file would save time for another analysis with another study. However the package takes care of loading. Save the data in the data folder.
#
# L = No. of cmpds in a pathway
# M= no. of altered cmpds in a pathway
# K =  total no. of altered cmpds
# phyper(M,L, N-L, K)
#
#
# This function also utilizes korg dataset from pathview package.

# %%
load('../data/ls_path.RData')
load('../data/korg.RData')
kegg_es = path_enrichmentscore(met_path,sig_metabolite_kegg_id=sig_metabolite_kegg_id,ls_path=ls_path,refmet_class=refmet_class,sps='hsa',padj='BH', kegg_comp_path=FALSE)
# Out:
# Warning message in phyper(M - 1, L, N - L, k, lower.tail = FALSE):
# “NaNs produced”
# Warning message in phyper(M - 1, L, N - L, k, lower.tail = FALSE):
# “NaNs produced”
# Warning message in phyper(M - 1, L, N - L, k, lower.tail = FALSE):
# “NaNs produced”
# Warning message in phyper(M - 1, L, N - L, k, lower.tail = FALSE):
# “NaNs produced”
# Warning message in phyper(M - 1, L, N - L, k, lower.tail = FALSE):
# “NaNs produced”
# Warning message in phyper(M - 1, L, N - L, k, lower.tail = FALSE):
# “NaNs produced”
# Warning message in phyper(M - 1, L, N - L, k, lower.tail = FALSE):
# “NaNs produced”
# Warning message in phyper(M - 1, L, N - L, k, lower.tail = FALSE):
# “NaNs produced”
# Warning message in phyper(M - 1, L, N - L, k, lower.tail = FALSE):
# “NaNs produced”
# Warning message in phyper(M - 1, L, N - L, k, lower.tail = FALSE):
# “NaNs produced”

# %%
head(kegg_es)
# Out:
#   Pathway name                                No.of mets in study
# 1 Alanine, aspartate and glutamate metabolism  7
# 2 alpha-Linolenic acid metabolism              1
# 3 Amino sugar and nucleotide sugar metabolism  2
# 4 Aminoacyl-tRNA biosynthesis                 10
# 5 Arachidonic acid metabolism                  4
# 6 Arginine and proline metabolism              9
#   Total_no._of_comps_in_pathway pathway_HG p-value Padjust
# 1  28                           0.9999995            1
# 2  44                           1.0000000            1
# 3 118                                 NaN          NaN
# 4  52                           1.0000000            1
# 5  75                                 NaN          NaN
# 6  72                                 NaN          NaN

# %% [markdown]
# ### Plot pathway network
# Only plotting significant pathways (pathway with p-value significance).
#
# The pathway network is such that it shows metabolites that are connected to different pathways and same metabolite in different pathway. Color of nodes of metabolites are according to the fold change of metabolites (low expression in green and high in red) and size of pathway nodes (square nodes) are according to the number of branches (meaning no of metabolites). All metabolite are written in blue

# %%
plot_pathway_networks (met_path,kegg_es, TRUE)
# Out:
# Warning message:
# “ggrepel: 93 unlabeled data points (too many overlaps). Consider increasing max.overlaps”
# plot without title

# %% [markdown]
# ### Heatmap

# %%
plot_heatmap(met_path, shorten_name=TRUE,refmet_name=FALSE, xaxis=8, yaxis=6)
# Out:
# plot without title

# %% [markdown]
# ### Dotplot

# %%
dotplot_met_class_path (met_path, kegg_es,"sub_class",xaxis=8,yaxis=6)
# Out:
# Warning message:
# “Use of `significant_pathways[["pathway_HG p-value"]]` is discouraged. Use `.data[["pathway_HG p-value"]]` instead.”
# plot without title

# %% [markdown]
# ### Get the gene and enzyme info
#
# Here we get the information of genes involved in enriched pathways for specified organism

# %%
met_gene_info = enzyme_gene_info (metenrichment, "hsa","sub_class")
head(met_gene_info)
# Out:
#   orthology_id ORTHOLOGY                              gene_id
# 1 K00008       L-iditol 2-dehydrogenase [EC:1.1.1.14] 6652
# 2 K00008       L-iditol 2-dehydrogenase [EC:1.1.1.14] 6652
# 3 K00011       aldehyde reductase [EC:1.1.1.21]       231
# 4 K00011       aldehyde reductase [EC:1.1.1.21]       57016
# 5 K00016       L-lactate dehydrogenase [EC:1.1.1.27]  160287
# 6 K00016       L-lactate dehydrogenase [EC:1.1.1.27]  3939
#   gene_name                                        ORGANISM
# 1 (RefSeq) sorbitol dehydrogenase                  Homo sapiens (human)
# 2 (RefSeq) sorbitol dehydrogenase                  Homo sapiens (human)
# 3 (RefSeq) aldo-keto reductase family 1 member B   Homo sapiens (human)
# 4 (RefSeq) aldo-keto reductase family 1 member B10 Homo sapiens (human)
# 5 (RefSeq) lactate dehydrogenase A like 6A         Homo sapiens (human)
# 6 (RefSeq) lactate dehydrogenase A                 Homo sapiens (human)
#   PATHWAY
# 1 Pentose and glucuronate interconversions, Fructose and mannose metabolism         , Metabolic pathways
# 2 Pentose and glucuronate interconversions, Fructose and mannose metabolism         , Metabolic pathways
# 3 Pentose and glucuronate interconversions, Fructose and mannose metabolism         , Galactose metabolism                    , Glycerolipid metabolism                 , Folate biosynthesis                     , Metabolic pathways
# 4 Pentose and glucuronate interconversions, Fructose and mannose metabolism         , Galactose metabolism                    , Glycerolipid metabolism                 , Folate biosynthesis                     , Metabolic pathways
# 5 Glycolysis / Gluconeogenesis       , Cysteine and methionine metabolism , Pyruvate metabolism                , Propanoate metabolism              , Metabolic pathways                 , HIF-1 signaling pathway            , Glucagon signaling pathway         , Central carbon metabolism in cancer
# 6 Glycolysis / Gluconeogenesis       , Cysteine and methionine metabolism , Pyruvate metabolism                , Propanoate metabolism              , Metabolic pathways                 , HIF-1 signaling pathway            , Glucagon signaling pathway         , Central carbon metabolism in cancer
#   DBLINKS
# 1 NCBI-GeneID: 6652        , NCBI-ProteinID: NP_003095, OMIM: 182500             , HGNC: 11184              , Ensembl: ENSG00000140263 , Vega: OTTHUMG00000131265 , Pharos: Q00796(Tchem)    , UniProt: Q00796
# 2 NCBI-GeneID: 6652        , NCBI-ProteinID: NP_003095, OMIM: 182500             , HGNC: 11184              , Ensembl: ENSG00000140263 , Vega: OTTHUMG00000131265 , Pharos: Q00796(Tchem)    , UniProt: Q00796
# 3 NCBI-GeneID: 231          , NCBI-ProteinID: NP_001619 , OMIM: 103880              , HGNC: 381                 , Ensembl: ENSG00000085662  , Vega: OTTHUMG00000155322  , Pharos: P15121(Tclin)     , UniProt: P15121 A0A024R7A8
# 4 NCBI-GeneID: 57016       , NCBI-ProteinID: NP_064695, OMIM: 604707             , HGNC: 382                , Ensembl: ENSG00000198074 , Vega: OTTHUMG00000155356 , Pharos: O60218(Tchem)    , UniProt: O60218
# 5 NCBI-GeneID: 160287         , NCBI-ProteinID: NP_001137543, OMIM: 618928                , HGNC: 28335                 , Ensembl: ENSG00000166800    , Vega: OTTHUMG00000167724    , Pharos: Q6ZMR3(Tbio)        , UniProt: Q6ZMR3
# 6 NCBI-GeneID: 3939        , NCBI-ProteinID: NP_005557, OMIM: 150000             , HGNC: 6535               , Ensembl: ENSG00000134333 , Vega: OTTHUMG00000167721 , Pharos: P00338(Tchem)    , UniProt: P00338 V9HWB9
#   MOTIF
# 1 Pfam: ADH_N ADH_zinc_N Glu_dehyd_C AlaDh_PNT_C Pyr_redox_2 DUF2921 ADH_zinc_N_2 Methyltransf_25 2-Hacid_dh_C
# 2 Pfam: ADH_N ADH_zinc_N Glu_dehyd_C AlaDh_PNT_C Pyr_redox_2 DUF2921 ADH_zinc_N_2 Methyltransf_25 2-Hacid_dh_C
# 3 Pfam: Aldo_ket_red
# 4 Pfam: Aldo_ket_red HU-CCDC81_euk_1
# 5 Pfam: Ldh_1_N Ldh_1_C Glyco_hydro_4 UDPG_MGDP_dh_N Disaggr_assoc ThiF DUF6154 Mig-14
# 6 Pfam: Ldh_1_N Ldh_1_C Glyco_hydro_4 Pyr_redox_2 Glyco_hydro_4C
#   rxn    Metabolite   KEGG ID sub_class
# 1 R00875 D-sorbitol   C00794  Sugar alcohols
# 2 R00875 fructose     C00095  Hexoses
# 3 R01787 D-sorbitol   C00794  Sugar alcohols
# 4 R01787 D-sorbitol   C00794  Sugar alcohols
# 5 R00703 pyruvic acid C00022  Short-chain acids
# 6 R00703 pyruvic acid C00022  Short-chain acids
#   Rxn_name
# 1 D-Glucitol:NAD+ 2-oxidoreductase
# 2 D-Glucitol:NAD+ 2-oxidoreductase
# 3 D-Glucitol:NADP+ 1-oxidoreductase
# 4 D-Glucitol:NADP+ 1-oxidoreductase
# 5 (S)-Lactate:NAD+ oxidoreductase
# 6 (S)-Lactate:NAD+ oxidoreductase
#   RCLASS
# 1 RC00001  C00003_C00004, RC00085  C00095_C00794
# 2 RC00001  C00003_C00004, RC00085  C00095_C00794
# 3 RC00001  C00005_C00006, RC00108  C00267_C00794
# 4 RC00001  C00005_C00006, RC00108  C00267_C00794
# 5 RC00001  C00003_C00004, RC00044  C00022_C00186
# 6 RC00001  C00003_C00004, RC00044  C00022_C00186
#   EQUATION
# 1 C00794 + C00003 <=> C00095 + C00004 + C00080
# 2 C00794 + C00003 <=> C00095 + C00004 + C00080
# 3 C00794 + C00006 <=> C00267 + C00005 + C00080
# 4 C00794 + C00006 <=> C00267 + C00005 + C00080
# 5 C00186 + C00003 <=> C00022 + C00004 + C00080
# 6 C00186 + C00003 <=> C00022 + C00004 + C00080
#   EQUATION_more                                       ENZYME
# 1 D-Sorbitol + NAD+ <=> D-Fructose + NADH + H+        1.1.1.14, 1.1.1.15
# 2 D-Sorbitol + NAD+ <=> D-Fructose + NADH + H+        1.1.1.14, 1.1.1.15
# 3 D-Sorbitol + NADP+ <=> alpha-D-Glucose + NADPH + H+ 1.1.1.21
# 4 D-Sorbitol + NADP+ <=> alpha-D-Glucose + NADPH + H+ 1.1.1.21
# 5 (S)-Lactate + NAD+ <=> Pyruvate + NADH + H+         1.1.1.27
# 6 (S)-Lactate + NAD+ <=> Pyruvate + NADH + H+         1.1.1.27

# %% [markdown]
# #### Get the information if metabolite is a reactant or substrate

# %%
rclass_info = react_substrate(met_gene_info)
head(rclass_info)
# Out:
#   orthology_id ORTHOLOGY                              gene_id
# 1 K00008       L-iditol 2-dehydrogenase [EC:1.1.1.14] 6652
# 2 K00008       L-iditol 2-dehydrogenase [EC:1.1.1.14] 6652
# 3 K00011       aldehyde reductase [EC:1.1.1.21]       231
# 4 K00011       aldehyde reductase [EC:1.1.1.21]       57016
# 5 K00016       L-lactate dehydrogenase [EC:1.1.1.27]  160287
# 6 K00016       L-lactate dehydrogenase [EC:1.1.1.27]  3939
#   gene_name                                        ORGANISM
# 1 (RefSeq) sorbitol dehydrogenase                  Homo sapiens (human)
# 2 (RefSeq) sorbitol dehydrogenase                  Homo sapiens (human)
# 3 (RefSeq) aldo-keto reductase family 1 member B   Homo sapiens (human)
# 4 (RefSeq) aldo-keto reductase family 1 member B10 Homo sapiens (human)
# 5 (RefSeq) lactate dehydrogenase A like 6A         Homo sapiens (human)
# 6 (RefSeq) lactate dehydrogenase A                 Homo sapiens (human)
#   PATHWAY
# 1 Pentose and glucuronate interconversions, Fructose and mannose metabolism         , Metabolic pathways
# 2 Pentose and glucuronate interconversions, Fructose and mannose metabolism         , Metabolic pathways
# 3 Pentose and glucuronate interconversions, Fructose and mannose metabolism         , Galactose metabolism                    , Glycerolipid metabolism                 , Folate biosynthesis                     , Metabolic pathways
# 4 Pentose and glucuronate interconversions, Fructose and mannose metabolism         , Galactose metabolism                    , Glycerolipid metabolism                 , Folate biosynthesis                     , Metabolic pathways
# 5 Glycolysis / Gluconeogenesis       , Cysteine and methionine metabolism , Pyruvate metabolism                , Propanoate metabolism              , Metabolic pathways                 , HIF-1 signaling pathway            , Glucagon signaling pathway         , Central carbon metabolism in cancer
# 6 Glycolysis / Gluconeogenesis       , Cysteine and methionine metabolism , Pyruvate metabolism                , Propanoate metabolism              , Metabolic pathways                 , HIF-1 signaling pathway            , Glucagon signaling pathway         , Central carbon metabolism in cancer
#   DBLINKS
# 1 NCBI-GeneID: 6652        , NCBI-ProteinID: NP_003095, OMIM: 182500             , HGNC: 11184              , Ensembl: ENSG00000140263 , Vega: OTTHUMG00000131265 , Pharos: Q00796(Tchem)    , UniProt: Q00796
# 2 NCBI-GeneID: 6652        , NCBI-ProteinID: NP_003095, OMIM: 182500             , HGNC: 11184              , Ensembl: ENSG00000140263 , Vega: OTTHUMG00000131265 , Pharos: Q00796(Tchem)    , UniProt: Q00796
# 3 NCBI-GeneID: 231          , NCBI-ProteinID: NP_001619 , OMIM: 103880              , HGNC: 381                 , Ensembl: ENSG00000085662  , Vega: OTTHUMG00000155322  , Pharos: P15121(Tclin)     , UniProt: P15121 A0A024R7A8
# 4 NCBI-GeneID: 57016       , NCBI-ProteinID: NP_064695, OMIM: 604707             , HGNC: 382                , Ensembl: ENSG00000198074 , Vega: OTTHUMG00000155356 , Pharos: O60218(Tchem)    , UniProt: O60218
# 5 NCBI-GeneID: 160287         , NCBI-ProteinID: NP_001137543, OMIM: 618928                , HGNC: 28335                 , Ensembl: ENSG00000166800    , Vega: OTTHUMG00000167724    , Pharos: Q6ZMR3(Tbio)        , UniProt: Q6ZMR3
# 6 NCBI-GeneID: 3939        , NCBI-ProteinID: NP_005557, OMIM: 150000             , HGNC: 6535               , Ensembl: ENSG00000134333 , Vega: OTTHUMG00000167721 , Pharos: P00338(Tchem)    , UniProt: P00338 V9HWB9
#   MOTIF
# 1 Pfam: ADH_N ADH_zinc_N Glu_dehyd_C AlaDh_PNT_C Pyr_redox_2 DUF2921 ADH_zinc_N_2 Methyltransf_25 2-Hacid_dh_C
# 2 Pfam: ADH_N ADH_zinc_N Glu_dehyd_C AlaDh_PNT_C Pyr_redox_2 DUF2921 ADH_zinc_N_2 Methyltransf_25 2-Hacid_dh_C
# 3 Pfam: Aldo_ket_red
# 4 Pfam: Aldo_ket_red HU-CCDC81_euk_1
# 5 Pfam: Ldh_1_N Ldh_1_C Glyco_hydro_4 UDPG_MGDP_dh_N Disaggr_assoc ThiF DUF6154 Mig-14
# 6 Pfam: Ldh_1_N Ldh_1_C Glyco_hydro_4 Pyr_redox_2 Glyco_hydro_4C
#   rxn    Metabolite   KEGG ID sub_class
# 1 R00875 D-sorbitol   C00794  Sugar alcohols
# 2 R00875 fructose     C00095  Hexoses
# 3 R01787 D-sorbitol   C00794  Sugar alcohols
# 4 R01787 D-sorbitol   C00794  Sugar alcohols
# 5 R00703 pyruvic acid C00022  Short-chain acids
# 6 R00703 pyruvic acid C00022  Short-chain acids
#   Rxn_name
# 1 D-Glucitol:NAD+ 2-oxidoreductase
# 2 D-Glucitol:NAD+ 2-oxidoreductase
# 3 D-Glucitol:NADP+ 1-oxidoreductase
# 4 D-Glucitol:NADP+ 1-oxidoreductase
# 5 (S)-Lactate:NAD+ oxidoreductase
# 6 (S)-Lactate:NAD+ oxidoreductase
#   RCLASS
# 1 RC00001  C00003_C00004, RC00085  C00095_C00794
# 2 RC00001  C00003_C00004, RC00085  C00095_C00794
# 3 RC00001  C00005_C00006, RC00108  C00267_C00794
# 4 RC00001  C00005_C00006, RC00108  C00267_C00794
# 5 RC00001  C00003_C00004, RC00044  C00022_C00186
# 6 RC00001  C00003_C00004, RC00044  C00022_C00186
#   EQUATION
# 1 C00794 + C00003 <=> C00095 + C00004 + C00080
# 2 C00794 + C00003 <=> C00095 + C00004 + C00080
# 3 C00794 + C00006 <=> C00267 + C00005 + C00080
# 4 C00794 + C00006 <=> C00267 + C00005 + C00080
# 5 C00186 + C00003 <=> C00022 + C00004 + C00080
# 6 C00186 + C00003 <=> C00022 + C00004 + C00080
#   EQUATION_more                                       ENZYME
# 1 D-Sorbitol + NAD+ <=> D-Fructose + NADH + H+        1.1.1.14, 1.1.1.15
# 2 D-Sorbitol + NAD+ <=> D-Fructose + NADH + H+        1.1.1.14, 1.1.1.15
# 3 D-Sorbitol + NADP+ <=> alpha-D-Glucose + NADPH + H+ 1.1.1.21
# 4 D-Sorbitol + NADP+ <=> alpha-D-Glucose + NADPH + H+ 1.1.1.21
# 5 (S)-Lactate + NAD+ <=> Pyruvate + NADH + H+         1.1.1.27
# 6 (S)-Lactate + NAD+ <=> Pyruvate + NADH + H+         1.1.1.27
#   reactant_product
# 1 Substrate
# 2 Product
# 3 Substrate
# 4 Substrate
# 5 Product
# 6 Product

# %% [markdown]
# #### Get gene info in short form

# %%
met_gene_info2=data.table::data.table(rclass_info)[,lapply(.SD, function(x) toString(unique(x))), by = 'Metabolite']
