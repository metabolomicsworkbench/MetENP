# %% [markdown]
# ## MetENP

# %% [markdown]
# MetENP is a R package that enables detection of significant metabolites from metabolite information
# (names or names and concentration along with metadata information) and provides
#
# 1. Enrichment score of metabolite class,
# 2. Maps to pathway of the species of choice,
# 3. Calculate enrichment score of pathways,
# 4. Plots the pathways and shows the metabolite increase or decrease
# 5. Gets gene info, reaction info, enzyme info
#
# For more info, check out the vignette.

# %%
if (!requireNamespace("KEGGREST", quietly = TRUE))
    BiocManager::install("KEGGREST", update = TRUE, ask = FALSE)

if (!requireNamespace("KEGGgraph", quietly = TRUE))
    BiocManager::install("KEGGgraph", update = TRUE, ask = FALSE)

if (!requireNamespace("pathview", quietly = TRUE))
    BiocManager::install("pathview", update = TRUE, ask = FALSE)

#if (!requireNamespace("KEGG.db", quietly = TRUE))
#    BiocManager::install("KEGG.db", update = TRUE, ask = FALSE)

#if (!requireNamespace("MetENP", quietly = TRUE))
#    devtools::install("..", upgrade = "never")
# Out:
# ##############################################################################
# Pathview is an open source software package distributed under GNU General
# Public License version 3 (GPLv3). Details of GPLv3 is available at
# http://www.gnu.org/licenses/gpl-3.0.html. Particullary, users are required to
# formally cite the original Pathview paper (not just mention it) in publications
# or products. For details, do citation("pathview") within R.
#
# The pathview downloads and uses KEGG data. Non-academic uses may require a KEGG
# license agreement (details at http://www.kegg.jp/kegg/legal.html).
# ##############################################################################

# %%
USER_HOME=Sys.getenv("HOME");
USER_PWD=Sys.getenv("PWD");
#.libPaths( c( .libPaths(), paste0(USER_HOME, "/.local/R") ))
.libPaths( c( .libPaths(), paste0(USER_PWD, "/../../R") )); # suitable path to where MetENP R package is installed
#.libPaths( c( .libPaths(), paste0("../../R") )); # suitable path to where MetENP R package is installed

library(MetENP)

# %% [markdown]
# #### If you do not wish to install, alternatively, download from github(https://github.com/metabolomicsworkbench/MetENP) and load libraries and functions
# #### Complete information for this study is at Metabolomics Workbench: https://www.metabolomicsworkbench.org/data/DRCCMetadata.php?Mode=Study&StudyID=ST001742&StudyType=MS&ResultType=1

# %%
data = getmwstudies('ST001742', 'data')
head(data)
# Out:
#   analysis_id <NA>     <NA>     <NA>     <NA>     <NA>
# 1 AN002835    AN002835 AN002835 AN002835 AN002835 AN002835
# 2 AN002835    AN002835 AN002835 AN002835 AN002835 AN002835
# 3 AN002835    AN002835 AN002835 AN002835 AN002835 AN002835
# 4 AN002835    AN002835 AN002835 AN002835 AN002835 AN002835
# 5 AN002835    AN002835 AN002835 AN002835 AN002835 AN002835
# 6 AN002835    AN002835 AN002835 AN002835 AN002835 AN002835
#   analysis_summary                 <NA>
# 1 Reversed phase POSITIVE ION MODE Reversed phase POSITIVE ION MODE
# 2 Reversed phase POSITIVE ION MODE Reversed phase POSITIVE ION MODE
# 3 Reversed phase POSITIVE ION MODE Reversed phase POSITIVE ION MODE
# 4 Reversed phase POSITIVE ION MODE Reversed phase POSITIVE ION MODE
# 5 Reversed phase POSITIVE ION MODE Reversed phase POSITIVE ION MODE
# 6 Reversed phase POSITIVE ION MODE Reversed phase POSITIVE ION MODE
#   <NA>                             <NA>
# 1 Reversed phase POSITIVE ION MODE Reversed phase POSITIVE ION MODE
# 2 Reversed phase POSITIVE ION MODE Reversed phase POSITIVE ION MODE
# 3 Reversed phase POSITIVE ION MODE Reversed phase POSITIVE ION MODE
# 4 Reversed phase POSITIVE ION MODE Reversed phase POSITIVE ION MODE
# 5 Reversed phase POSITIVE ION MODE Reversed phase POSITIVE ION MODE
# 6 Reversed phase POSITIVE ION MODE Reversed phase POSITIVE ION MODE
#   <NA>                             <NA>
# 1 Reversed phase POSITIVE ION MODE Reversed phase POSITIVE ION MODE
# 2 Reversed phase POSITIVE ION MODE Reversed phase POSITIVE ION MODE
# 3 Reversed phase POSITIVE ION MODE Reversed phase POSITIVE ION MODE
# 4 Reversed phase POSITIVE ION MODE Reversed phase POSITIVE ION MODE
# 5 Reversed phase POSITIVE ION MODE Reversed phase POSITIVE ION MODE
# 2 11478.60464 31763.75377 92889.33492 9875.43014  40756.30399 17399.70095
# 3 4.146259126 8.353208935 10.91257184 6.099251084 5.195388551 6.97366592
# 4 6.804079154 12.74068831 6.378753611 13.99634318 13.13583241 7.673885187
# 5 749.3364268 773.4878614 673.8675982 391.9905678 266.7322365 379.9625815
# 6 64.6119919  139.7284615 551.8659937 61.28839221 181.0027097 94.54981867
#   355594      355837      359130      360399
# 1 31.16531679 34.44025249 38.87615423 26.70799305
# 2 24530.2907  1756.482726 23773.25756 3856.904703
# 3 7.320597283 3.483861703 14.40905702 8.004050357
# 4 7.740948127 16.49699689 9.562101201 12.74049231
# 5 422.6758837 544.6729219 908.7220538 674.2418789
# 6 136.7332773 28.43724001 115.6095058 48.53054662

# %%
metadata = getmwstudies('ST001742', 'factors')
head(metadata)
# Out:
#   study_id local_sample_id sample_source factors      mb_sample_id raw_data
# 1 ST001742 213267          Blood (s....  Group:Di.... SA163223     QE2_jdg_....
# 2 ST001742 213269          Blood (s....  Group:Di.... SA163222     QE2_jdg_....
# 3 ST001742 313074          Blood (s....  Group:Di.... SA163214     QE2_jdg_....
# 4 ST001742 313390          Blood (s....  Group:Di.... SA163226     QE2_jdg_....
# 5 ST001742 321588          Blood (s....  Group:Di.... SA163212     QE2_jdg_....
# 6 ST001742 325103          Blood (s....  Group:Di.... SA163225     QE2_jdg_....
#   Group    Fasted vs Fed
# 1 Diabetic Fasted
# 2 Diabetic Fasted
# 3 Diabetic Fasted
# 4 Diabetic Fasted
# 5 Diabetic Fasted
# 6 Diabetic Fasted

# %% [markdown]
# Find the factors you would want to compare
# Multiple factors (independent variables) are formatted in multiple columns but you can get information on all the factors by "factors" column, such as 'TreatmentGroup:Prednisolone', this indicates column name 'TreatmentGroup' with factor Prednisolone. For t-test use the factors in the same column. For comparing multipe independent variables use anova by anova_ana function.

# %% [markdown]
# ### Associate metabolomics data to the refmet class

# %%
refmet_class= convert_refmet(data)
head(refmet_class)
# Out:
#   metabolite_name               analysis_id analysis_summary metabolite_id
# 1 2-hydroxyisobutyric acid      AN002835    Reversed....     ME404305
# 2 2,6-diaminoheptanedioate      AN002835    Reversed....     ME404278
# 3 5-hydroxymethyl-2-furaldehyde AN002835    Reversed....     ME404288
# 4 Anthranilic Acid              AN002835    Reversed....     ME404294
# 5 Aspartate                     AN002835    Reversed....     ME404303
# 6 Citramalate                   AN002835    Reversed....     ME404286
#   refmet_name  213267      213269      216422      223169      228415      ⋯
# 1 2-Hydrox.... 3571.687583 2952.862803 38279.31664 3715.782167 1962.831232 ⋯
# 2 2,6-Diam.... 28.4614691  28.60232679 33.55073235 46.96524744 34.92883405 ⋯
# 3 5-Hydrox.... 16.24609734 6.392339286 14.4979182  4.034452254 10.86824845 ⋯
# 4 2-Aminob.... 10.23251016 15.82498698 8.735853444 38.47294933 19.38540371 ⋯
# 5 Aspartic.... 863.7467866 602.4521282 793.6813074 579.293206  741.8745409 ⋯
# 6 Citramal.... 22.75803679 23.19046427 126.5162935 23.99330464 17.84786488 ⋯
#   354675      355594      355837      359130      360399      formula
# 1 17399.70095 24530.2907  1756.482726 23773.25756 3856.904703 C4H8O3
# 2 41.08337062 31.16531679 34.44025249 38.87615423 26.70799305 C7H14N2O4
# 3 6.97366592  7.320597283 3.483861703 14.40905702 8.004050357 C6H6O3
# 4 7.673885187 7.740948127 16.49699689 9.562101201 12.74049231 C7H7NO2
# 5 379.9625815 422.6758837 544.6729219 908.7220538 674.2418789 C4H7NO4
# 6 94.54981867 136.7332773 28.43724001 115.6095058 48.53054662 C5H8O5
#   super_class              main_class               sub_class
# 1 Fatty Acyls              Fatty acids              Hydroxy FA
# 2 Organic acids            Amino acids and peptides Amino acids
# 3 Organic oxygen compounds Carbonyl compounds       Aryl aldehydes
# 4 Benzenoids               Benzenes                 Aminobenzoic acids
# 5 Organic acids            Amino acids and peptides Amino acids
# 6 Organic acids            Hydroxy acids            Beta hydroxy acids
#   refmet_id
# 1 RM0139716
# 2 RM0136793
# 3 RM0038424
# 4 RM0013238
# 5 RM0135905
# 6 RM0042389

# %%
unique(metadata$factors)
# Out:
# [[1]]
# [1] "Group:Diabetic | Fasted vs Fed:Fasted"
#
# [[2]]
# [1] "Group:Diabetic | Fasted vs Fed:Fed"
#
# [[3]]
# [1] "Group:Healthy | Fasted vs Fed:Fasted"
#
# [[4]]
# [1] "Group:Healthy | Fasted vs Fed:Fed"

# %%
### Find the analysis mode
unique(data$analysis_summary)
# Out:
# [[1]]
# [1] "Reversed phase POSITIVE ION MODE"

# %% [markdown]
# ### Find significant metabolites, run significance of all the analysis summary together. The analysis summary/modes you got in the previous section
# There is a normalization step which takes into account missing values, and this can be achieved via three methods:
#
# 1) half_of_min: where the NAs are replaced by half of min values in the data
#
# 2) remove_NAs: where Cols with NAs values are removed
#
# 3) 50percent: where cols with more than 50% NAs values are removed, and then the remaining NA values are replaced with half_of_min
#
# half_of_min is ideal when you wish to see which metabolites were present in either group. Very high fold change would mean it was present in either group.

# %%
stats_metabolites = significant_met(metabolomics_data=refmet_class, met_col="metabolite_name",analysis_type=c('Reversed phase POSITIVE ION MODE'), metadata=metadata, factor1='Healthy', factor2=c('Diabetic'), factor_col='Group',sample_col='local_sample_id', p_adjust='fdr',normalization="50percent")

sig_metabolites = stats_metabolites[which(stats_metabolites[,"pval"] <= 0.05&abs(stats_metabolites[,"log2Fold_change"])>0.5),]

# %%
plot_volcano(stats_metabolites, thres_pval= 0.05,thres_log2foldchange = 0.0, TRUE)
# Out:
# plot without title

# %% [markdown]
# ### Map metabolite class of the significant metabolites utilzing refmet classification in Metabolomics Workbench
# This function not only maps metabolite to metabolite class but also to external databases such as pubchem, inchi key, smiles and kegg
#
# In this example, we will go forward with significant metabolite obtained by t-test/

# %%
sig_metabolites_kegg_id= map_keggid(sig_metabolites)

# %% [markdown]
# #### Check all your significant metabolites have not been assigned metabolite class

# %%
setdiff(sig_metabolites$refmet_name, sig_metabolites_kegg_id$refmet_name)
# Out:
# [1] ""

# %% [markdown]
# ### Count metabolites in each of the metabolite class and plotting
# You may choose from sub_class, main_class and super_class

# %%
count_changes = metcountplot(df_metclass=sig_metabolites_kegg_id, metclass='sub_class', plotting=TRUE, thres_logfC = 0.0, updown_fillcolor=c("red", "green"))
print(count_changes$sig_met_count)
# Out:
#                    sub_class No.of_metabolites                 color
# 1                Amino acids                 3 increased metabolites
# 2                   Amino FA                 1 increased metabolites
# 3                 Hydroxy FA                 1 increased metabolites
# 4 Pyrimidine ribonucleosides                 1 increased metabolites
# 5                Amino acids                -2 decreased metabolites
# 6         Aminobenzoic acids                -1 decreased metabolites
# 7             C24 bile acids                -1 decreased metabolites
# 8    Simple indole alkaloids                -1 decreased metabolites

# %%
count_changes$plotimg
# Out:
# Warning message:
# “Use of `count_changes[[metclass]]` is discouraged.
# ℹ Use `.data[[metclass]]` instead.”
# plot without title

# %% [markdown]
# ### Enrichment class score
#
# Calculate the enrichment score of each metabolite class. Enrichment score is calculated through hypergeometric method. One can specify the no. of significant metabolites in a class while calculating the enrichment score. We advice to use the number of mtabolites in each class as 3 or more. But if someone just wants to know the enrichment score and rest of the information of all the metabolites, then they can choose the number as 1.

# %%
# pass debug = 0 below or comment some lines to suppress some print output
metenrichment = metclassenrichment(df_metclass=sig_metabolites_kegg_id,refmet_class, metclass="sub_class",enrich_stats="HG",no=1, debug = 1)
print(head(metenrichment))
#knitr::kable(head(metenrichment))
metenrichment[metenrichment$main_class %in% c("Ceramides", "Sphingomyelins"), c("Metabolite", "pval", "super_class", "main_class", "sub_class", "HG p-value")]
colnames(metenrichment)
metenrichment$super_class
metenrichment$main_class
metenrichment$sub_class
# Out:
# [1] "Name = 2-Aminobenzoic acid"
# [1] "M = 1"                  "L = 11"                 "N = 28"
# [4] "k = 1"                  "pp = 0.392857142857143"
# [1] "Name = 2-Hydroxyisobutyric acid"
# [1] "M = 1"                  "L = 11"                 "N = 28"
# [4] "k = 1"                  "pp = 0.392857142857143"
# [1] "Name = gamma-Aminobutyric acid"
# [1] "M = 1"                  "L = 11"                 "N = 28"
# [4] "k = 1"                  "pp = 0.392857142857143"
# [1] "Name = Indoxyl sulfate"
# [1] "M = 1"                  "L = 11"                 "N = 28"
# [4] "k = 1"                  "pp = 0.392857142857143"
# [1] "Name = Isoleucine"
# [1] "M = 5"                  "L = 11"                 "N = 28"
# [4] "k = 13"                 "pp = 0.679977116704806"
# [1] "Name = Kynurenine"
# [1] "M = 5"                  "L = 11"                 "N = 28"
# [4] "k = 13"                 "pp = 0.679977116704806"
# [1] "Name = Leucine"
# [1] "M = 5"                  "L = 11"                 "N = 28"
# [4] "k = 13"                 "pp = 0.679977116704806"
# [1] "Name = N-Acetylaspartic acid"
# [1] "M = 5"                  "L = 11"                 "N = 28"
# [4] "k = 13"                 "pp = 0.679977116704806"
# [1] "Name = Tauroursodeoxycholic acid"
# [1] "M = 1"                  "L = 11"                 "N = 28"
# [4] "k = 1"                  "pp = 0.392857142857143"
# [1] "Name = Uridine"
# [1] "M = 1"                  "L = 11"                 "N = 28"
# [4] "k = 1"                  "pp = 0.392857142857143"
# [1] "Name = Valine"
# [1] "M = 5"                  "L = 11"                 "N = 28"
# [4] "k = 13"                 "pp = 0.679977116704806"
#                refmet_name Exact mass KEGG ID               Metabolite
# 1      2-Aminobenzoic acid   137.0477  C00108         Anthranilic Acid
# 2 2-Hydroxyisobutyric acid   104.0473  C21297 2-hydroxyisobutyric acid
# 3  gamma-Aminobutyric acid   103.0633  C00334                     GABA
# 4          Indoxyl sulfate   213.0096                  Indoxyl Sulfate
# 5               Isoleucine   131.0946  C00407               Isoleucine
# 6               Kynurenine   208.0848  C00328               Kynurenine
#   Diabetic_mean Healthy_mean Fold_change log2Fold_change   t_value         pval
# 1      12.88778     24.11389   0.5344546      -0.9038606  3.880063 3.431822e-04
# 2      31555.58      5225.50   6.0387676       2.5942541 -2.480177 1.983824e-02
# 3      4531.228     2014.099   2.2497544       1.1697675 -5.200169 1.316566e-05
# 4      2283.884     9295.648   0.2456939      -2.0250661  4.480856 1.027743e-04
# 5     19080.747     8850.267   2.1559516       1.1083248 -3.588984 1.264372e-03
# 6      528.7990     886.8297   0.5962802      -0.7459376  4.052509 1.946157e-04
#           padj metabolite_id   super_class               main_class
# 1 0.0009914151      ME404294    Benzenoids                 Benzenes
# 2 0.0368424513      ME404305   Fatty Acyls              Fatty acids
# 3 0.0001141024      ME404281   Fatty Acyls              Fatty acids
# 4 0.0006680327      ME404301     Alkaloids     Tryptophan alkaloids
# 5 0.0032873674      ME404285 Organic acids Amino acids and peptides
# 6 0.0007257083      ME404289 Organic acids Amino acids and peptides
#                 sub_class    formula HG p-value
# 1      Aminobenzoic acids    C7H7NO2  0.3928571
# 2              Hydroxy FA     C4H8O3  0.3928571
# 3                Amino FA    C4H9NO2  0.3928571
# 4 Simple indole alkaloids   C8H7NO4S  0.3928571
# 5             Amino acids   C6H13NO2  0.6799771
# 6             Amino acids C10H12N2O3  0.6799771
#      Metabolite pval super_class main_class sub_class HG p-value
#  [1] "refmet_name"     "Exact mass"      "KEGG ID"         "Metabolite"
#  [5] "Diabetic_mean"   "Healthy_mean"    "Fold_change"     "log2Fold_change"
#  [9] "t_value"         "pval"            "padj"            "metabolite_id"
# [13] "super_class"     "main_class"      "sub_class"       "formula"
# [17] "HG p-value"
#  [1] "Benzenoids"    "Fatty Acyls"   "Fatty Acyls"   "Alkaloids"
#  [5] "Organic acids" "Organic acids" "Organic acids" "Organic acids"
#  [9] "Sterol Lipids" "Nucleic acids" "Organic acids"
#  [1] "Benzenes"                 "Fatty acids"
#  [3] "Fatty acids"              "Tryptophan alkaloids"
#  [5] "Amino acids and peptides" "Amino acids and peptides"
#  [7] "Amino acids and peptides" "Amino acids and peptides"
#  [9] "Bile acids"               "Pyrimidines"
# [11] "Amino acids and peptides"
#  [1] "Aminobenzoic acids"         "Hydroxy FA"
#  [3] "Amino FA"                   "Simple indole alkaloids"
#  [5] "Amino acids"                "Amino acids"
#  [7] "Amino acids"                "Amino acids"
#  [9] "C24 bile acids"             "Pyrimidine ribonucleosides"
# [11] "Amino acids"

# %% [markdown]
# #### Plot the enrichment score via function plot_met_enrichment

# %%
plot_met_enrichment(metenrichment, "sub_class","HG", no=1)
# Out:
# Warning message:
# “Use of `metclass_stats[[metclass]]` is discouraged.
# ℹ Use `.data[[metclass]]` instead.”
# Warning message:
# “Use of `metclass_stats[[enrich_stats]]` is discouraged.
# ℹ Use `.data[[enrich_stats]]` instead.”
# Warning message:
# “Use of `metclass_stats[[enrich_stats]]` is discouraged.
# ℹ Use `.data[[enrich_stats]]` instead.”
# plot without title

# %% [markdown]
# ### Check the pathways with reactions of all the significant metabolites

# %%
met_path = met_pathways(df_metenrichment = metenrichment, 'hsa')
head(met_path)
# Out:
#   rxn    refmet_name             Exact mass KEGG ID Metabolite
# 1 R00261 gamma-Aminobutyric acid 103.0633   C00334  GABA
# 2 R00261 gamma-Aminobutyric acid 103.0633   C00334  GABA
# 3 R00261 gamma-Aminobutyric acid 103.0633   C00334  GABA
# 4 R00487 N-Acetylaspartic acid   175.0481   C01042  N-acetyl-L-aspartic_Acid
# 5 R00487 N-Acetylaspartic acid   175.0481   C01042  N-acetyl-L-aspartic_Acid
# 6 R00488 N-Acetylaspartic acid   175.0481   C01042  N-acetyl-L-aspartic_Acid
#   Diabetic_mean Healthy_mean Fold_change log2Fold_change t_value   ⋯
# 1 4531.228      2014.099     2.2497544    1.1697675      -5.200169 ⋯
# 2 4531.228      2014.099     2.2497544    1.1697675      -5.200169 ⋯
# 3 4531.228      2014.099     2.2497544    1.1697675      -5.200169 ⋯
# 4 47.97055      74.16062     0.6468467   -0.6285043       5.574898 ⋯
# 5 47.97055      74.16062     0.6468467   -0.6285043       5.574898 ⋯
# 6 47.97055      74.16062     0.6468467   -0.6285043       5.574898 ⋯
#   metabolite_id super_class   main_class               sub_class   formula
# 1 ME404281      Fatty Acyls   Fatty acids              Amino FA    C4H9NO2
# 2 ME404281      Fatty Acyls   Fatty acids              Amino FA    C4H9NO2
# 3 ME404281      Fatty Acyls   Fatty acids              Amino FA    C4H9NO2
# 4 ME404283      Organic acids Amino acids and peptides Amino acids C6H9NO5
# 5 ME404283      Organic acids Amino acids and peptides Amino acids C6H9NO5
# 6 ME404283      Organic acids Amino acids and peptides Amino acids C6H9NO5
#   HG p-value Rxn_name     PATHWAY
# 1 0.3928571  L-glutam.... Alanine, aspartate and glutamate metabolism
# 2 0.3928571  L-glutam.... Butanoate metabolism
# 3 0.3928571  L-glutam.... Metabolic pathways
# 4 0.6799771  acetyl-C.... Alanine, aspartate and glutamate metabolism
# 5 0.6799771  acetyl-C.... Metabolic pathways
# 6 0.6799771  N-acetyl.... Alanine, aspartate and glutamate metabolism
#   pathway_id sps_path_id
# 1 rn00250    hsa00250
# 2 rn00650    hsa00650
# 3 rn01100    hsa01100
# 4 rn00250    hsa00250
# 5 rn01100    hsa01100
# 6 rn00250    hsa00250

# %% [markdown]
# Find metabolites for which no pathways were registered in Kegg and/or no kegg id was found

# %%
setdiff(metenrichment$Metabolite,unique(met_path$Metabolite))
# Out:
# [1] "2-hydroxyisobutyric acid"  "Indoxyl Sulfate"
# [3] "Tauroursodeoxycholic acid"

# %% [markdown]
# ### Get pathway enrichment sore.
#
# Once we have the pathway information, we can calculate enrichment score of pathways. Again, here I have used hypergeometric (HG) score. For hypergeometric score, we need to know the total number of kegg compounds that are linked to kegg pathways.
#
# N = total no. of compounds/metabolites linked to all kegg pathways (kegg_comp_path = TRUE) or the total number of metabolites detected in a study (kegg_comp_path = FALSE).
#
# In the former case, this step might take long time, so I advice to run the script comp_linkedto_pathways() just the first time or after 6 months or so if desired to run the pipeline again. Save the result from comp_linkedto_pathways() and load it. Loading from saved file would save time for another analysis with another study. However the package takes care of loading. Save the data in the data folder.
#
# L = No. of significant metabolites detected in a study
#
# M = No. of significant metabolites detected in a metabolite class or pathway
#
# k = Total no. of metabolites detected in a metabolite class/pathway
#
# p-value = phyper(M-1, L, N-L, k, lower.tail=FALSE) # as in the actual R code # originally, it was wriiten as: phyper(M, L, N-L, K)
#
# This function also utilizes korg dataset from pathview package.

# %%
load('../data/ls_path.RData')
load('../data/korg.RData')
kegg_es = path_enrichmentscore(met_path,sig_metabolites_kegg_id=sig_metabolites_kegg_id,ls_path=ls_path,refmet_class=refmet_class,sps='hsa',padj='BH', kegg_comp_path=TRUE, debug = 1)
# Out:
#    M  L    N  k           pp
# 1  2 11 6148 28 1.072652e-03
# 2  3 11 6148 52 8.978776e-05
# 3  1 11 6148 71 1.200384e-01
# 4  1 11 6148 32 5.583163e-02
# 5  1 11 6148 47 8.101407e-02
# 6  1 11 6148 67 1.136408e-01
# 7  1 11 6148 55 9.419357e-02
# 8  1 11 6148 30 5.242700e-02
# 9  1 11 6148 35 6.091774e-02
# 10 1 11 6148 66 1.120349e-01
# 11 2 11 6148 84 9.365749e-03
# 12 3 11 6148 23 7.402422e-06
# 13 3 11 6148 42 4.710003e-05
# [1] "freqtable = "
#                                           Pathway name
# 1          Alanine, aspartate and glutamate metabolism
# 2                          Aminoacyl-tRNA biosynthesis
# 3                      Arginine and proline metabolism
# 4                              beta-Alanine metabolism
# 5                                 Butanoate metabolism
# 6              Glyoxylate and dicarboxylate metabolism
# 7               Nicotinate and nicotinamide metabolism
# 8                    Pantothenate and CoA biosynthesis
# 9  Phenylalanine, tyrosine and tryptophan biosynthesis
# 10                               Pyrimidine metabolism
# 11                               Tryptophan metabolism
# 12         Valine, leucine and isoleucine biosynthesis
# 13          Valine, leucine and isoleucine degradation
#    No. of sig mets in pathway Total_no._of_comps_in_pathway
# 1                           2                            28
# 2                           3                            52
# 3                           1                            71
# 4                           1                            32
# 5                           1                            47
# 6                           1                            67
# 7                           1                            55
# 8                           1                            30
# 9                           1                            35
# 10                          1                            66
# 11                          2                            84
# 12                          3                            23
# 13                          3                            42
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                
#   Total_no._of_comps_in_pathway
# 1 28
# 2 52
# 3 71
# 4 32
# 5 47
# 6 67
#   id
# 1 C00014;C00022;C00025;C00026;C00036;C00041;C00042;C00049;C00064;C00122;C00152;C00158;C00169;C00232;C00334;C00352;C00402;C00438;C00940;C01042;C02362;C03090;C03406;C03794;C03912;C12270;C20775;C20776
# 2 C00025;C00037;C00041;C00047;C00049;C00062;C00064;C00065;C00073;C00078;C00079;C00082;C00097;C00101;C00123;C00135;C00148;C00152;C00183;C00188;C00234;C00407;C00886;C01005;C01931;C02047;C02163;C02282;C02412;C02430;C02553;C02554;C02702;C02839;C02984;C02987;C02988;C02992;C03125;C03127;C03294;C03402;C03511;C03512;C06112;C06113;C06481;C06482;C16138;C16638;C17022;C17027
# 3 C00012;C00019;C00022;C00025;C00048;C00062;C00077;C00086;C00134;C00148;C00179;C00213;C00223;C00300;C00315;C00334;C00406;C00431;C00436;C00441;C00533;C00555;C00581;C00750;C00763;C00791;C00884;C00986;C01035;C01043;C01110;C01137;C01157;C01165;C01250;C01682;C02305;C02565;C02647;C02714;C02946;C03078;C03166;C03287;C03296;C03375;C03415;C03564;C03771;C03912;C04137;C04281;C05147;C05931;C05932;C05933;C05936;C05938;C05945;C05946;C05947;C10497;C15699;C15700;C15767;C18172;C18174;C18326;C19706;C20560;C22886
# 4 C00024;C00049;C00083;C00099;C00100;C00106;C00135;C00222;C00315;C00334;C00383;C00386;C00429;C00555;C00750;C00804;C00864;C00894;C00986;C01013;C01073;C01262;C02335;C02642;C03492;C03722;C05340;C05341;C05665;C05668;C05669;C05670
# 5 C00022;C00024;C00025;C00026;C00042;C00091;C00122;C00132;C00136;C00164;C00207;C00232;C00246;C00332;C00334;C00356;C00497;C00741;C00810;C00877;C00989;C01089;C01144;C01384;C01412;C01769;C01845;C02331;C02411;C02527;C02630;C03044;C03046;C03058;C03561;C04546;C06010;C06142;C06143;C06144;C06145;C06146;C11062;C17530;C20657;C20783;C21390
# 6 C00007;C00011;C00014;C00022;C00024;C00025;C00026;C00027;C00033;C00036;C00037;C00042;C00048;C00049;C00058;C00064;C00065;C00091;C00100;C00111;C00136;C00149;C00158;C00160;C00168;C00197;C00209;C00258;C00266;C00311;C00313;C00332;C00417;C00552;C00631;C00683;C00798;C00877;C00888;C00898;C00975;C00988;C01127;C01146;C01182;C01213;C01380;C01732;C01989;C01990;C02123;C02405;C03217;C03459;C03548;C03561;C03618;C04348;C05840;C06027;C06028;C06049;C18026;C18324;C19838;C20238;C22337
#   pathway_HG_p_value Padjust
# 1 1.072652e-03       0.0034861178
# 2 8.978776e-05       0.0003890803
# 3 1.200384e-01       0.1200384250
# 4 5.583163e-02       0.0989913276
# 5 8.101407e-02       0.1170203200
# 6 1.136408e-01       0.1200384250

# %% [markdown]
# ### Plot pathway network
# Only plotting significant pathways (pathway with p-value significance).
#
# The pathway network is such that it shows metabolites that are connected to different pathways and same metabolite in different pathway. Color of nodes of metabolites are according to the fold change of metabolites (low expression in green and high in red) and size of pathway nodes (square nodes) are according to the number of branches (meaning no of metabolites). All metabolite are written in blue

# %%
plot_pathway_networks (met_path,kegg_es, TRUE)
# Out:
# plot without title

# %% [markdown]
# ### Heatmap

# %%
plot_heatmap(met_path, shorten_name=TRUE,refmet_name=FALSE, xaxis=8, yaxis=6)
# Out:
# plot without title

# %% [markdown]
# ### Dotplot

# %%
dotplot_met_class_path (met_path, kegg_es,"sub_class",xaxis=8,yaxis=6)
# Out:
# Warning message:
# “Use of `significant_pathways[["pathway_HG_p_value"]]` is discouraged.
# ℹ Use `.data[["pathway_HG_p_value"]]` instead.”
# plot without title

# %% [markdown]
# ### Get the gene and enzyme info
#
# Here we get the information of genes involved in enriched pathways for specified organism

# %%
met_gene_info = enzyme_gene_info (metenrichment, "hsa","sub_class")
head(met_gene_info)
# Out:
#   orthology_id ORTHOLOGY                                  gene_id gene_name
# 1 K00128       aldehyde dehydrogenase (NAD+) [EC:1.2.1.3] 217     (RefSeq)....
# 2 K00128       aldehyde dehydrogenase (NAD+) [EC:1.2.1.3] 217     (RefSeq)....
# 3 K00128       aldehyde dehydrogenase (NAD+) [EC:1.2.1.3] 219     (RefSeq)....
# 4 K00128       aldehyde dehydrogenase (NAD+) [EC:1.2.1.3] 219     (RefSeq)....
# 5 K00128       aldehyde dehydrogenase (NAD+) [EC:1.2.1.3] 224     (RefSeq)....
# 6 K00128       aldehyde dehydrogenase (NAD+) [EC:1.2.1.3] 224     (RefSeq)....
#   ORGANISM     PATHWAY      DBLINKS      MOTIF        rxn    Metabolite KEGG ID
# 1 Homo sap.... Glycolys.... NCBI-Gen.... Pfam: Al.... R01986 GABA       C00334
# 2 Homo sap.... Glycolys.... NCBI-Gen.... Pfam: Al.... R02549 GABA       C00334
# 3 Homo sap.... Glycolys.... NCBI-Gen.... Pfam: Aldedh R01986 GABA       C00334
# 4 Homo sap.... Glycolys.... NCBI-Gen.... Pfam: Aldedh R02549 GABA       C00334
# 5 Homo sap.... Glycolys.... NCBI-Gen.... Pfam: Al.... R01986 GABA       C00334
# 6 Homo sap.... Glycolys.... NCBI-Gen.... Pfam: Al.... R02549 GABA       C00334
#   sub_class Rxn_name     RCLASS       EQUATION     EQUATION_more ENZYME
# 1 Amino FA  4-aminob.... RC00001 .... C00555 +.... 4-Aminob....       1.2.1.3
# 2 Amino FA  4-aminob.... RC00001 .... C00555 +.... 4-Aminob....  1.2.1.3,....
# 3 Amino FA  4-aminob.... RC00001 .... C00555 +.... 4-Aminob....       1.2.1.3
# 4 Amino FA  4-aminob.... RC00001 .... C00555 +.... 4-Aminob....  1.2.1.3,....
# 5 Amino FA  4-aminob.... RC00001 .... C00555 +.... 4-Aminob....       1.2.1.3
# 6 Amino FA  4-aminob.... RC00001 .... C00555 +.... 4-Aminob....  1.2.1.3,....

# %% [markdown]
# #### Get the information if metabolite is a reactant or substrate

# %%
rclass_info = react_substrate(met_gene_info)
head(rclass_info)
# Out:
#   orthology_id ORTHOLOGY                                  gene_id gene_name
# 1 K00128       aldehyde dehydrogenase (NAD+) [EC:1.2.1.3] 217     (RefSeq)....
# 2 K00128       aldehyde dehydrogenase (NAD+) [EC:1.2.1.3] 217     (RefSeq)....
# 3 K00128       aldehyde dehydrogenase (NAD+) [EC:1.2.1.3] 219     (RefSeq)....
# 4 K00128       aldehyde dehydrogenase (NAD+) [EC:1.2.1.3] 219     (RefSeq)....
# 5 K00128       aldehyde dehydrogenase (NAD+) [EC:1.2.1.3] 224     (RefSeq)....
# 6 K00128       aldehyde dehydrogenase (NAD+) [EC:1.2.1.3] 224     (RefSeq)....
#   ORGANISM     PATHWAY      DBLINKS      MOTIF        rxn    Metabolite KEGG ID
# 1 Homo sap.... Glycolys.... NCBI-Gen.... Pfam: Al.... R01986 GABA       C00334
# 2 Homo sap.... Glycolys.... NCBI-Gen.... Pfam: Al.... R02549 GABA       C00334
# 3 Homo sap.... Glycolys.... NCBI-Gen.... Pfam: Aldedh R01986 GABA       C00334
# 4 Homo sap.... Glycolys.... NCBI-Gen.... Pfam: Aldedh R02549 GABA       C00334
# 5 Homo sap.... Glycolys.... NCBI-Gen.... Pfam: Al.... R01986 GABA       C00334
# 6 Homo sap.... Glycolys.... NCBI-Gen.... Pfam: Al.... R02549 GABA       C00334
#   sub_class Rxn_name     RCLASS       EQUATION     EQUATION_more ENZYME
# 1 Amino FA  4-aminob.... RC00001 .... C00555 +.... 4-Aminob....       1.2.1.3
# 2 Amino FA  4-aminob.... RC00001 .... C00555 +.... 4-Aminob....  1.2.1.3,....
# 3 Amino FA  4-aminob.... RC00001 .... C00555 +.... 4-Aminob....       1.2.1.3
# 4 Amino FA  4-aminob.... RC00001 .... C00555 +.... 4-Aminob....  1.2.1.3,....
# 5 Amino FA  4-aminob.... RC00001 .... C00555 +.... 4-Aminob....       1.2.1.3
# 6 Amino FA  4-aminob.... RC00001 .... C00555 +.... 4-Aminob....  1.2.1.3,....
#   reactant_product
# 1 Product
# 2 Product
# 3 Product
# 4 Product
# 5 Product
# 6 Product

# %% [markdown]
# #### Get gene info in short form

# %%
met_gene_info2=data.table::data.table(rclass_info)[,lapply(.SD, function(x) toString(unique(x))), by = 'Metabolite']
