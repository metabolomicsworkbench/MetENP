# %% [markdown]
# ## MetENP

# %% [markdown]
# MetENP is a R package that enables detection of significant metabolites from metabolite information
# (names or names and concentration along with metadata information) and provides
#
# 1. Enrichment score of metabolite class,
# 2. Maps to pathway of the species of choice,
# 3. Calculate enrichment score of pathways,
# 4. Plots the pathways and shows the metabolite increase or decrease
# 5. Gets gene info, reaction info, enzyme info
#
# For more info, check out the vignette.

# %%
if (!requireNamespace("KEGGREST", quietly = TRUE))
    BiocManager::install("KEGGREST", update = TRUE, ask = FALSE)

if (!requireNamespace("KEGGgraph", quietly = TRUE))
    BiocManager::install("KEGGgraph", update = TRUE, ask = FALSE)

if (!requireNamespace("pathview", quietly = TRUE))
    BiocManager::install("pathview", update = TRUE, ask = FALSE)

#if (!requireNamespace("KEGG.db", quietly = TRUE))
#    BiocManager::install("KEGG.db", update = TRUE, ask = FALSE)

#if (!requireNamespace("MetENP", quietly = TRUE))
#    devtools::install("..", upgrade = "never")
# Out:
# ##############################################################################
# Pathview is an open source software package distributed under GNU General
# Public License version 3 (GPLv3). Details of GPLv3 is available at
# http://www.gnu.org/licenses/gpl-3.0.html. Particullary, users are required to
# formally cite the original Pathview paper (not just mention it) in publications
# or products. For details, do citation("pathview") within R.
#
# The pathview downloads and uses KEGG data. Non-academic uses may require a KEGG
# license agreement (details at http://www.kegg.jp/kegg/legal.html).
# ##############################################################################

# %%
USER_HOME=Sys.getenv("HOME");
.libPaths( c( .libPaths(), paste0(USER_HOME, "/.local/R") ))
#.libPaths( c( .libPaths(), paste0("../../R") )); # suitable path to where MetENP R package is installed

library(MetENP)

# %% [markdown]
# #### If you do not wish to install, alternatively, download from github(https://github.com/metabolomicsworkbench/MetENP) and load libraries and functions

# %%
data = getmwstudies('ST001742', 'data')
head(data)
# Out:
#   analysis_id analysis_summary                 metabolite_name
# 1 AN002835    Reversed phase POSITIVE ION MODE 2,6-diaminoheptanedioate
# 2 AN002835    Reversed phase POSITIVE ION MODE 2-hydroxyisobutyric acid
# 3 AN002835    Reversed phase POSITIVE ION MODE 5-hydroxymethyl-2-furaldehyde
# 4 AN002835    Reversed phase POSITIVE ION MODE Anthranilic Acid
# 5 AN002835    Reversed phase POSITIVE ION MODE Aspartate
# 6 AN002835    Reversed phase POSITIVE ION MODE Citramalate
#   metabolite_id 213267      213269      216422      223169      228415
# 1 ME404278      28.4614691  28.60232679 33.55073235 46.96524744 34.92883405
# 2 ME404305      3571.687583 2952.862803 38279.31664 3715.782167 1962.831232
# 3 ME404288      16.24609734 6.392339286 14.4979182  4.034452254 10.86824845
# 4 ME404294      10.23251016 15.82498698 8.735853444 38.47294933 19.38540371
# 5 ME404303      863.7467866 602.4521282 793.6813074 579.293206  741.8745409
# 6 ME404286      22.75803679 23.19046427 126.5162935 23.99330464 17.84786488
#   232368      ⋯ 348332      349833      349937      353791      354675
# 1 50.75668511 ⋯ 57.09460919 21.29123287 38.58853423 17.93422304 41.08337062
# 2 5614.298918 ⋯ 31763.75377 92889.33492 9875.43014  40756.30399 17399.70095
# 3 5.435803319 ⋯ 8.353208935 10.91257184 6.099251084 5.195388551 6.97366592
# 4 30.25547902 ⋯ 12.74068831 6.378753611 13.99634318 13.13583241 7.673885187
# 5 684.6116172 ⋯ 773.4878614 673.8675982 391.9905678 266.7322365 379.9625815
# 6 48.52298905 ⋯ 139.7284615 551.8659937 61.28839221 181.0027097 94.54981867
#   355594      355837      359130      360399      refmet_name
# 1 31.16531679 34.44025249 38.87615423 26.70799305 NULL
# 2 24530.2907  1756.482726 23773.25756 3856.904703 2-Hydroxyisobutyric acid
# 3 7.320597283 3.483861703 14.40905702 8.004050357 2-Hydroxyisobutyric acid
# 4 7.740948127 16.49699689 9.562101201 12.74049231 2-Aminobenzoic acid
# 5 422.6758837 544.6729219 908.7220538 674.2418789 Aspartic acid
# 6 136.7332773 28.43724001 115.6095058 48.53054662 Citramalic acid

# %%
metadata = getmwstudies('ST001742', 'factors')
head(metadata)
# Out:
#   study_id local_sample_id subject_type factors
# 1 ST001742 213267          Mammal       Group:Diabetic | Fasted vs Fed:Fasted
# 2 ST001742 213269          Mammal       Group:Diabetic | Fasted vs Fed:Fasted
# 3 ST001742 313074          Mammal       Group:Diabetic | Fasted vs Fed:Fasted
# 4 ST001742 313390          Mammal       Group:Diabetic | Fasted vs Fed:Fasted
# 5 ST001742 321588          Mammal       Group:Diabetic | Fasted vs Fed:Fasted
# 6 ST001742 325103          Mammal       Group:Diabetic | Fasted vs Fed:Fasted
#   Group    Fasted vs Fed
# 1 Diabetic Fasted
# 2 Diabetic Fasted
# 3 Diabetic Fasted
# 4 Diabetic Fasted
# 5 Diabetic Fasted
# 6 Diabetic Fasted

# %% [markdown]
# Find the factors you would want to compare
# Multiple factors (independent variables) are formatted in multiple columns but you can get information on all the factors by "factors" column, such as 'TreatmentGroup:Prednisolone', this indicates column name 'TreatmentGroup' with factor Prednisolone. For t-test use the factors in the same column. For comparing multipe independent variables use anova by anova_ana function.

# %% [markdown]
# ### Associate metabolomics data to the refmet class

# %%
refmet_class= convert_refmet(data)
head(refmet_class)
# Out:
#   metabolite_name               analysis_id analysis_summary
# 1 2-hydroxyisobutyric acid      AN002835    Reversed phase POSITIVE ION MODE
# 2 2,6-diaminoheptanedioate      AN002835    Reversed phase POSITIVE ION MODE
# 3 5-hydroxymethyl-2-furaldehyde AN002835    Reversed phase POSITIVE ION MODE
# 4 Anthranilic Acid              AN002835    Reversed phase POSITIVE ION MODE
# 5 Aspartate                     AN002835    Reversed phase POSITIVE ION MODE
# 6 Citramalate                   AN002835    Reversed phase POSITIVE ION MODE
#   metabolite_id 213267      213269      216422      223169      228415
# 1 ME404305      3571.687583 2952.862803 38279.31664 3715.782167 1962.831232
# 2 ME404278      28.4614691  28.60232679 33.55073235 46.96524744 34.92883405
# 3 ME404288      16.24609734 6.392339286 14.4979182  4.034452254 10.86824845
# 4 ME404294      10.23251016 15.82498698 8.735853444 38.47294933 19.38540371
# 5 ME404303      863.7467866 602.4521282 793.6813074 579.293206  741.8745409
# 6 ME404286      22.75803679 23.19046427 126.5162935 23.99330464 17.84786488
#   232368      ⋯ 354675      355594      355837      359130      360399
# 1 5614.298918 ⋯ 17399.70095 24530.2907  1756.482726 23773.25756 3856.904703
# 2 50.75668511 ⋯ 41.08337062 31.16531679 34.44025249 38.87615423 26.70799305
# 3 5.435803319 ⋯ 6.97366592  7.320597283 3.483861703 14.40905702 8.004050357
# 4 30.25547902 ⋯ 7.673885187 7.740948127 16.49699689 9.562101201 12.74049231
# 5 684.6116172 ⋯ 379.9625815 422.6758837 544.6729219 908.7220538 674.2418789
# 6 48.52298905 ⋯ 94.54981867 136.7332773 28.43724001 115.6095058 48.53054662
#   refmet_name              formula super_class   main_class
# 1 2-Hydroxyisobutyric acid C4H8O3  Fatty Acyls   Fatty acids
# 2 NULL                     NA      NA            NA
# 3 2-Hydroxyisobutyric acid NA      NA            NA
# 4 2-Aminobenzoic acid      C7H7NO2 Benzenoids    Benzoic acids
# 5 Aspartic acid            C4H7NO4 Organic acids Amino acids and peptides
# 6 Citramalic acid          C5H8O5  Organic acids Hydroxy acids
#   sub_class
# 1 Hydroxy FA
# 2 NA
# 3 NA
# 4 Aminobenzoic acids
# 5 Amino acids
# 6 Beta hydroxy acids

# %%
unique(metadata$factors)
# Out:
# [[1]]
# [1] "Group:Diabetic | Fasted vs Fed:Fasted"
#
# [[2]]
# [1] "Group:Diabetic | Fasted vs Fed:Fed"
#
# [[3]]
# [1] "Group:Healthy | Fasted vs Fed:Fasted"
#
# [[4]]
# [1] "Group:Healthy | Fasted vs Fed:Fed"

# %%
### Find the analysis mode
unique(data$analysis_summary)
# Out:
# [[1]]
# [1] "Reversed phase POSITIVE ION MODE"

# %% [markdown]
# ### Find significant metabolites, run significance of all the analysis summary together. The analysis summary/modes you got in the previous section
# There is a normalization step which takes into account missing values, and this can be achieved via three methods:
#
# 1) half_of_min: where the NAs are replaced by half of min values in the data
#
# 2) remove_NAs: where Cols with NAs values are removed
#
# 3) 50percent: where cols with more than 50% NAs values are removed
#
# half_of_min is ideal when you wish to see which metabolites were present in either group. Very high fold change would mean it was present in either group.

# %%
stats_metabolites = significant_met(metabolomics_data=refmet_class, met_col="metabolite_name",analysis_type=c('Reversed phase POSITIVE ION MODE'), metadata=metadata, factor1='Healthy', factor2=c('Diabetic'), factor_col='Group',sample_col='local_sample_id', p_adjust='fdr',normalization="50percent")

sig_metabolites = stats_metabolites[which(stats_metabolites[,"pval"] <= 0.05&abs(stats_metabolites[,"log2Fold_change"])>0.5),]

# %%
plot_volcano(stats_metabolites, thres_pval= 0.05,thres_log2foldchange = 0.0, TRUE)
# Out:
# plot without title

# %% [markdown]
# ### Map metabolite class of the significant metabolites utilzing refmet classification in Metabolomics Workbench
# This function not only maps metabolite to metabolite class but also to external databases such as pubchem, inchi key, smiles and kegg
#
# In this example, we will go forward with significant metabolite obtained by t-test/

# %%
sig_metabolites_kegg_id= map_keggid(sig_metabolites)

# %% [markdown]
# #### Check all your significant metabolites have not been assigned metabolite class

# %%
setdiff(sig_metabolites$refmet_name, sig_metabolites_kegg_id$refmet_name)
# Out:
# character(0)

# %% [markdown]
# ### Count metabolites in each of the metabolite class and plotting
# You may choose from sub_class, main_class and super_class

# %%
count_changes = metcountplot(df_metclass=sig_metabolites_kegg_id, metclass='sub_class', plotting=TRUE, thres_logfC = 0.0)

# %%
count_changes$plotimg
# Out:
# Warning message:
# “Use of `count_changes[[metclass]]` is discouraged. Use `.data[[metclass]]` instead.”
# plot without title

# %% [markdown]
# ### Enrichment class score
#
# Calculate the enrichment score of each metabolite class. Enrichment score is calculated through hypergeometric method. One can specify the no. of significant metabolites in a class while calculating the enrichment score. We advice to use the number of mtabolites in each class as 3 or more. But if someone just wants to know the enrichment score and rest of the information of all the metabolites, then they can choose the number as 1.

# %%
metenrichment = metclassenrichment(df_metclass=sig_metabolites_kegg_id,refmet_class, metclass="sub_class",enrich_stats="HG",no=1)

# %% [markdown]
# #### Plot the enrichment score via function plot_met_enrichment

# %%
plot_met_enrichment(metenrichment, "sub_class","HG", no=1)
# Out:
# Warning message:
# “Use of `metclass_stats[[metclass]]` is discouraged. Use `.data[[metclass]]` instead.”
# Warning message:
# “Use of `metclass_stats[[enrich_stats]]` is discouraged. Use `.data[[enrich_stats]]` instead.”
# Warning message:
# “Use of `metclass_stats[[enrich_stats]]` is discouraged. Use `.data[[enrich_stats]]` instead.”
# plot without title

# %% [markdown]
# ### Check the pathways with reactions of all the significant metabolites

# %%
met_path = met_pathways(df_metenrichment = metenrichment, 'hsa')
head(met_path)
# Out:
# [1] "query_split val"
# NULL
# [1] "----colnames of dd---"
# [1] "ENTRY"      "NAME"       "PATHWAY"    "RCLASS"     "ORTHOLOGY"
# [6] "DEFINITION" "EQUATION"   "ENZYME"
# [1] "-----"
# [1] "colnames of df"
# [1] "ENTRY"      "NAME"       "PATHWAY"    "RCLASS"     "ORTHOLOGY"
# [6] "DEFINITION" "EQUATION"   "ENZYME"
# [1] "======"
# [1] "After renaming columns"
# [1] "ENTRY"         "NAME"          "PATHWAY"       "RCLASS"
# [5] "ORTHOLOGY"     "EQUATION_more" "EQUATION"      "ENZYME"
#   rxn    refmet_name             Exact mass KEGG ID Metabolite
# 1 R00261 gamma-Aminobutyric acid 103.0633   C00334  Glucosamine/Mannosamine
# 2 R00261 gamma-Aminobutyric acid 103.0633   C00334  Glucosamine/Mannosamine
# 3 R00261 gamma-Aminobutyric acid 103.0633   C00334  Glucosamine/Mannosamine
# 4 R00261 gamma-Aminobutyric acid 103.0633   C00334  GABA
# 5 R00261 gamma-Aminobutyric acid 103.0633   C00334  GABA
# 6 R00261 gamma-Aminobutyric acid 103.0633   C00334  GABA
#   Diabetic_mean Healthy_mean Fold_change log2Fold_change t_value   ⋯
# 1 31836.11      19760.30     1.611115    0.6880592       -3.125744 ⋯
# 2 31836.11      19760.30     1.611115    0.6880592       -3.125744 ⋯
# 3 31836.11      19760.30     1.611115    0.6880592       -3.125744 ⋯
# 4 4531.228      2014.099     2.249754    1.1697675       -5.200169 ⋯
# 5 4531.228      2014.099     2.249754    1.1697675       -5.200169 ⋯
# 6 4531.228      2014.099     2.249754    1.1697675       -5.200169 ⋯
#   metabolite_id super_class   main_class      sub_class    formula  HG p-value
# 1 ME404296      Carbohydrates Monosaccharides Amino sugars C6H13NO5 0.9496337
# 2 ME404296      Carbohydrates Monosaccharides Amino sugars C6H13NO5 0.9496337
# 3 ME404296      Carbohydrates Monosaccharides Amino sugars C6H13NO5 0.9496337
# 4 ME404281      Fatty Acyls   Fatty acids     Amino FA     C4H9NO2  0.9496337
# 5 ME404281      Fatty Acyls   Fatty acids     Amino FA     C4H9NO2  0.9496337
# 6 ME404281      Fatty Acyls   Fatty acids     Amino FA     C4H9NO2  0.9496337
#   Rxn_name
# 1 L-glutamate 1-carboxy-lyase (4-aminobutanoate-forming)
# 2 L-glutamate 1-carboxy-lyase (4-aminobutanoate-forming)
# 3 L-glutamate 1-carboxy-lyase (4-aminobutanoate-forming)
# 4 L-glutamate 1-carboxy-lyase (4-aminobutanoate-forming)
# 5 L-glutamate 1-carboxy-lyase (4-aminobutanoate-forming)
# 6 L-glutamate 1-carboxy-lyase (4-aminobutanoate-forming)
#   PATHWAY                                     pathway_id sps_path_id
# 1 Alanine, aspartate and glutamate metabolism rn00250    hsa00250
# 2 Butanoate metabolism                        rn00650    hsa00650
# 3 Metabolic pathways                          rn01100    hsa01100
# 4 Alanine, aspartate and glutamate metabolism rn00250    hsa00250
# 5 Butanoate metabolism                        rn00650    hsa00650
# 6 Metabolic pathways                          rn01100    hsa01100

# %% [markdown]
# Find metabolites for which no pathways were registered in Kegg and/or no kegg id was found

# %%
setdiff(metenrichment$Metabolite,unique(met_path$Metabolite))
# Out:
# [1] "2-hydroxyisobutyric acid"  "Indoxyl Sulfate"
# [3] "Tauroursodeoxycholic acid"

# %% [markdown]
# ### Get pathway enrichment sore.
#
# Once we have the pathway information, we can calculate enrichment score of pathways. Again, here i have used hypergeometric score. For hypergeometric score, we need to know the total number of kegg compounds that are linked to kegg pathways.
# N = total no. of cmpds linked to kegg pathway (this is the step which might take long), so I advice to run the script comp_linkedto_pathways() just the first time or after 6 months or so if desired to run the pipeline again. save the result from comp_linkedto_pathways() and load it. Loading from saved file would save time for another analysis with another study. However the package takes care of loading. Save the data in the data folder.
#
# L = No. of cmpds in a pathway
# M= no. of altered cmpds in a pathway
# K =  total no. of altered cmpds
# phyper(M,L, N-L, K)
#
#
# This function also utilizes korg dataset from pathview package.

# %%
load('../data/ls_path.RData')
load('../data/korg.RData')
kegg_es = path_enrichmentscore(met_path,sig_metabolite_kegg_id=sig_metabolite_kegg_id,ls_path=ls_path,refmet_class=refmet_class,sps='hsa',padj='BH', kegg_comp_path=FALSE)
# Out:
# Warning message in phyper(M - 1, L, N - L, k, lower.tail = FALSE):
# “NaNs produced”
# Warning message in phyper(M - 1, L, N - L, k, lower.tail = FALSE):
# “NaNs produced”
# Warning message in phyper(M - 1, L, N - L, k, lower.tail = FALSE):
# “NaNs produced”
# Warning message in phyper(M - 1, L, N - L, k, lower.tail = FALSE):
# “NaNs produced”
# Warning message in phyper(M - 1, L, N - L, k, lower.tail = FALSE):
# “NaNs produced”
# Warning message in phyper(M - 1, L, N - L, k, lower.tail = FALSE):
# “NaNs produced”
# Warning message in phyper(M - 1, L, N - L, k, lower.tail = FALSE):
# “NaNs produced”
# Warning message in phyper(M - 1, L, N - L, k, lower.tail = FALSE):
# “NaNs produced”
# Warning message in phyper(M - 1, L, N - L, k, lower.tail = FALSE):
# “NaNs produced”
# Warning message in phyper(M - 1, L, N - L, k, lower.tail = FALSE):
# “NaNs produced”
# Warning message in phyper(M - 1, L, N - L, k, lower.tail = FALSE):
# “NaNs produced”

# %%
head(kegg_es)
# Out:
#   Pathway name                                No.of mets in study
# 1 Alanine, aspartate and glutamate metabolism 3
# 2 Aminoacyl-tRNA biosynthesis                 3
# 3 Arginine and proline metabolism             2
# 4 beta-Alanine metabolism                     2
# 5 Butanoate metabolism                        2
# 6 Glyoxylate and dicarboxylate metabolism     1
#   Total_no._of_comps_in_pathway pathway_HG p-value Padjust
# 1 28                              1                  1
# 2 52                            NaN                NaN
# 3 72                            NaN                NaN
# 4 32                            NaN                NaN
# 5 47                            NaN                NaN
# 6 62                            NaN                NaN

# %% [markdown]
# ### Plot pathway network
# Only plotting significant pathways (pathway with p-value significance).
#
# The pathway network is such that it shows metabolites that are connected to different pathways and same metabolite in different pathway. Color of nodes of metabolites are according to the fold change of metabolites (low expression in green and high in red) and size of pathway nodes (square nodes) are according to the number of branches (meaning no of metabolites). All metabolite are written in blue

# %%
plot_pathway_networks (met_path,kegg_es, TRUE)
# Out:
# plot without title

# %% [markdown]
# ### Heatmap

# %%
plot_heatmap(met_path, shorten_name=TRUE,refmet_name=FALSE, xaxis=8, yaxis=6)
# Out:
# plot without title

# %% [markdown]
# ### Dotplot

# %%
dotplot_met_class_path (met_path, kegg_es,"sub_class",xaxis=8,yaxis=6)
# Out:
# Warning message:
# “Use of `significant_pathways[["pathway_HG p-value"]]` is discouraged. Use `.data[["pathway_HG p-value"]]` instead.”
# plot without title

# %% [markdown]
# ### Get the gene and enzyme info
#
# Here we get the information of genes involved in enriched pathways for specified organism

# %%
met_gene_info = enzyme_gene_info (metenrichment, "hsa","sub_class")
head(met_gene_info)
# Out:
# [1] "query_split val"
# NULL
# [1] "----colnames of dd---"
# [1] "ENTRY"      "NAME"       "PATHWAY"    "RCLASS"     "ORTHOLOGY"
# [6] "DEFINITION" "EQUATION"   "ENZYME"
# [1] "-----"
# [1] "colnames of df"
# [1] "ENTRY"      "NAME"       "PATHWAY"    "RCLASS"     "ORTHOLOGY"
# [6] "DEFINITION" "EQUATION"   "ENZYME"
# [1] "======"
# [1] "After renaming columns"
# [1] "ENTRY"         "NAME"          "PATHWAY"       "RCLASS"
# [5] "ORTHOLOGY"     "EQUATION_more" "EQUATION"      "ENZYME"
#   orthology_id ORTHOLOGY                                  gene_id
# 1 K00128       aldehyde dehydrogenase (NAD+) [EC:1.2.1.3] 217
# 2 K00128       aldehyde dehydrogenase (NAD+) [EC:1.2.1.3] 217
# 3 K00128       aldehyde dehydrogenase (NAD+) [EC:1.2.1.3] 217
# 4 K00128       aldehyde dehydrogenase (NAD+) [EC:1.2.1.3] 217
# 5 K00128       aldehyde dehydrogenase (NAD+) [EC:1.2.1.3] 219
# 6 K00128       aldehyde dehydrogenase (NAD+) [EC:1.2.1.3] 219
#   gene_name                                          ORGANISM
# 1 (RefSeq) aldehyde dehydrogenase 2 family member    Homo sapiens (human)
# 2 (RefSeq) aldehyde dehydrogenase 2 family member    Homo sapiens (human)
# 3 (RefSeq) aldehyde dehydrogenase 2 family member    Homo sapiens (human)
# 4 (RefSeq) aldehyde dehydrogenase 2 family member    Homo sapiens (human)
# 5 (RefSeq) aldehyde dehydrogenase 1 family member B1 Homo sapiens (human)
# 6 (RefSeq) aldehyde dehydrogenase 1 family member B1 Homo sapiens (human)
#   PATHWAY
# 1 Glycolysis / Gluconeogenesis              , Ascorbate and aldarate metabolism         , Fatty acid degradation                    , Valine, leucine and isoleucine degradation, Lysine degradation                        , Arginine and proline metabolism           , Histidine metabolism                      , Tryptophan metabolism                     , beta-Alanine metabolism                   , Glycerolipid metabolism                   , Pyruvate metabolism                       , Pantothenate and CoA biosynthesis         , Metabolic pathways                        , Biosynthesis of cofactors                 , Alcoholic liver disease
# 2 Glycolysis / Gluconeogenesis              , Ascorbate and aldarate metabolism         , Fatty acid degradation                    , Valine, leucine and isoleucine degradation, Lysine degradation                        , Arginine and proline metabolism           , Histidine metabolism                      , Tryptophan metabolism                     , beta-Alanine metabolism                   , Glycerolipid metabolism                   , Pyruvate metabolism                       , Pantothenate and CoA biosynthesis         , Metabolic pathways                        , Biosynthesis of cofactors                 , Alcoholic liver disease
# 3 Glycolysis / Gluconeogenesis              , Ascorbate and aldarate metabolism         , Fatty acid degradation                    , Valine, leucine and isoleucine degradation, Lysine degradation                        , Arginine and proline metabolism           , Histidine metabolism                      , Tryptophan metabolism                     , beta-Alanine metabolism                   , Glycerolipid metabolism                   , Pyruvate metabolism                       , Pantothenate and CoA biosynthesis         , Metabolic pathways                        , Biosynthesis of cofactors                 , Alcoholic liver disease
# 4 Glycolysis / Gluconeogenesis              , Ascorbate and aldarate metabolism         , Fatty acid degradation                    , Valine, leucine and isoleucine degradation, Lysine degradation                        , Arginine and proline metabolism           , Histidine metabolism                      , Tryptophan metabolism                     , beta-Alanine metabolism                   , Glycerolipid metabolism                   , Pyruvate metabolism                       , Pantothenate and CoA biosynthesis         , Metabolic pathways                        , Biosynthesis of cofactors                 , Alcoholic liver disease
# 5 Glycolysis / Gluconeogenesis              , Ascorbate and aldarate metabolism         , Fatty acid degradation                    , Valine, leucine and isoleucine degradation, Lysine degradation                        , Arginine and proline metabolism           , Histidine metabolism                      , Tryptophan metabolism                     , beta-Alanine metabolism                   , Glycerolipid metabolism                   , Pyruvate metabolism                       , Pantothenate and CoA biosynthesis         , Metabolic pathways                        , Biosynthesis of cofactors                 , Alcoholic liver disease
# 6 Glycolysis / Gluconeogenesis              , Ascorbate and aldarate metabolism         , Fatty acid degradation                    , Valine, leucine and isoleucine degradation, Lysine degradation                        , Arginine and proline metabolism           , Histidine metabolism                      , Tryptophan metabolism                     , beta-Alanine metabolism                   , Glycerolipid metabolism                   , Pyruvate metabolism                       , Pantothenate and CoA biosynthesis         , Metabolic pathways                        , Biosynthesis of cofactors                 , Alcoholic liver disease
#   DBLINKS
# 1 NCBI-GeneID: 217          , NCBI-ProteinID: NP_000681 , OMIM: 100650              , HGNC: 404                 , Ensembl: ENSG00000111275  , Vega: OTTHUMG00000169603  , Pharos: P05091(Tclin)     , UniProt: P05091 A0A384NPN7
# 2 NCBI-GeneID: 217          , NCBI-ProteinID: NP_000681 , OMIM: 100650              , HGNC: 404                 , Ensembl: ENSG00000111275  , Vega: OTTHUMG00000169603  , Pharos: P05091(Tclin)     , UniProt: P05091 A0A384NPN7
# 3 NCBI-GeneID: 217          , NCBI-ProteinID: NP_000681 , OMIM: 100650              , HGNC: 404                 , Ensembl: ENSG00000111275  , Vega: OTTHUMG00000169603  , Pharos: P05091(Tclin)     , UniProt: P05091 A0A384NPN7
# 4 NCBI-GeneID: 217          , NCBI-ProteinID: NP_000681 , OMIM: 100650              , HGNC: 404                 , Ensembl: ENSG00000111275  , Vega: OTTHUMG00000169603  , Pharos: P05091(Tclin)     , UniProt: P05091 A0A384NPN7
# 5 NCBI-GeneID: 219          , NCBI-ProteinID: NP_000683 , OMIM: 100670              , HGNC: 407                 , Ensembl: ENSG00000137124  , Vega: OTTHUMG00000019938  , Pharos: P30837(Tbio)      , UniProt: P30837 A0A384MTJ7
# 6 NCBI-GeneID: 219          , NCBI-ProteinID: NP_000683 , OMIM: 100670              , HGNC: 407                 , Ensembl: ENSG00000137124  , Vega: OTTHUMG00000019938  , Pharos: P30837(Tbio)      , UniProt: P30837 A0A384MTJ7
#   MOTIF                rxn    Metabolite              KEGG ID sub_class
# 1 Pfam: Aldedh DUF1235 R01986 GABA                    C00334  Amino FA
# 2 Pfam: Aldedh DUF1235 R02549 GABA                    C00334  Amino FA
# 3 Pfam: Aldedh DUF1235 R02549 Glucosamine/Mannosamine C00334  Amino sugars
# 4 Pfam: Aldedh DUF1235 R01986 Glucosamine/Mannosamine C00334  Amino sugars
# 5 Pfam: Aldedh         R01986 GABA                    C00334  Amino FA
# 6 Pfam: Aldedh         R02549 GABA                    C00334  Amino FA
#   Rxn_name
# 1 4-Aminobutyraldehyde:NAD+ oxidoreductase
# 2 4-aminobutanal:NAD+ 1-oxidoreductase;   , 4-aminobutyraldehyde:NAD+ oxidoreductase
# 3 4-aminobutanal:NAD+ 1-oxidoreductase;   , 4-aminobutyraldehyde:NAD+ oxidoreductase
# 4 4-Aminobutyraldehyde:NAD+ oxidoreductase
# 5 4-Aminobutyraldehyde:NAD+ oxidoreductase
# 6 4-aminobutanal:NAD+ 1-oxidoreductase;   , 4-aminobutyraldehyde:NAD+ oxidoreductase
#   RCLASS
# 1 RC00001  C00005_C00006, RC00080  C00334_C00555
# 2 RC00001  C00003_C00004, RC00080  C00334_C00555
# 3 RC00001  C00003_C00004, RC00080  C00334_C00555
# 4 RC00001  C00005_C00006, RC00080  C00334_C00555
# 5 RC00001  C00005_C00006, RC00080  C00334_C00555
# 6 RC00001  C00003_C00004, RC00080  C00334_C00555
#   EQUATION
# 1 C00555 + C00006 + C00001 <=> C00334 + C00005 + C00080
# 2 C00555 + C00003 + C00001 <=> C00334 + C00004 + C00080
# 3 C00555 + C00003 + C00001 <=> C00334 + C00004 + C00080
# 4 C00555 + C00006 + C00001 <=> C00334 + C00005 + C00080
# 5 C00555 + C00006 + C00001 <=> C00334 + C00005 + C00080
# 6 C00555 + C00003 + C00001 <=> C00334 + C00004 + C00080
#   EQUATION_more
# 1 4-Aminobutyraldehyde + NADP+ + H2O <=> 4-Aminobutanoate + NADPH + H+
# 2 4-Aminobutyraldehyde + NAD+ + H2O <=> 4-Aminobutanoate + NADH + H+
# 3 4-Aminobutyraldehyde + NAD+ + H2O <=> 4-Aminobutanoate + NADH + H+
# 4 4-Aminobutyraldehyde + NADP+ + H2O <=> 4-Aminobutanoate + NADPH + H+
# 5 4-Aminobutyraldehyde + NADP+ + H2O <=> 4-Aminobutanoate + NADPH + H+
# 6 4-Aminobutyraldehyde + NAD+ + H2O <=> 4-Aminobutanoate + NADH + H+
#   ENZYME
# 1 1.2.1.3
# 2 1.2.1.3 , 1.2.1.19, 1.2.1.-
# 3 1.2.1.3 , 1.2.1.19, 1.2.1.-
# 4 1.2.1.3
# 5 1.2.1.3
# 6 1.2.1.3 , 1.2.1.19, 1.2.1.-

# %% [markdown]
# #### Get the information if metabolite is a reactant or substrate

# %%
rclass_info = react_substrate(met_gene_info)
head(rclass_info)
# Out:
#   orthology_id ORTHOLOGY                                  gene_id
# 1 K00128       aldehyde dehydrogenase (NAD+) [EC:1.2.1.3] 217
# 2 K00128       aldehyde dehydrogenase (NAD+) [EC:1.2.1.3] 217
# 3 K00128       aldehyde dehydrogenase (NAD+) [EC:1.2.1.3] 217
# 4 K00128       aldehyde dehydrogenase (NAD+) [EC:1.2.1.3] 217
# 5 K00128       aldehyde dehydrogenase (NAD+) [EC:1.2.1.3] 219
# 6 K00128       aldehyde dehydrogenase (NAD+) [EC:1.2.1.3] 219
#   gene_name                                          ORGANISM
# 1 (RefSeq) aldehyde dehydrogenase 2 family member    Homo sapiens (human)
# 2 (RefSeq) aldehyde dehydrogenase 2 family member    Homo sapiens (human)
# 3 (RefSeq) aldehyde dehydrogenase 2 family member    Homo sapiens (human)
# 4 (RefSeq) aldehyde dehydrogenase 2 family member    Homo sapiens (human)
# 5 (RefSeq) aldehyde dehydrogenase 1 family member B1 Homo sapiens (human)
# 6 (RefSeq) aldehyde dehydrogenase 1 family member B1 Homo sapiens (human)
#   PATHWAY
# 1 Glycolysis / Gluconeogenesis              , Ascorbate and aldarate metabolism         , Fatty acid degradation                    , Valine, leucine and isoleucine degradation, Lysine degradation                        , Arginine and proline metabolism           , Histidine metabolism                      , Tryptophan metabolism                     , beta-Alanine metabolism                   , Glycerolipid metabolism                   , Pyruvate metabolism                       , Pantothenate and CoA biosynthesis         , Metabolic pathways                        , Biosynthesis of cofactors                 , Alcoholic liver disease
# 2 Glycolysis / Gluconeogenesis              , Ascorbate and aldarate metabolism         , Fatty acid degradation                    , Valine, leucine and isoleucine degradation, Lysine degradation                        , Arginine and proline metabolism           , Histidine metabolism                      , Tryptophan metabolism                     , beta-Alanine metabolism                   , Glycerolipid metabolism                   , Pyruvate metabolism                       , Pantothenate and CoA biosynthesis         , Metabolic pathways                        , Biosynthesis of cofactors                 , Alcoholic liver disease
# 3 Glycolysis / Gluconeogenesis              , Ascorbate and aldarate metabolism         , Fatty acid degradation                    , Valine, leucine and isoleucine degradation, Lysine degradation                        , Arginine and proline metabolism           , Histidine metabolism                      , Tryptophan metabolism                     , beta-Alanine metabolism                   , Glycerolipid metabolism                   , Pyruvate metabolism                       , Pantothenate and CoA biosynthesis         , Metabolic pathways                        , Biosynthesis of cofactors                 , Alcoholic liver disease
# 4 Glycolysis / Gluconeogenesis              , Ascorbate and aldarate metabolism         , Fatty acid degradation                    , Valine, leucine and isoleucine degradation, Lysine degradation                        , Arginine and proline metabolism           , Histidine metabolism                      , Tryptophan metabolism                     , beta-Alanine metabolism                   , Glycerolipid metabolism                   , Pyruvate metabolism                       , Pantothenate and CoA biosynthesis         , Metabolic pathways                        , Biosynthesis of cofactors                 , Alcoholic liver disease
# 5 Glycolysis / Gluconeogenesis              , Ascorbate and aldarate metabolism         , Fatty acid degradation                    , Valine, leucine and isoleucine degradation, Lysine degradation                        , Arginine and proline metabolism           , Histidine metabolism                      , Tryptophan metabolism                     , beta-Alanine metabolism                   , Glycerolipid metabolism                   , Pyruvate metabolism                       , Pantothenate and CoA biosynthesis         , Metabolic pathways                        , Biosynthesis of cofactors                 , Alcoholic liver disease
# 6 Glycolysis / Gluconeogenesis              , Ascorbate and aldarate metabolism         , Fatty acid degradation                    , Valine, leucine and isoleucine degradation, Lysine degradation                        , Arginine and proline metabolism           , Histidine metabolism                      , Tryptophan metabolism                     , beta-Alanine metabolism                   , Glycerolipid metabolism                   , Pyruvate metabolism                       , Pantothenate and CoA biosynthesis         , Metabolic pathways                        , Biosynthesis of cofactors                 , Alcoholic liver disease
#   DBLINKS
# 1 NCBI-GeneID: 217          , NCBI-ProteinID: NP_000681 , OMIM: 100650              , HGNC: 404                 , Ensembl: ENSG00000111275  , Vega: OTTHUMG00000169603  , Pharos: P05091(Tclin)     , UniProt: P05091 A0A384NPN7
# 2 NCBI-GeneID: 217          , NCBI-ProteinID: NP_000681 , OMIM: 100650              , HGNC: 404                 , Ensembl: ENSG00000111275  , Vega: OTTHUMG00000169603  , Pharos: P05091(Tclin)     , UniProt: P05091 A0A384NPN7
# 3 NCBI-GeneID: 217          , NCBI-ProteinID: NP_000681 , OMIM: 100650              , HGNC: 404                 , Ensembl: ENSG00000111275  , Vega: OTTHUMG00000169603  , Pharos: P05091(Tclin)     , UniProt: P05091 A0A384NPN7
# 4 NCBI-GeneID: 217          , NCBI-ProteinID: NP_000681 , OMIM: 100650              , HGNC: 404                 , Ensembl: ENSG00000111275  , Vega: OTTHUMG00000169603  , Pharos: P05091(Tclin)     , UniProt: P05091 A0A384NPN7
# 5 NCBI-GeneID: 219          , NCBI-ProteinID: NP_000683 , OMIM: 100670              , HGNC: 407                 , Ensembl: ENSG00000137124  , Vega: OTTHUMG00000019938  , Pharos: P30837(Tbio)      , UniProt: P30837 A0A384MTJ7
# 6 NCBI-GeneID: 219          , NCBI-ProteinID: NP_000683 , OMIM: 100670              , HGNC: 407                 , Ensembl: ENSG00000137124  , Vega: OTTHUMG00000019938  , Pharos: P30837(Tbio)      , UniProt: P30837 A0A384MTJ7
#   MOTIF                rxn    Metabolite              KEGG ID sub_class
# 1 Pfam: Aldedh DUF1235 R01986 GABA                    C00334  Amino FA
# 2 Pfam: Aldedh DUF1235 R02549 GABA                    C00334  Amino FA
# 3 Pfam: Aldedh DUF1235 R02549 Glucosamine/Mannosamine C00334  Amino sugars
# 4 Pfam: Aldedh DUF1235 R01986 Glucosamine/Mannosamine C00334  Amino sugars
# 5 Pfam: Aldedh         R01986 GABA                    C00334  Amino FA
# 6 Pfam: Aldedh         R02549 GABA                    C00334  Amino FA
#   Rxn_name
# 1 4-Aminobutyraldehyde:NAD+ oxidoreductase
# 2 4-aminobutanal:NAD+ 1-oxidoreductase;   , 4-aminobutyraldehyde:NAD+ oxidoreductase
# 3 4-aminobutanal:NAD+ 1-oxidoreductase;   , 4-aminobutyraldehyde:NAD+ oxidoreductase
# 4 4-Aminobutyraldehyde:NAD+ oxidoreductase
# 5 4-Aminobutyraldehyde:NAD+ oxidoreductase
# 6 4-aminobutanal:NAD+ 1-oxidoreductase;   , 4-aminobutyraldehyde:NAD+ oxidoreductase
#   RCLASS
# 1 RC00001  C00005_C00006, RC00080  C00334_C00555
# 2 RC00001  C00003_C00004, RC00080  C00334_C00555
# 3 RC00001  C00003_C00004, RC00080  C00334_C00555
# 4 RC00001  C00005_C00006, RC00080  C00334_C00555
# 5 RC00001  C00005_C00006, RC00080  C00334_C00555
# 6 RC00001  C00003_C00004, RC00080  C00334_C00555
#   EQUATION
# 1 C00555 + C00006 + C00001 <=> C00334 + C00005 + C00080
# 2 C00555 + C00003 + C00001 <=> C00334 + C00004 + C00080
# 3 C00555 + C00003 + C00001 <=> C00334 + C00004 + C00080
# 4 C00555 + C00006 + C00001 <=> C00334 + C00005 + C00080
# 5 C00555 + C00006 + C00001 <=> C00334 + C00005 + C00080
# 6 C00555 + C00003 + C00001 <=> C00334 + C00004 + C00080
#   EQUATION_more
# 1 4-Aminobutyraldehyde + NADP+ + H2O <=> 4-Aminobutanoate + NADPH + H+
# 2 4-Aminobutyraldehyde + NAD+ + H2O <=> 4-Aminobutanoate + NADH + H+
# 3 4-Aminobutyraldehyde + NAD+ + H2O <=> 4-Aminobutanoate + NADH + H+
# 4 4-Aminobutyraldehyde + NADP+ + H2O <=> 4-Aminobutanoate + NADPH + H+
# 5 4-Aminobutyraldehyde + NADP+ + H2O <=> 4-Aminobutanoate + NADPH + H+
# 6 4-Aminobutyraldehyde + NAD+ + H2O <=> 4-Aminobutanoate + NADH + H+
#   ENZYME                       reactant_product
# 1 1.2.1.3                      Product
# 2 1.2.1.3 , 1.2.1.19, 1.2.1.-  Product
# 3 1.2.1.3 , 1.2.1.19, 1.2.1.-  Product
# 4 1.2.1.3                      Product
# 5 1.2.1.3                      Product
# 6 1.2.1.3 , 1.2.1.19, 1.2.1.-  Product

# %% [markdown]
# #### Get gene info in short form

# %%
met_gene_info2=data.table::data.table(rclass_info)[,lapply(.SD, function(x) toString(unique(x))), by = 'Metabolite']
